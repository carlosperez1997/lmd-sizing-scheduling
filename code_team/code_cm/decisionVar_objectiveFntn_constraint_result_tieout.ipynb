# %% [markdown]
# Code used to create result file for tying out decision variable, objective function and constraint code.

# %%
from glob import glob
from os import path
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.legend_handler import HandlerTuple
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#get the distinct list of city and demand type combinations

list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['paris_db=1.00', 'berlin_db=1.00', 'berlin_db=0.50', 'frankfurt_db=2.00', 'lyon_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'paris_db=2.00', 'lyon_db=1.00', 'paris_db=0.50', 'frankfurt_db=1.00', 'paris_db=4.00', 'lyon_db=0.50', 'berlin_db=2.00', 'frankfurt_db=4.00', 'lyon_db=4.00']
# 16

# %%
#create a dataframe that can hold all result information

list_results = []

workforce_dict = {0:5, 1:5, 2:5, 3:5, 4:5}
RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

for base_file in list_city_dt:
    weekday_ = f'{base_file}_dt=doublepeak.json'
    weekend_ = f'{base_file}_dt=uniform.json'

    instance_file_weekday = f"../instances/{weekday_}"
    instance_file_weekend = f"../instances/{weekend_}"

    shift_file_weekday = f"../shifts/{weekday_}"
    shift_file_weekend = f"../shifts/{weekend_}"
    
    for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
    # for OC in [1.5]:
        model = 'fixed'
        dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
        df_ = pd.DataFrame(dict_results)
        list_results.append(df_)

        model = 'flex'
        dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
        df_ = pd.DataFrame(dict_results)
        list_results.append(df_)

        model = 'partflex'
        for max_n_shifts in range(2,5):            
            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
            df_ = pd.DataFrame(dict_results)
            list_results.append(df_)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35780 rows, 39520 columns and 208958 nonzeros
# Model fingerprint: 0xb4b9c01f
# Variable types: 33600 continuous, 5920 integer (5920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 35105 rows and 37352 columns
# Presolve time: 0.17s
# Presolved: 675 rows, 2168 columns, 6183 nonzeros
# Variable types: 753 continuous, 1415 integer (1400 binary)
# Found heuristic solution: objective 16852.894682
#
# Root relaxation: objective 1.677321e+04, 1683 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    16773.214119 16773.2141  0.00%     -    0s
#
# Explored 1 nodes (1683 simplex iterations) in 0.24 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 16773.2 16852.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.677321411899e+04, best bound 1.677321411899e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35730 rows, 39505 columns and 208348 nonzeros
# Model fingerprint: 0x282adef1
# Variable types: 33600 continuous, 5905 integer (5905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 33899 rows and 33848 columns
# Presolve time: 0.10s
#
# Explored 0 nodes (0 simplex iterations) in 0.13 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35380 rows, 39300 columns and 203518 nonzeros
# Model fingerprint: 0x9ab22ec7
# Variable types: 33600 continuous, 5700 integer (5700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 75 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35730 rows, 39505 columns and 208348 nonzeros
# Model fingerprint: 0x282adef1
# Variable types: 33600 continuous, 5905 integer (5905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 33899 rows and 33848 columns
# Presolve time: 0.08s
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35730 rows, 39505 columns and 208348 nonzeros
# Model fingerprint: 0x282adef1
# Variable types: 33600 continuous, 5905 integer (5905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 33899 rows and 33848 columns
# Presolve time: 0.07s
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35780 rows, 39520 columns and 208958 nonzeros
# Model fingerprint: 0xb05c0abf
# Variable types: 33600 continuous, 5920 integer (5920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 35105 rows and 37352 columns
# Presolve time: 0.16s
# Presolved: 675 rows, 2168 columns, 6183 nonzeros
# Variable types: 753 continuous, 1415 integer (1400 binary)
# Found heuristic solution: objective 20946.118352
#
# Root relaxation: objective 2.084652e+04, 1685 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    20846.517649 20846.5176  0.00%     -    0s
#
# Explored 1 nodes (1685 simplex iterations) in 0.22 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 20846.5 20946.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.084651764874e+04, best bound 2.084651764874e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35730 rows, 39505 columns and 208348 nonzeros
# Model fingerprint: 0xd895ce05
# Variable types: 33600 continuous, 5905 integer (5905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 33874 rows and 33848 columns
# Presolve time: 0.09s
#
# Explored 0 nodes (0 simplex iterations) in 0.13 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35380 rows, 39300 columns and 203518 nonzeros
# Model fingerprint: 0x809e48a5
# Variable types: 33600 continuous, 5700 integer (5700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 75 rows and 0 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35630 rows, 39445 columns and 207038 nonzeros
# Model fingerprint: 0x600c64ab
# Variable types: 33600 continuous, 5845 integer (5845 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34334 rows and 35148 columns
# Presolve time: 0.10s
#
# Explored 0 nodes (0 simplex iterations) in 0.14 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35630 rows, 39445 columns and 207038 nonzeros
# Model fingerprint: 0x600c64ab
# Variable types: 33600 continuous, 5845 integer (5845 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34334 rows and 35148 columns
# Presolve time: 0.07s
#
# Explored 0 nodes (0 simplex iterations) in 0.09 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35780 rows, 39520 columns and 208958 nonzeros
# Model fingerprint: 0x52971236
# Variable types: 33600 continuous, 5920 integer (5920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 35105 rows and 37352 columns
# Presolve time: 0.20s
# Presolved: 675 rows, 2168 columns, 6183 nonzeros
# Variable types: 753 continuous, 1415 integer (1400 binary)
# Found heuristic solution: objective 25039.342022
#
# Root relaxation: objective 2.491982e+04, 1775 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24919.821178 24919.8212  0.00%     -    0s
#
# Explored 1 nodes (1775 simplex iterations) in 0.27 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 24919.8 25039.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.491982117849e+04, best bound 2.491982117849e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35680 rows, 39475 columns and 207643 nonzeros
# Model fingerprint: 0x90552af1
# Variable types: 33600 continuous, 5875 integer (5875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34114 rows and 34568 columns
# Presolve time: 0.07s
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35380 rows, 39300 columns and 203518 nonzeros
# Model fingerprint: 0x84101e89
# Variable types: 33600 continuous, 5700 integer (5700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 75 rows and 0 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35630 rows, 39445 columns and 206838 nonzeros
# Model fingerprint: 0x9a6f06dd
# Variable types: 33600 continuous, 5845 integer (5845 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34339 rows and 35418 columns
# Presolve time: 0.07s
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35630 rows, 39445 columns and 206838 nonzeros
# Model fingerprint: 0x9a6f06dd
# Variable types: 33600 continuous, 5845 integer (5845 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34339 rows and 35418 columns
# Presolve time: 0.07s
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35780 rows, 39520 columns and 208958 nonzeros
# Model fingerprint: 0xa4b22d50
# Variable types: 33600 continuous, 5920 integer (5920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 35105 rows and 37352 columns
# Presolve time: 0.17s
# Presolved: 675 rows, 2168 columns, 6183 nonzeros
# Variable types: 753 continuous, 1415 integer (1400 binary)
# Found heuristic solution: objective 27768.157803
#
# Root relaxation: objective 2.763536e+04, 1566 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27635.356865 27635.3569  0.00%     -    0s
#
# Explored 1 nodes (1566 simplex iterations) in 0.24 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27635.4 27768.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.763535686499e+04, best bound 2.763535686499e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35680 rows, 39475 columns and 207643 nonzeros
# Model fingerprint: 0x4590a7ed
# Variable types: 33600 continuous, 5875 integer (5875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34224 rows and 34483 columns
# Presolve time: 0.11s
#
# Explored 0 nodes (0 simplex iterations) in 0.14 seconds (0.14 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35380 rows, 39300 columns and 203518 nonzeros
# Model fingerprint: 0x97221d2b
# Variable types: 33600 continuous, 5700 integer (5700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 75 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35580 rows, 39415 columns and 206133 nonzeros
# Model fingerprint: 0xfdd5e341
# Variable types: 33600 continuous, 5815 integer (5815 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34234 rows and 34833 columns
# Presolve time: 0.08s
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.11 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35580 rows, 39415 columns and 206133 nonzeros
# Model fingerprint: 0xfdd5e341
# Variable types: 33600 continuous, 5815 integer (5815 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 34234 rows and 34833 columns
# Presolve time: 0.08s
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.11 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35780 rows, 39520 columns and 208958 nonzeros
# Model fingerprint: 0x5a100faa
# Variable types: 33600 continuous, 5920 integer (5920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 35105 rows and 37352 columns
# Presolve time: 0.18s
# Presolved: 675 rows, 2168 columns, 6183 nonzeros
# Variable types: 753 continuous, 1415 integer (1400 binary)
# Found heuristic solution: objective 34590.197253
#
# Root relaxation: objective 3.442420e+04, 1413 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    34424.196081 34424.1961  0.00%     -    0s
#
# Explored 1 nodes (1413 simplex iterations) in 0.24 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 34424.2 34590.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.442419608123e+04, best bound 3.442419608123e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35480 rows, 39355 columns and 204923 nonzeros
# Model fingerprint: 0x18259002
# Variable types: 33600 continuous, 5755 integer (5755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 50 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35380 rows, 39300 columns and 203518 nonzeros
# Model fingerprint: 0x31c0ff1a
# Variable types: 33600 continuous, 5700 integer (5700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 75 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35480 rows, 39355 columns and 204923 nonzeros
# Model fingerprint: 0x18259002
# Variable types: 33600 continuous, 5755 integer (5755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 50 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35480 rows, 39355 columns and 204923 nonzeros
# Model fingerprint: 0x18259002
# Variable types: 33600 continuous, 5755 integer (5755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 50 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101300 rows, 115960 columns and 499088 nonzeros
# Model fingerprint: 0xa854eb5b
# Variable types: 99120 continuous, 16840 integer (16840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91901 columns
# Presolve time: 0.17s
# Presolved: 5139 rows, 24059 columns, 91134 nonzeros
# Variable types: 7259 continuous, 16800 integer (16800 binary)
# Found heuristic solution: objective 7036.9133333
# Found heuristic solution: objective 7035.3133333
#
# Root relaxation: objective 6.792093e+03, 3570 iterations, 0.05 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6792.0933333 6792.09333  0.00%     -    0s
#
# Explored 1 nodes (3570 simplex iterations) in 0.59 seconds (0.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6792.09 7035.31 7036.91
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.792093333333e+03, best bound 6.792093333333e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101380 rows, 116025 columns and 502153 nonzeros
# Model fingerprint: 0x305dbfb7
# Variable types: 99120 continuous, 16905 integer (16905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.16s
# Presolved: 5344 rows, 24139 columns, 94424 nonzeros
# Variable types: 7259 continuous, 16880 integer (16880 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.31 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101140 rows, 115875 columns and 493983 nonzeros
# Model fingerprint: 0xb9643209
# Variable types: 99120 continuous, 16755 integer (16755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91896 columns
# Presolve time: 0.17s
# Presolved: 4979 rows, 23979 columns, 86194 nonzeros
# Variable types: 7259 continuous, 16720 integer (16720 binary)
# Found heuristic solution: objective 7055.2000000
#
# Root relaxation: objective 6.845260e+03, 3111 iterations, 0.05 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6845.2600000 6845.26000  0.00%     -    0s
#
# Explored 1 nodes (3111 simplex iterations) in 0.55 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 6845.26 7055.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.845260000000e+03, best bound 6.845260000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116010 columns and 501668 nonzeros
# Model fingerprint: 0x59e95041
# Variable types: 99120 continuous, 16890 integer (16890 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96111 rows and 91901 columns
# Presolve time: 0.22s
# Presolved: 5249 rows, 24109 columns, 93794 nonzeros
# Variable types: 7259 continuous, 16850 integer (16850 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.35 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101380 rows, 116025 columns and 502153 nonzeros
# Model fingerprint: 0x305dbfb7
# Variable types: 99120 continuous, 16905 integer (16905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.16s
# Presolved: 5344 rows, 24139 columns, 94424 nonzeros
# Variable types: 7259 continuous, 16880 integer (16880 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.28 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101300 rows, 115960 columns and 499088 nonzeros
# Model fingerprint: 0xd024af70
# Variable types: 99120 continuous, 16840 integer (16840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91901 columns
# Presolve time: 0.16s
# Presolved: 5139 rows, 24059 columns, 91134 nonzeros
# Variable types: 7254 continuous, 16805 integer (16800 binary)
# Found heuristic solution: objective 8676.1416667
# Found heuristic solution: objective 8674.1416667
#
# Root relaxation: objective 8.370117e+03, 3542 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8370.1166667 8370.11667  0.00%     -    0s
#
# Explored 1 nodes (4304 simplex iterations) in 0.58 seconds (0.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 8370.12 8674.14 8676.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.370116666666e+03, best bound 8.370116666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101400 rows, 116035 columns and 502713 nonzeros
# Model fingerprint: 0x6e13cd71
# Variable types: 99120 continuous, 16915 integer (16915 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.15s
# Presolved: 5364 rows, 24149 columns, 94964 nonzeros
# Variable types: 7254 continuous, 16895 integer (16890 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.26 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101140 rows, 115875 columns and 493983 nonzeros
# Model fingerprint: 0x7d80da93
# Variable types: 99120 continuous, 16755 integer (16755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91896 columns
# Presolve time: 0.18s
# Presolved: 4979 rows, 23979 columns, 86194 nonzeros
# Variable types: 7254 continuous, 16725 integer (16720 binary)
# Found heuristic solution: objective 8699.0000000
#
# Root relaxation: objective 8.436575e+03, 3259 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8436.5750000 8436.57500  0.00%     -    0s
#
# Explored 1 nodes (3259 simplex iterations) in 0.52 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8436.58 8699
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.436575000000e+03, best bound 8.436575000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116005 columns and 501263 nonzeros
# Model fingerprint: 0x23c11096
# Variable types: 99120 continuous, 16885 integer (16885 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96211 rows and 91916 columns
# Presolve time: 0.16s
# Presolved: 5149 rows, 24089 columns, 93184 nonzeros
# Variable types: 7254 continuous, 16835 integer (16830 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.27 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101380 rows, 116025 columns and 502153 nonzeros
# Model fingerprint: 0x4a97d943
# Variable types: 99120 continuous, 16905 integer (16905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.14s
# Presolved: 5344 rows, 24139 columns, 94424 nonzeros
# Variable types: 7254 continuous, 16885 integer (16880 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.25 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101300 rows, 115960 columns and 499088 nonzeros
# Model fingerprint: 0x51402f02
# Variable types: 99120 continuous, 16840 integer (16840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91901 columns
# Presolve time: 0.14s
# Presolved: 5139 rows, 24059 columns, 91134 nonzeros
# Variable types: 7259 continuous, 16800 integer (16800 binary)
# Found heuristic solution: objective 10315.370000
# Found heuristic solution: objective 10312.970000
#
# Root relaxation: objective 9.948140e+03, 3612 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9948.1400000 9948.14000  0.00%     -    0s
#
# Explored 1 nodes (3612 simplex iterations) in 0.52 seconds (0.42 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 9948.14 10313 10315.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.948139999999e+03, best bound 9.948139999999e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116010 columns and 501188 nonzeros
# Model fingerprint: 0x2bb99e9a
# Variable types: 99120 continuous, 16890 integer (16890 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96136 rows and 91901 columns
# Presolve time: 0.15s
# Presolved: 5224 rows, 24109 columns, 93274 nonzeros
# Variable types: 7259 continuous, 16850 integer (16850 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.25 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101140 rows, 115875 columns and 493983 nonzeros
# Model fingerprint: 0x3e88af20
# Variable types: 99120 continuous, 16755 integer (16755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91896 columns
# Presolve time: 0.16s
# Presolved: 4979 rows, 23979 columns, 86194 nonzeros
# Variable types: 7259 continuous, 16720 integer (16720 binary)
# Found heuristic solution: objective 10342.800000
#
# Root relaxation: objective 1.002789e+04, 3309 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    10027.890000 10027.8900  0.00%     -    0s
#
# Explored 1 nodes (3851 simplex iterations) in 0.50 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 10027.9 10342.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.002789000000e+04, best bound 1.002789000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116010 columns and 501188 nonzeros
# Model fingerprint: 0x2bb99e9a
# Variable types: 99120 continuous, 16890 integer (16890 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96136 rows and 91901 columns
# Presolve time: 0.15s
# Presolved: 5224 rows, 24109 columns, 93274 nonzeros
# Variable types: 7259 continuous, 16850 integer (16850 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.26 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116010 columns and 501188 nonzeros
# Model fingerprint: 0x2bb99e9a
# Variable types: 99120 continuous, 16890 integer (16890 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96136 rows and 91901 columns
# Presolve time: 0.17s
# Presolved: 5224 rows, 24109 columns, 93274 nonzeros
# Variable types: 7259 continuous, 16850 integer (16850 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.28 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101300 rows, 115960 columns and 499088 nonzeros
# Model fingerprint: 0xd46de83b
# Variable types: 99120 continuous, 16840 integer (16840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91901 columns
# Presolve time: 0.14s
# Presolved: 5139 rows, 24059 columns, 91134 nonzeros
# Variable types: 6822 continuous, 17237 integer (16800 binary)
# Found heuristic solution: objective 11408.188889
# Found heuristic solution: objective 11405.522222
#
# ...
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 28405 rows and 29654 columns
# Presolve time: 0.24s
# Presolved: 655 rows, 2026 columns, 5791 nonzeros
# Variable types: 691 continuous, 1335 integer (1320 binary)
# Found heuristic solution: objective 41509.544751
#
# Root relaxation: objective 4.134507e+04, 1569 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    41345.066203 41345.0662  0.00%     -    0s
#
# Explored 1 nodes (1569 simplex iterations) in 0.31 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 41345.1 41509.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.134506620289e+04, best bound 4.134506620289e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28550 rows, 31390 columns and 169985 nonzeros
# Model fingerprint: 0xefbfbd6b
# Variable types: 26880 continuous, 4510 integer (4510 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28550 rows, 31390 columns and 169885 nonzeros
# Model fingerprint: 0x9907a71c
# Variable types: 26880 continuous, 4510 integer (4510 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28600 rows, 31420 columns and 170690 nonzeros
# Model fingerprint: 0xbf8dbe07
# Variable types: 26880 continuous, 4540 integer (4540 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28600 rows, 31420 columns and 170690 nonzeros
# Model fingerprint: 0xbf8dbe07
# Variable types: 26880 continuous, 4540 integer (4540 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29060 rows, 31680 columns and 176140 nonzeros
# Model fingerprint: 0x74b63533
# Variable types: 26880 continuous, 4800 integer (4800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 28405 rows and 29654 columns
# Presolve time: 0.24s
# Presolved: 655 rows, 2026 columns, 5791 nonzeros
# Variable types: 691 continuous, 1335 integer (1320 binary)
# Found heuristic solution: objective 46068.383056
#
# Root relaxation: objective 4.588563e+04, 1471 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    45885.629114 45885.6291  0.00%     -    0s
#
# Explored 1 nodes (1471 simplex iterations) in 0.31 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 45885.6 46068.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.588562911432e+04, best bound 4.588562911432e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28550 rows, 31390 columns and 169985 nonzeros
# Model fingerprint: 0x5073da27
# Variable types: 26880 continuous, 4510 integer (4510 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28550 rows, 31390 columns and 169885 nonzeros
# Model fingerprint: 0xd40da240
# Variable types: 26880 continuous, 4510 integer (4510 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28600 rows, 31420 columns and 170690 nonzeros
# Model fingerprint: 0x55d9f269
# Variable types: 26880 continuous, 4540 integer (4540 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28600 rows, 31420 columns and 170690 nonzeros
# Model fingerprint: 0x55d9f269
# Variable types: 26880 continuous, 4540 integer (4540 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29060 rows, 31680 columns and 176140 nonzeros
# Model fingerprint: 0x07bd1646
# Variable types: 26880 continuous, 4800 integer (4800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 28405 rows and 29654 columns
# Presolve time: 0.20s
# Presolved: 655 rows, 2026 columns, 5791 nonzeros
# Variable types: 691 continuous, 1335 integer (1320 binary)
# Found heuristic solution: objective 57465.478821
#
# Root relaxation: objective 5.723704e+04, 1354 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    57237.036393 57237.0364  0.00%     -    0s
#
# Explored 1 nodes (1354 simplex iterations) in 0.26 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 57237 57465.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.723703639290e+04, best bound 5.723703639290e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28600 rows, 31420 columns and 170490 nonzeros
# Model fingerprint: 0x9b44e8e3
# Variable types: 26880 continuous, 4540 integer (4540 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28550 rows, 31390 columns and 169885 nonzeros
# Model fingerprint: 0xd1a5b603
# Variable types: 26880 continuous, 4510 integer (4510 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28650 rows, 31450 columns and 171195 nonzeros
# Model fingerprint: 0x824fa888
# Variable types: 26880 continuous, 4570 integer (4570 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 70 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28650 rows, 31450 columns and 171195 nonzeros
# Model fingerprint: 0x824fa888
# Variable types: 26880 continuous, 4570 integer (4570 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 70 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
df_results = pd.concat(list_results, ignore_index = True)
df_results.drop(columns = ['wage_costs','objective_value_post_wage'], inplace = True)
df_results.sort_values(by = ['city','demand_baseline','model','outsourcing_cost_multiplier'], inplace = True)

df_results.to_csv(r'../rostering_results/results_cm.csv', index = False)

# %%
df_results = pd.concat(list_results, ignore_index = True)
df_results.drop(columns = ['wage_costs','objective_value_post_wage'], inplace = True)
df_results.sort_values(by = ['city','demand_baseline','model','outsourcing_cost_multiplier'], inplace = True)

df_results.to_excel(r'../rostering_results/results_cm.xlsx', index = False)

# %% [markdown]
# - Import results back in and tie out

# %%
df_cm = pd.read_csv(r'../rostering_results/results_cm.csv')
df_cm.rename(columns = {'outsourcing_cost_multiplier':'OC'}, inplace = True)
df_cm = df_cm[['city','model','demand_baseline','OC','objective_value']]
df_cm.head()
# Out:
#      city  model  demand_baseline   OC  objective_value
# 0  berlin  fixed              0.5  1.2          3276.60
# 1  berlin  fixed              0.5  1.5          3975.75
# 2  berlin  fixed              0.5  1.8          4674.90
# 3  berlin  fixed              0.5  2.0          5141.00
# 4  berlin  fixed              0.5  2.5          6306.25

# %%
list_jonny = []

for file_in in os.listdir(r'../rostering_results'):
    if 'jonny' in file_in:
        # print(file_in)
        df_ = pd.read_csv(f'../rostering_results/{file_in}')
        split_ = file_in.split('_')
        df_['city'] = split_[0]
        df_['demand_baseline'] = pd.to_numeric(split_[1].split('=')[1])
        df_['OC'] = pd.to_numeric(split_[4].split('=')[1])
        df_ = df_[['city','model','shift_type','demand_baseline','OC','obj_value']]
        list_jonny.append(df_)

df_jonny = pd.concat(list_jonny, ignore_index = True)
df_jonny['shift_type'] = df_jonny['shift_type'].str.replace('3','').str.strip()
df_jonny = df_jonny[df_jonny['model']=='roster']
df_jonny.drop(columns = ['model'], inplace = True)
df_jonny.rename(columns = {'shift_type':'model'}, inplace = True)
df_jonny.sort_values(by = ['city','model'], inplace = True)
df_jonny.head()
# Out:
#          city     model  demand_baseline   OC    obj_value
# 13     berlin     fixed              1.0  1.5  8370.116667
# 3      berlin  partflex              1.0  1.5  9381.550000
# 11  frankfurt     fixed              1.0  1.5  4224.500000
# 7   frankfurt  partflex              1.0  1.5  4943.000000
# 1        lyon     fixed              1.0  1.5  7032.120437

# %%
#compare

df_compare = df_jonny.merge(df_cm, how = 'left', on = ['city','model','demand_baseline','OC'])
df_compare['diff'] = (df_compare['obj_value']-df_compare['objective_value']).abs().round(4)
df_compare
# Out:
#          city     model  demand_baseline   OC     obj_value  objective_value  \
# 0      berlin     fixed              1.0  1.5   8370.116667      8370.116667
# 1      berlin  partflex              1.0  1.5   9381.550000              NaN
# 2      berlin  partflex              1.0  1.5   9381.550000              NaN
# 3      berlin  partflex              1.0  1.5   9381.550000              NaN
# 4   frankfurt     fixed              1.0  1.5   4224.500000      4224.500000
# 5   frankfurt  partflex              1.0  1.5   4943.000000              NaN
# 6   frankfurt  partflex              1.0  1.5   4943.000000              NaN
# 7   frankfurt  partflex              1.0  1.5   4943.000000              NaN
# 8        lyon     fixed              1.0  1.5   7032.120437      7032.120437
# 9        lyon  partflex              1.0  1.5   7585.464980              NaN
# 10       lyon  partflex              1.0  1.5   7585.464980              NaN
# 11       lyon  partflex              1.0  1.5   7585.464980              NaN
# 12      paris     fixed              1.0  1.5  20846.517649     20846.517649
# 13      paris  partflex              1.0  1.5  21607.642758              NaN
# 14      paris  partflex              1.0  1.5  21607.642758              NaN
# 15      paris  partflex              1.0  1.5  21607.642758              NaN
#
#     diff
# 0    0.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    0.0
# 5    NaN
# 6    NaN
# 7    NaN
# 8    0.0
# 9    NaN
# 10   NaN
# 11   NaN
# 12   0.0
# 13   NaN
# 14   NaN
# 15   NaN
