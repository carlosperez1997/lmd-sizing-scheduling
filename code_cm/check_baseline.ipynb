# %% [markdown]
# Code used to create result file for tying out decision variable, objective function and constraint code.

# %%
from glob import glob
from os import path
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval_w_baseline
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#get the distinct list of city and demand type combinations

list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=1.00', 'paris_db=1.00', 'berlin_db=2.00', 'frankfurt_db=2.00', 'lyon_db=0.50', 'frankfurt_db=4.00', 'paris_db=2.00', 'frankfurt_db=0.50', 'paris_db=4.00', 'frankfurt_db=1.00', 'berlin_db=4.00', 'lyon_db=2.00', 'paris_db=0.50', 'berlin_db=0.50', 'lyon_db=4.00', 'lyon_db=1.00']
# 16

# %%
#create a dataframe that can hold all result information

list_results = []

workforce_dict = {0:5, 1:5, 2:5, 3:5, 4:5}
RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

# for base_file in list_city_dt:
for base_file in ['berlin_db=1.00']:
    weekday_ = f'{base_file}_dt=doublepeak.json'
    weekend_ = f'{base_file}_dt=uniform.json'

    instance_file_weekday = f"../instances/{weekday_}"
    instance_file_weekend = f"../instances/{weekend_}"

    shift_file_weekday = f"../shifts/{weekday_}"
    shift_file_weekend = f"../shifts/{weekend_}"
    
    # for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
    for OC in [1.5]:
        model = 'fixed'
        dict_baseline, dict_results = run_roster_solver_objval_w_baseline(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
        df_ = pd.DataFrame(dict_baseline)
        df_['calc'] = 'baseline'
        list_results.append(df_)
        df_ = pd.DataFrame(dict_results)
        df_['calc'] = 'roster'
        list_results.append(df_)

        model = 'flex'
        dict_baseline, dict_results = run_roster_solver_objval_w_baseline(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
        df_ = pd.DataFrame(dict_baseline)
        df_['calc'] = 'baseline'
        list_results.append(df_)
        df_ = pd.DataFrame(dict_results)
        df_['calc'] = 'roster'
        list_results.append(df_)

        model = 'partflex'
        for max_n_shifts in range(2,5):            
            dict_baseline, dict_results = run_roster_solver_objval_w_baseline(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
            df_ = pd.DataFrame(dict_baseline)
            df_['calc'] = 'baseline'
            list_results.append(df_)
            df_ = pd.DataFrame(dict_results)
            df_['calc'] = 'roster'
            list_results.append(df_)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100380 rows, 115640 columns and 463768 nonzeros
# Model fingerprint: 0x19225bc0
# Variable types: 99120 continuous, 16520 integer (16520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 9763.6000000
# Presolve removed 92862 rows and 92498 columns
# Presolve time: 0.17s
# Presolved: 7518 rows, 23142 columns, 49052 nonzeros
# Variable types: 9825 continuous, 13317 integer (12955 binary)
# Found heuristic solution: objective 7664.8416667
#
# Root relaxation: objective 7.572142e+03, 208 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7572.1416667 7572.14167  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.35 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7572.14 7664.84 9763.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.572141666666e+03, best bound 7.572141666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101300 rows, 115960 columns and 499088 nonzeros
# Model fingerprint: 0x3b58eb85
# Variable types: 99120 continuous, 16840 integer (16840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91901 columns
# Presolve time: 0.17s
# Presolved: 5139 rows, 24059 columns, 91134 nonzeros
# Variable types: 7254 continuous, 16805 integer (16800 binary)
# Found heuristic solution: objective 8648.4916667
#
# Root relaxation: objective 8.370117e+03, 3582 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8370.1166667 8370.11667  0.00%     -    0s
#
# Explored 1 nodes (3582 simplex iterations) in 0.57 seconds (0.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8370.12 8648.49
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.370116666666e+03, best bound 8.370116666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100380 rows, 115640 columns and 463768 nonzeros
# Model fingerprint: 0x19225bc0
# Variable types: 99120 continuous, 16520 integer (16520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 9763.6000000
# Presolve removed 92862 rows and 92498 columns
# Presolve time: 0.15s
# Presolved: 7518 rows, 23142 columns, 49052 nonzeros
# Variable types: 9825 continuous, 13317 integer (12955 binary)
# Found heuristic solution: objective 7664.8416667
#
# Root relaxation: objective 7.572142e+03, 208 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7572.1416667 7572.14167  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.32 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7572.14 7664.84 9763.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.572141666666e+03, best bound 7.572141666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101400 rows, 116035 columns and 502713 nonzeros
# Model fingerprint: 0xb9c5099d
# Variable types: 99120 continuous, 16915 integer (16915 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.19s
# Presolved: 5364 rows, 24149 columns, 94964 nonzeros
# Variable types: 7254 continuous, 16895 integer (16890 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.32 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100380 rows, 115640 columns and 463768 nonzeros
# Model fingerprint: 0x19225bc0
# Variable types: 99120 continuous, 16520 integer (16520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 9763.6000000
# Presolve removed 92862 rows and 92498 columns
# Presolve time: 0.19s
# Presolved: 7518 rows, 23142 columns, 49052 nonzeros
# Variable types: 9825 continuous, 13317 integer (12955 binary)
# Found heuristic solution: objective 7664.8416667
#
# Root relaxation: objective 7.572142e+03, 208 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7572.1416667 7572.14167  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.36 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7572.14 7664.84 9763.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.572141666666e+03, best bound 7.572141666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101140 rows, 115875 columns and 493983 nonzeros
# Model fingerprint: 0x6f2aa4f1
# Variable types: 99120 continuous, 16755 integer (16755 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96161 rows and 91896 columns
# Presolve time: 0.16s
# Presolved: 4979 rows, 23979 columns, 86194 nonzeros
# Variable types: 7254 continuous, 16725 integer (16720 binary)
# Found heuristic solution: objective 8671.3500000
#
# Root relaxation: objective 8.436575e+03, 3011 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8436.5750000 8436.57500  0.00%     -    0s
#
# Explored 1 nodes (3011 simplex iterations) in 0.54 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8436.58 8671.35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.436575000000e+03, best bound 8.436575000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100380 rows, 115640 columns and 463768 nonzeros
# Model fingerprint: 0x19225bc0
# Variable types: 99120 continuous, 16520 integer (16520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 9763.6000000
# Presolve removed 92862 rows and 92498 columns
# Presolve time: 0.21s
# Presolved: 7518 rows, 23142 columns, 49052 nonzeros
# Variable types: 9825 continuous, 13317 integer (12955 binary)
# Found heuristic solution: objective 7664.8416667
#
# Root relaxation: objective 7.572142e+03, 208 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7572.1416667 7572.14167  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.41 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7572.14 7664.84 9763.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.572141666666e+03, best bound 7.572141666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101360 rows, 116005 columns and 501263 nonzeros
# Model fingerprint: 0x8efc5cd6
# Variable types: 99120 continuous, 16885 integer (16885 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96211 rows and 91916 columns
# Presolve time: 0.19s
# Presolved: 5149 rows, 24089 columns, 93184 nonzeros
# Variable types: 7254 continuous, 16835 integer (16830 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.33 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100380 rows, 115640 columns and 463768 nonzeros
# Model fingerprint: 0x19225bc0
# Variable types: 99120 continuous, 16520 integer (16520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 9763.6000000
# Presolve removed 92862 rows and 92498 columns
# Presolve time: 0.16s
# Presolved: 7518 rows, 23142 columns, 49052 nonzeros
# Variable types: 9825 continuous, 13317 integer (12955 binary)
# Found heuristic solution: objective 7664.8416667
#
# Root relaxation: objective 7.572142e+03, 208 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7572.1416667 7572.14167  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.35 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7572.14 7664.84 9763.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.572141666666e+03, best bound 7.572141666666e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101380 rows, 116025 columns and 502153 nonzeros
# Model fingerprint: 0x3c0421c6
# Variable types: 99120 continuous, 16905 integer (16905 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 96036 rows and 91886 columns
# Presolve time: 0.22s
# Presolved: 5344 rows, 24139 columns, 94424 nonzeros
# Variable types: 7254 continuous, 16885 integer (16880 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.35 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
df_results = pd.concat(list_results, ignore_index = True)
df_results.drop(columns = ['wage_costs','objective_value_post_wage'], inplace = True)
df_results.sort_values(by = ['city','demand_baseline','model','outsourcing_cost_multiplier'], inplace = True)

df_results.to_excel(r'../rostering_results/results_cm_w_baseline.xlsx', index = False)
