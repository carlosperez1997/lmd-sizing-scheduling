# %%
from glob import glob
from os import path
import seaborn as sns
import json
import os
import numpy as np
import pandas as pd
import re
from os.path import basename, splitext
import time
import pickle
import json
from datetime import datetime

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering_new_baseline import run_baseline_solver_output

# %%
def load_shift(shift_file, OC, RM, GM, model, max_n_shifts = None):
    with open(shift_file, 'r') as file:
        data = json.load(file)
        df_shifts = pd.DataFrame(data)
    df_shifts = df_shifts[(df_shifts['outsourcing_cost_multiplier']==OC)&(df_shifts['regional_multiplier']==RM)&(df_shifts['global_multiplier']==GM)]
    #fixed or flex
    if model in ['fixed','flex']:
        df_shifts = df_shifts[df_shifts['model']==model]
    #partflex
    else:
        df_shifts = df_shifts[(df_shifts['model']==model)&(df_shifts['max_n_shifts']==max_n_shifts)]
    df_shifts.reset_index(drop = True, inplace=True)
    df_shifts = df_shifts[['region','shifts_start']]
    dict_shifts = {}
    for region in df_shifts['region'].unique().tolist():
        dict_shifts[region] = []
        dict_ = df_shifts[df_shifts['region']==region]['shifts_start'].tolist()[0]
        for shift_start in dict_.keys():
            dict_shifts[region].append(dict_[shift_start])
    return dict_shifts

# %%
def create_run_dictionary(base_file, OC, RM, GM):

    #create inputs to run a trial workforce size
    weekday_ = f'{base_file}_dt=doublepeak.json'
    weekend_ = f'{base_file}_dt=uniform.json'

    shift_file_weekday = f"../shifts/{weekday_}"
    shift_file_weekend = f"../shifts/{weekend_}"

    #load all shifts
    dict_weekday = {}
    dict_weekend = {}
    dict_track = {}
    dict_opt = {}
    for model in ['fixed','flex','partflex']:
        if model == 'partflex':
            for max_n_shifts in range(2,5):
                dict_ = load_shift(shift_file_weekday, OC, RM, GM, model, max_n_shifts)
                dict_weekday[(model, max_n_shifts)] = dict_
                dict_ = load_shift(shift_file_weekend, OC, RM, GM, model, max_n_shifts)
                dict_weekend[(model, max_n_shifts)] = dict_
                dict_track[(model, max_n_shifts)] = []
                dict_opt[(model, max_n_shifts)] = 0
        else:
            dict_ = load_shift(shift_file_weekday, OC, RM, GM, model, max_n_shifts = None)
            dict_weekday[(model, None)] = dict_
            dict_ = load_shift(shift_file_weekend, OC, RM, GM, model, max_n_shifts = None)
            dict_weekend[(model, None)] = dict_
            dict_track[(model, None)] = []
            dict_opt[(model, None)] = 0

    #create a dictionary of distinct list of (model, max_n_shifts) that are the same

    list_models = [('fixed', None),('flex', None),('partflex',2),('partflex',3),('partflex',4)]
    list_ran = []
    for comb in list_models:
        list_ = list_models.copy()
        list_.remove(comb)
        for other_comb in list_:
            if (dict_weekday[comb]==dict_weekday[other_comb])&(dict_weekend[comb]==dict_weekend[other_comb])&(comb not in list_ran):
                dict_track[comb].append(other_comb)
                list_ran.append(other_comb)

    list_rmv = []
    for comb in dict_track.keys():
        ind_ = 0
        for comb_ in dict_track.keys():
            if comb in dict_track[comb_]:
                ind_ = 1

        if (dict_track[comb] == [])&(ind_ == 1):
            list_rmv.append(comb)
    for comb in list_rmv:
        del dict_track[comb]

    return dict_track

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()

#remove berlin
val_rmv = []
for val in list_city_dt:
    if val.find('berlin') > -1:
        val_rmv.append(val)
for val in val_rmv:
    list_city_dt.remove(val)

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('paris') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt)
# print(list_city_dt_subset)
# Out:
# ['frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']

# %%
RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

# for base_file in list_city_dt:
for base_file in ['lyon_db=0.50']:

    #create inputs to run a trial workforce size
    weekday_ = f'{base_file}_dt=doublepeak.json'
    weekend_ = f'{base_file}_dt=uniform.json'

    instance_file_weekday = f"../instances/{weekday_}"
    instance_file_weekend = f"../instances/{weekend_}"

    shift_file_weekday = f"../shifts/{weekday_}"
    shift_file_weekend = f"../shifts/{weekend_}"

    workforce_dict = {}

    city_pattern = r'(\w+)_db'
    db_pattern = r'db=(\d+\.\d+)'

    city_match = re.search(city_pattern, base_file)
    db_match = re.search(db_pattern, base_file)

    city = city_match.group(1) if city_match else None
    demand_baseline = float(db_match.group(1)) if db_match else None

    for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
    # for OC in [1.2]:

        #run only over distinct shift combinations (avoiding duplicates but still keeping track)

        dict_run = create_run_dictionary(base_file, OC, RM, GM)
        print(f'dict_run: {dict_run}')

        dict_str = {}
        for key in dict_run.keys():
            key_str = f'{key[0]}-{key[1]}'
            dict_str[key_str] = []
            for val in dict_run[key]:
                val_str = f'{val[0]}-{val[1]}'
                dict_str[key_str].append(val_str)

        for comb in dict_run.keys():
            model = comb[0]
            max_n_shifts = comb[1]

            if max_n_shifts == None:
                results_file = f"{base_file}_OC={OC}_model={model}.pkl"
            else:
                results_file = f"{base_file}_OC={OC}_model={model}_max_n_shifts={max_n_shifts}.pkl"

            if results_file not in os.listdir(r'../rerun_baseline'):

                start_time = time.time()
                print(f'start_time: {datetime.fromtimestamp(start_time)}')
                dict_baseline = \
                    run_baseline_solver_output(model, instance_file_weekday, 
                                                        shift_file_weekday, instance_file_weekend, 
                                                        shift_file_weekend, workforce_dict, 
                                                        OC, RM, GM, h_min, h_max, max_n_diff, 
                                                        max_n_shifts, expand_workforce_to_regions=True)
                
                dict_baseline['dict_run'] = dict_run
                end_time = time.time()
                run_time = (end_time - start_time)
                dict_baseline['run_time'] = run_time

                # Save results
                with open(f'../rerun_baseline/{results_file}', 'wb') as file:
                    pickle.dump(dict_baseline, file)
                print(f'Base: {base_file}, OC: {OC}, model: {model}-{max_n_shifts}, run_time: {run_time}')

                for subcomb in dict_run[comb]:
                    if subcomb[1] == None:
                        results_file_ = f"{base_file}_OC={OC}_model={subcomb[0]}.pkl"
                    else:
                        results_file_ = f"{base_file}_OC={OC}_model={subcomb[0]}_max_n_shifts={subcomb[1]}.pkl"

                    with open(f'../rerun_baseline/{results_file_}', 'wb') as file:
                        pickle.dump(dict_baseline, file)

            else:
                for subcomb in dict_run[comb]:
                    dict_baseline = pd.read_pickle(f'../rerun_baseline/{results_file}')
                    if subcomb[1] == None:
                        results_file_ = f"{base_file}_OC={OC}_model={subcomb[0]}.pkl"
                    else:
                        results_file_ = f"{base_file}_OC={OC}_model={subcomb[0]}_max_n_shifts={subcomb[1]}.pkl"

                    with open(f'../rerun_baseline/{results_file_}', 'wb') as file:
                        pickle.dump(dict_baseline, file)
# Out:
# dict_run: {('fixed', None): [], ('flex', None): [('partflex', 3), ('partflex', 4)], ('partflex', 2): []}
# start_time: 2024-06-05 12:21:54.155328
# Base: frankfurt_db=0.50, OC: 1.2, model: fixed-None, run_time: 4.325312376022339
# start_time: 2024-06-05 12:21:58.483006
# Base: frankfurt_db=0.50, OC: 1.2, model: flex-None, run_time: 3.9539988040924072
# start_time: 2024-06-05 12:22:02.444994
# Base: frankfurt_db=0.50, OC: 1.2, model: partflex-2, run_time: 4.633356332778931
# dict_run: {('fixed', None): [], ('flex', None): [('partflex', 3), ('partflex', 4)], ('partflex', 2): []}
# start_time: 2024-06-05 12:22:07.112290
# Base: frankfurt_db=0.50, OC: 1.5, model: fixed-None, run_time: 5.3230719566345215
# start_time: 2024-06-05 12:22:12.437125
# Base: frankfurt_db=0.50, OC: 1.5, model: flex-None, run_time: 4.775463581085205
# start_time: 2024-06-05 12:22:17.217322
# Base: frankfurt_db=0.50, OC: 1.5, model: partflex-2, run_time: 5.220911026000977
# dict_run: {('fixed', None): [], ('flex', None): [], ('partflex', 2): [], ('partflex', 3): [('partflex', 4)]}
# start_time: 2024-06-05 12:22:22.473467
# Base: frankfurt_db=0.50, OC: 1.8, model: fixed-None, run_time: 6.413700580596924
# start_time: 2024-06-05 12:22:28.888944
# Base: frankfurt_db=0.50, OC: 1.8, model: flex-None, run_time: 5.401766538619995
# start_time: 2024-06-05 12:22:34.292404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 61
#      58 start_time = time.time()
#      59 print(f'start_time: {datetime.fromtimestamp(start_time)}')
#      60 dict_baseline = \
# ---> 61     run_baseline_solver_output(model, instance_file_weekday,
#      62                                         shift_file_weekday, instance_file_weekend,
#      63                                         shift_file_weekend, workforce_dict,
#      64                                         OC, RM, GM, h_min, h_max, max_n_diff,
#      65                                         max_n_shifts, expand_workforce_to_regions=True)
#      67 dict_baseline['dict_run'] = dict_run
#      68 end_time = time.time()
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering_new_baseline.py:877, in run_baseline_solver_output(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, outsourcing_cost_multiplier, regional_multiplier, global_multiplier, h_min, h_max, max_n_diff, max_n_shifts, expand_workforce_to_regions)
#     874 i = Instance(args=args)
#     875 solver = Solver(args=args, i=i)
# --> 877 baseline_results = solver.solve_baseline_objval()
#     879 return baseline_results
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering_new_baseline.py:749, in Solver.solve_baseline_objval(self)
#     748 def solve_baseline_objval(self) -> dict:
# --> 749     self.__build_baseline_model()
#     750     self.m.setParam("OutputFlag", 0) # No logs
#     751     self.m.optimize()
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering_new_baseline.py:428, in Solver.__build_baseline_model(self)
#     416 self.m.addConstrs((
#     417     sum(self.k[(employee, area, theta, day)]
#     418         for area in self.i.reg_areas[region]
#    (...)
#     424         for day in self.i.days
#     425 ), name = 'specific_periods_per_day')
#     427 #constraint - demand can be met by outsourcing
# --> 428 self.m.addConstrs(
#     429     (
#     430         self.i.srequired[(scenario, area, theta, day)] * self.omega[(scenario, area, theta, day)] >= \
#     431         (self.i.srequired[(scenario, area, theta, day)] -
#     432         sum(
#     433             self.k[(employee, area, theta, day)]
#     434             for employee in self.i.employees[region]
#     435         )) * self.i.sdemand[(scenario, area, theta, day)] * self.i.outsourcing_cost
#     436
#     437         for region in self.i.regions
#     438         for area in self.i.reg_areas[region]
#     439         for day in self.i.days
#     440         for theta in self.i.periods[day]
#     441         for scenario in self.i.scenarios[day]
#     442     ), name='outsourcing_demand'
#     443 )
#     445 # constraint - ensuring employees work whole of shift
#     446 self.m.addConstrs((
#     447     sum(
#     448         self.k[(employee, area, theta, day)]
#    (...)
#     455     for theta in self.i.periods[day]
#     456 ), name='baseline_works_a_day')
#
# File src/gurobipy/model.pxi:3877, in gurobipy.Model.addConstrs()
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering_new_baseline.py:431, in <genexpr>(.0)
#     416 self.m.addConstrs((
#     417     sum(self.k[(employee, area, theta, day)]
#     418         for area in self.i.reg_areas[region]
#    (...)
#     424         for day in self.i.days
#     425 ), name = 'specific_periods_per_day')
#     427 #constraint - demand can be met by outsourcing
#     428 self.m.addConstrs(
#     429     (
#     430         self.i.srequired[(scenario, area, theta, day)] * self.omega[(scenario, area, theta, day)] >= \
# --> 431         (self.i.srequired[(scenario, area, theta, day)] -
#     432         sum(
#     433             self.k[(employee, area, theta, day)]
#     434             for employee in self.i.employees[region]
#     435         )) * self.i.sdemand[(scenario, area, theta, day)] * self.i.outsourcing_cost
#     436
#     437         for region in self.i.regions
#     438         for area in self.i.reg_areas[region]
#     439         for day in self.i.days
#     440         for theta in self.i.periods[day]
#     441         for scenario in self.i.scenarios[day]
#     442     ), name='outsourcing_demand'
#     443 )
#     445 # constraint - ensuring employees work whole of shift
#     446 self.m.addConstrs((
#     447     sum(
#     448         self.k[(employee, area, theta, day)]
#    (...)
#     455     for theta in self.i.periods[day]
#     456 ), name='baseline_works_a_day')
#
# File src/gurobipy/linexpr.pxi:542, in gurobipy.LinExpr.__mul__()
#
# File src/gurobipy/linexpr.pxi:48, in gurobipy.LinExpr.__init__()
#
# File /usr/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
