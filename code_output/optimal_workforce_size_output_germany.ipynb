# %%
from glob import glob
from os import path
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']
# 16

# %%
#Subset to Germany

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('berlin') > -1)|(city_db.find('frank') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt_subset)
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00']

# %%
def dict_append_workforce(dict_, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, workforce_size, objvalprev, objval, objvalnext):
    dict_['instance_file_base'].append(base_file)
    dict_['city'].append(city)
    dict_['demand_baseline'].append(demand_baseline)
    dict_['model'].append(model)
    dict_['max_n_shifts'].append(max_n_shifts)
    dict_['outsourcing_cost_multiplier'].append(OC)
    dict_['regional_multiplier'].append(RM)
    dict_['global_multiplier'].append(GM)
    dict_['workforce_size_region0'].append(workforce_size)
    dict_['objective_value_prev'].append(objvalprev)
    dict_['objective_value'].append(objval)
    dict_['objective_value_next'].append(objvalnext)
    return dict_

# %%
#Code that determines optimal workforce size

MAX_TRIES = 200

RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

for base_file in list_city_dt_subset:
# for base_file in ['berlin_db=1.00']:
    print(base_file+'============================================')

    if f'{base_file}.json' not in os.listdir(r'../workforce_size'):

        list_results = []

        #create inputs to run a trial workforce size
        weekday_ = f'{base_file}_dt=doublepeak.json'
        weekend_ = f'{base_file}_dt=uniform.json'

        instance_file_weekday = f"../instances/{weekday_}"
        instance_file_weekend = f"../instances/{weekend_}"

        shift_file_weekday = f"../shifts/{weekday_}"
        shift_file_weekend = f"../shifts/{weekend_}"

        #create dictionary for evaluating optimal workforce size
        workforce_out = f"../workforce_size/{base_file}.json"
        dict_out = {
            'instance_file_base':[],
            'city':[],
            'demand_baseline':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'workforce_size_region0':[],
            'objective_value_prev':[],
            'objective_value':[],
            'objective_value_next':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'

        city_match = re.search(city_pattern, base_file)
        db_match = re.search(db_pattern, base_file)

        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None

        #Set min_tries based on demand_baseline
        if demand_baseline == 0.5:
            MIN_TRIES = 5
        elif demand_baseline == 1.0:
            MIN_TRIES = 15
        elif demand_baseline == 2.0:
            MIN_TRIES = 25
        elif demand_baseline == 4.0:
            MIN_TRIES = 70

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
        # for OC in [1.2]:
            print(f'OC = {OC}++++++++++++++++++++++')
            for model in ['fixed', 'flex', 'partflex']:
            # for model in ['fixed']:
                print(f'model = {model}-------------------------')
                if model == 'partflex':
                    for max_n_shifts in range(2,5):
                    # for max_n_shifts in [4]:
                        objvalprev = 1e8
                        objval = 1e7
                        for trial_size in range(MIN_TRIES, MAX_TRIES):
                            workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                            if (objval < objvalprev)&(np.isnan(objval) == False):
                                objvalprev = objval
                                dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
                                objval = dict_results['objective_value'][0]
                                print("trial_size",trial_size)
                                df_ = pd.DataFrame(dict_results)
                                df_['workforce_size_trial'] = trial_size
                                list_results.append(df_)
                            else:
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size-1, np.nan, objvalprev, objval)
                                break
                            if trial_size == int(MAX_TRIES-1):
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size, objvalprev, objval, np.nan)
                else:
                    objvalprev = 1e8
                    objval = 1e7
                    for trial_size in range(MIN_TRIES, MAX_TRIES):
                        workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                        if (objval < objvalprev)&(np.isnan(objval) == False):
                            objvalprev = objval
                            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
                            objval = dict_results['objective_value'][0]
                            print("trial_size",trial_size)
                            df_ = pd.DataFrame(dict_results)
                            df_['workforce_size_trial'] = trial_size
                            list_results.append(df_)
                        else: 
                            #keep track of optimal (trial size - 1)
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size-1, np.nan, objvalprev, objval)
                            break
                        if trial_size == int(MAX_TRIES-1):
                            #keep track of optimal
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size, objvalprev, objval, np.nan)
        #export optimal workforce size values
        with open(workforce_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
        df_trials = pd.concat(list_results, ignore_index = True)
        df_trials.to_excel(f'../workforce_size/{base_file}_all_trials.xlsx', index = False)
# Out:
# berlin_db=0.50============================================
# berlin_db=1.00============================================
# berlin_db=2.00============================================
# berlin_db=4.00============================================
# OC = 1.2++++++++++++++++++++++
# model = fixed-------------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110143 rows, 142232 columns and 1429807 nonzeros
# Model fingerprint: 0x3efea3a3
# Variable types: 99120 continuous, 43112 integer (43112 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99896 rows and 99325 columns
# Presolve time: 0.57s
# Presolved: 10247 rows, 42907 columns, 207197 nonzeros
# Found heuristic solution: objective 28765.652270
# Variable types: 2517 continuous, 40390 integer (40390 binary)
# Found heuristic solution: objective 28672.024270
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.738774e+04, 37622 iterations, 2.26 seconds (1.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27387.743127 27387.7431  0.00%     -    6s
#
# Explored 1 nodes (45876 simplex iterations) in 6.57 seconds (3.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27387.7 28672 28765.7 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.738774312698e+04, best bound 2.738774312698e+04, gap 0.0000%
# trial_size 70
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110294 rows, 142808 columns and 1447758 nonzeros
# Model fingerprint: 0x0201595c
# Variable types: 99120 continuous, 43688 integer (43688 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99912 rows and 99327 columns
# Presolve time: 0.58s
# Presolved: 10382 rows, 43481 columns, 210109 nonzeros
# Found heuristic solution: objective 28770.703889
# Variable types: 2517 continuous, 40964 integer (40964 binary)
# Found heuristic solution: objective 28681.099222
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.735558e+04, 38156 iterations, 2.74 seconds (1.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27355.583127 27355.5831  0.00%     -    7s
#
# Explored 1 nodes (47445 simplex iterations) in 7.69 seconds (4.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27355.6 28681.1 28770.7 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.735558312698e+04, best bound 2.735558312698e+04, gap 0.0000%
# trial_size 71
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110445 rows, 143384 columns and 1465709 nonzeros
# Model fingerprint: 0x8540d9f2
# Variable types: 99120 continuous, 44264 integer (44264 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99928 rows and 99329 columns
# Presolve time: 0.85s
# Presolved: 10517 rows, 44055 columns, 213021 nonzeros
# Found heuristic solution: objective 28717.809079
# Variable types: 2517 continuous, 41538 integer (41538 binary)
# Found heuristic solution: objective 28624.648032
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.732380e+04, 38861 iterations, 2.84 seconds (1.33 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27323.802556 27323.8026  0.00%     -    8s
#
# Explored 1 nodes (47600 simplex iterations) in 8.60 seconds (4.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27323.8 28624.6 28717.8 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.732380255555e+04, best bound 2.732380255555e+04, gap 0.0000%
# trial_size 72
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110596 rows, 143960 columns and 1483660 nonzeros
# Model fingerprint: 0x21a36587
# Variable types: 99120 continuous, 44840 integer (44840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99944 rows and 99331 columns
# Presolve time: 1.57s
# Presolved: 10652 rows, 44629 columns, 215933 nonzeros
# Found heuristic solution: objective 28674.655698
# Variable types: 2517 continuous, 42112 integer (42112 binary)
# Found heuristic solution: objective 28588.101889
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#     5596 PPushes remaining with PInf 0.0000000e+00                10s
#        0 PPushes remaining with PInf 0.0000000e+00                13s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.0968333e+02     13s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    39601    2.7292461e+04   0.000000e+00   6.096833e+02     13s
#    39759    2.7292461e+04   0.000000e+00   0.000000e+00     13s
#    39759    2.7292461e+04   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 2.729246e+04, 39759 iterations, 8.91 seconds (1.45 work units)
# Total elapsed time = 12.97s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27292.460841 27292.4608  0.00%     -   23s
#
# Explored 1 nodes (49483 simplex iterations) in 23.35 seconds (4.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27292.5 28588.1 28674.7 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.729246084127e+04, best bound 2.729246084127e+04, gap 0.0000%
# trial_size 73
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110747 rows, 144536 columns and 1501611 nonzeros
# Model fingerprint: 0x3598bb0d
# Variable types: 99120 continuous, 45416 integer (45416 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99960 rows and 99333 columns
# Presolve time: 0.52s
# Presolved: 10787 rows, 45203 columns, 218845 nonzeros
# Found heuristic solution: objective 28558.534651
# Variable types: 2517 continuous, 42686 integer (42686 binary)
# Found heuristic solution: objective 28471.980841
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.726203e+04, 40143 iterations, 2.54 seconds (1.44 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27262.034175 27262.0342  0.00%     -    6s
#
# Explored 1 nodes (50125 simplex iterations) in 6.98 seconds (4.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27262 28472 28558.5 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.726203417460e+04, best bound 2.726203417460e+04, gap 0.0000%
# trial_size 74
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110898 rows, 145112 columns and 1519562 nonzeros
# Model fingerprint: 0xc6d8bf8d
# Variable types: 99120 continuous, 45992 integer (45992 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99976 rows and 99335 columns
# Presolve time: 0.53s
# Presolved: 10922 rows, 45777 columns, 221757 nonzeros
# Found heuristic solution: objective 28570.005651
# Variable types: 2517 continuous, 43260 integer (43260 binary)
# Found heuristic solution: objective 28479.895460
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.723279e+04, 41251 iterations, 2.38 seconds (1.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27232.786556 27232.7866  0.00%     -    7s
#
# Explored 1 nodes (52829 simplex iterations) in 7.61 seconds (5.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27232.8 28479.9 28570 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.723278655555e+04, best bound 2.723278655555e+04, gap 0.0000%
# trial_size 75
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111049 rows, 145688 columns and 1537513 nonzeros
# Model fingerprint: 0x184fdb99
# Variable types: 99120 continuous, 46568 integer (46568 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 99992 rows and 99337 columns
# Presolve time: 0.53s
# Presolved: 11057 rows, 46351 columns, 224669 nonzeros
# Found heuristic solution: objective 28547.975222
# Variable types: 2517 continuous, 43834 integer (43834 binary)
# Found heuristic solution: objective 28461.408365
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.720749e+04, 41601 iterations, 2.47 seconds (1.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27207.486556 27207.4866  0.00%     -    7s
#
# Explored 1 nodes (51608 simplex iterations) in 7.54 seconds (5.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27207.5 28461.4 28548 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720748655555e+04, best bound 2.720748655555e+04, gap 0.0000%
# trial_size 76
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111200 rows, 146264 columns and 1555464 nonzeros
# Model fingerprint: 0xcbab2940
# Variable types: 99120 continuous, 47144 integer (47144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100008 rows and 99339 columns
# Presolve time: 0.57s
# Presolved: 11192 rows, 46925 columns, 227581 nonzeros
# Found heuristic solution: objective 28524.985937
# Variable types: 2517 continuous, 44408 integer (44408 binary)
# Found heuristic solution: objective 28431.370984
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.718283e+04, 41738 iterations, 2.66 seconds (1.48 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27182.833889 27182.8339  0.00%     -    7s
#
# Explored 1 nodes (52660 simplex iterations) in 8.04 seconds (5.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27182.8 28431.4 28525 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.718283388889e+04, best bound 2.718283388889e+04, gap 0.0000%
# trial_size 77
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111351 rows, 146840 columns and 1573415 nonzeros
# Model fingerprint: 0xa0027193
# Variable types: 99120 continuous, 47720 integer (47720 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100024 rows and 99341 columns
# Presolve time: 0.53s
# Presolved: 11327 rows, 47499 columns, 230493 nonzeros
# Found heuristic solution: objective 28469.112841
# Variable types: 2517 continuous, 44982 integer (44982 binary)
# Found heuristic solution: objective 28383.013508
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.715887e+04, 42300 iterations, 2.32 seconds (1.40 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27158.865889 27158.8659  0.00%     -    7s
#
# Explored 1 nodes (53367 simplex iterations) in 7.82 seconds (5.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27158.9 28383 28469.1 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.715886588889e+04, best bound 2.715886588889e+04, gap 0.0000%
# trial_size 78
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111502 rows, 147416 columns and 1591366 nonzeros
# Model fingerprint: 0x740a63b7
# Variable types: 99120 continuous, 48296 integer (48296 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100040 rows and 99343 columns
# Presolve time: 0.83s
# Presolved: 11462 rows, 48073 columns, 233405 nonzeros
# Found heuristic solution: objective 28472.366127
# Variable types: 2517 continuous, 45556 integer (45556 binary)
# Found heuristic solution: objective 28382.268984
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.713628e+04, 42468 iterations, 2.78 seconds (1.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27136.276365 27136.2764  0.00%     -    8s
#
# Explored 1 nodes (54798 simplex iterations) in 9.08 seconds (6.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27136.3 28382.3 28472.4 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.713627636508e+04, best bound 2.713627636508e+04, gap 0.0000%
# trial_size 79
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111653 rows, 147992 columns and 1609317 nonzeros
# Model fingerprint: 0x915c066a
# Variable types: 99120 continuous, 48872 integer (48872 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100056 rows and 99345 columns
# Presolve time: 0.58s
# Presolved: 11597 rows, 48647 columns, 236317 nonzeros
# Found heuristic solution: objective 28417.943127
# Variable types: 2517 continuous, 46130 integer (46130 binary)
# Found heuristic solution: objective 28320.771794
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.711521e+04, 43385 iterations, 3.50 seconds (1.78 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27115.206270 27115.2063  0.00%     -    9s
#
# Explored 1 nodes (55047 simplex iterations) in 9.91 seconds (5.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27115.2 28320.8 28417.9 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.711520626984e+04, best bound 2.711520626984e+04, gap 0.0000%
# trial_size 80
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111804 rows, 148568 columns and 1627268 nonzeros
# Model fingerprint: 0xcf702bc8
# Variable types: 99120 continuous, 49448 integer (49448 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100072 rows and 99347 columns
# Presolve time: 0.96s
# Presolved: 11732 rows, 49221 columns, 239229 nonzeros
# Variable types: 2517 continuous, 46704 integer (46704 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.709520e+04, 43906 iterations, 3.05 seconds (1.58 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27095.200937 27095.2009  0.00%     -    8s
#
# Explored 1 nodes (53074 simplex iterations) in 8.85 seconds (4.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27095.2 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.709520093651e+04, best bound 2.709520093651e+04, gap 0.0000%
# trial_size 81
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 111955 rows, 149144 columns and 1645219 nonzeros
# Model fingerprint: 0xbb02071d
# Variable types: 99120 continuous, 50024 integer (50024 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100088 rows and 99349 columns
# Presolve time: 0.61s
# Presolved: 11867 rows, 49795 columns, 242141 nonzeros
# Found heuristic solution: objective 28360.218746
# Variable types: 2517 continuous, 47278 integer (47278 binary)
# Found heuristic solution: objective 28267.096270
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    44281    2.7076192e+04   0.000000e+00   0.000000e+00      5s
#    44281    2.7076192e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.707619e+04, 44281 iterations, 3.65 seconds (1.64 work units)
# Total elapsed time = 5.09s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27076.191603 27076.1916  0.00%     -    9s
#
# Explored 1 nodes (54390 simplex iterations) in 9.22 seconds (5.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27076.2 28267.1 28360.2 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.707619160317e+04, best bound 2.707619160317e+04, gap 0.0000%
# trial_size 82
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112106 rows, 149720 columns and 1663170 nonzeros
# Model fingerprint: 0x93827431
# Variable types: 99120 continuous, 50600 integer (50600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100104 rows and 99351 columns
# Presolve time: 0.86s
# Presolved: 12002 rows, 50369 columns, 245053 nonzeros
# Found heuristic solution: objective 28302.382460
# Variable types: 2517 continuous, 47852 integer (47852 binary)
# Found heuristic solution: objective 28208.754460
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.3209344e+01      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    44977    2.7057652e+04   0.000000e+00   5.320934e+01      6s
#    45101    2.7057652e+04   0.000000e+00   0.000000e+00      6s
#    45101    2.7057652e+04   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.705765e+04, 45101 iterations, 4.07 seconds (1.64 work units)
# Total elapsed time = 6.02s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27057.651841 27057.6518  0.00%     -   11s
#
# Explored 1 nodes (57181 simplex iterations) in 11.77 seconds (6.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27057.7 28208.8 28302.4 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.705765184127e+04, best bound 2.705765184127e+04, gap 0.0000%
# trial_size 83
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112257 rows, 150296 columns and 1681121 nonzeros
# Model fingerprint: 0x4a9fa241
# Variable types: 99120 continuous, 51176 integer (51176 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100120 rows and 99353 columns
# Presolve time: 0.62s
# Presolved: 12137 rows, 50943 columns, 247965 nonzeros
# Variable types: 2517 continuous, 48426 integer (48426 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.0576967e-11      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    45521    2.7041078e+04   0.000000e+00   0.000000e+00      5s
#    45521    2.7041078e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.704108e+04, 45521 iterations, 3.49 seconds (1.54 work units)
# Total elapsed time = 5.14s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27041.077714 27041.0777  0.00%     -   10s
#
# Explored 1 nodes (56341 simplex iterations) in 10.58 seconds (5.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27041.1 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.704107771428e+04, best bound 2.704107771428e+04, gap 0.0000%
# trial_size 84
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112408 rows, 150872 columns and 1699072 nonzeros
# Model fingerprint: 0x5d05bb51
# Variable types: 99120 continuous, 51752 integer (51752 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100136 rows and 99355 columns
# Presolve time: 0.77s
# Presolved: 12272 rows, 51517 columns, 250877 nonzeros
# Variable types: 2517 continuous, 49000 integer (49000 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.702588e+04, 46089 iterations, 2.91 seconds (1.61 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27025.880476 27025.8805  0.00%     -    9s
#
# Explored 1 nodes (58440 simplex iterations) in 10.08 seconds (5.98 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27025.9 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.702588047619e+04, best bound 2.702588047619e+04, gap 0.0000%
# trial_size 85
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112559 rows, 151448 columns and 1717023 nonzeros
# Model fingerprint: 0x88d02bc2
# Variable types: 99120 continuous, 52328 integer (52328 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100152 rows and 99357 columns
# Presolve time: 0.89s
# Presolved: 12407 rows, 52091 columns, 253789 nonzeros
# Variable types: 2517 continuous, 49574 integer (49574 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.701158e+04, 46188 iterations, 2.77 seconds (1.67 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    27011.581619 27011.5816  0.00%     -   10s
#
# Explored 1 nodes (57459 simplex iterations) in 10.28 seconds (5.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27011.6 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.701158161905e+04, best bound 2.701158161905e+04, gap 0.0000%
# trial_size 86
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112710 rows, 152024 columns and 1734974 nonzeros
# Model fingerprint: 0xf4e8884c
# Variable types: 99120 continuous, 52904 integer (52904 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100168 rows and 99359 columns
# Presolve time: 0.92s
# Presolved: 12542 rows, 52665 columns, 256701 nonzeros
# Variable types: 2512 continuous, 50153 integer (50153 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.3162094e+02      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    46734    2.6998409e+04   0.000000e+00   5.316209e+02      5s
#    46880    2.6998409e+04   0.000000e+00   0.000000e+00      5s
#    46880    2.6998409e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.699841e+04, 46880 iterations, 3.54 seconds (1.76 work units)
# Total elapsed time = 5.42s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26998.409238 26998.4092  0.00%     -    9s
#
# Explored 1 nodes (57993 simplex iterations) in 10.01 seconds (6.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 26998.4 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.699840923809e+04, best bound 2.699840923809e+04, gap 0.0000%
# trial_size 87
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 112861 rows, 152600 columns and 1752925 nonzeros
# Model fingerprint: 0xe25d6b54
# Variable types: 99120 continuous, 53480 integer (53480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100184 rows and 99361 columns
# Presolve time: 0.89s
# Presolved: 12677 rows, 53239 columns, 259613 nonzeros
# Variable types: 2512 continuous, 50727 integer (50727 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.6273586e-11      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    47265    2.6985584e+04   0.000000e+00   0.000000e+00      5s
#    47265    2.6985584e+04   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.698558e+04, 47265 iterations, 3.73 seconds (1.81 work units)
# Total elapsed time = 5.51s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26985.583857 26985.5839  0.00%     -   10s
#
# Explored 1 nodes (57988 simplex iterations) in 10.95 seconds (6.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 26985.6 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.698558385714e+04, best bound 2.698558385714e+04, gap 0.0000%
# trial_size 88
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113012 rows, 153176 columns and 1770876 nonzeros
# Model fingerprint: 0xec133582
# Variable types: 99120 continuous, 54056 integer (54056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100200 rows and 98740 columns
# Presolve time: 1.25s
# Presolved: 12812 rows, 54436 columns, 213931 nonzeros
# Variable types: 2512 continuous, 51924 integer (51301 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8543833e-11      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    47318    2.6973876e+04   0.000000e+00   0.000000e+00      5s
#    47318    2.6973876e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.697388e+04, 47318 iterations, 3.18 seconds (1.81 work units)
# Total elapsed time = 5.22s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26973.876238 26973.8762  0.00%     -    9s
#
# Explored 1 nodes (58700 simplex iterations) in 9.85 seconds (6.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 26973.9 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.697387623809e+04, best bound 2.697387623809e+04, gap 0.0000%
# trial_size 89
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113163 rows, 153752 columns and 1788827 nonzeros
# Model fingerprint: 0x5cede858
# Variable types: 99120 continuous, 54632 integer (54632 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100453 rows and 98945 columns
# Presolve time: 1.32s
# Presolved: 12710 rows, 54807 columns, 215457 nonzeros
# Found heuristic solution: objective 28618.434968
# Variable types: 2512 continuous, 52295 integer (52295 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.696285e+04, 48299 iterations, 3.46 seconds (1.79 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26962.854524 26962.8545  0.00%     -    7s
#
# Explored 1 nodes (56191 simplex iterations) in 8.15 seconds (4.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 26962.9 28618.4 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.696285452381e+04, best bound 2.696285452381e+04, gap 0.0000%
# trial_size 90
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113314 rows, 154328 columns and 1806778 nonzeros
# Model fingerprint: 0x71286d1d
# Variable types: 99120 continuous, 55208 integer (55208 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100469 rows and 98940 columns
# Presolve time: 1.31s
# Presolved: 12845 rows, 55388 columns, 217823 nonzeros
# Found heuristic solution: objective 28589.805524
# Variable types: 2512 continuous, 52876 integer (52876 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3264000e+01      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    48848    2.6952741e+04   0.000000e+00   1.326400e+01      6s
#    48854    2.6952741e+04   0.000000e+00   0.000000e+00      6s
#    48854    2.6952741e+04   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.695274e+04, 48854 iterations, 4.23 seconds (1.79 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26952.741190 26952.7412  0.00%     -    9s
#
# Explored 1 nodes (58103 simplex iterations) in 9.62 seconds (5.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 26952.7 28589.8 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.695274119047e+04, best bound 2.695274119047e+04, gap 0.0000%
# trial_size 91
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113465 rows, 154904 columns and 1824729 nonzeros
# Model fingerprint: 0x33d129ea
# Variable types: 99120 continuous, 55784 integer (55784 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100485 rows and 98935 columns
# Presolve time: 1.46s
# Presolved: 12980 rows, 55969 columns, 220189 nonzeros
# Found heuristic solution: objective 28602.219317
# Variable types: 2512 continuous, 53457 integer (53457 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5302093e-11      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    49365    2.6943741e+04   0.000000e+00   0.000000e+00      5s
#    49365    2.6943741e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.694374e+04, 49365 iterations, 3.63 seconds (1.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26943.741000 26943.7410  0.00%     -    8s
#
# Explored 1 nodes (58496 simplex iterations) in 9.17 seconds (5.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 26943.7 28602.2 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.694374100000e+04, best bound 2.694374100000e+04, gap 0.0000%
# trial_size 92
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113616 rows, 155480 columns and 1842680 nonzeros
# Model fingerprint: 0xefaf2ccf
# Variable types: 99120 continuous, 56360 integer (56360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100501 rows and 98930 columns
# Presolve time: 1.77s
# Presolved: 13115 rows, 56550 columns, 222555 nonzeros
# Found heuristic solution: objective 28650.102365
# Variable types: 2512 continuous, 54038 integer (54038 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.4460988e-11      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    49897    2.6935858e+04   0.000000e+00   0.000000e+00      5s
#    49897    2.6935858e+04   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.693586e+04, 49897 iterations, 3.28 seconds (1.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26935.857571 26935.8576  0.00%     -    9s
#
# Explored 1 nodes (60612 simplex iterations) in 9.76 seconds (6.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 26935.9 28650.1 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.693585757143e+04, best bound 2.693585757143e+04, gap 0.0000%
# trial_size 93
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113767 rows, 156056 columns and 1860631 nonzeros
# Model fingerprint: 0xf9d82913
# Variable types: 99120 continuous, 56936 integer (56936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 6.608000e+12
# Presolve removed 100517 rows and 98925 columns
# Presolve time: 1.52s
# Presolved: 13250 rows, 57131 columns, 224921 nonzeros
# Found heuristic solution: objective 28467.013286
# Variable types: 2512 continuous, 54619 integer (54619 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.9730048e+02      5s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    50433    2.6932155e+04   0.000000e+00   1.973005e+02      5s
#    50445    2.6932155e+04   0.000000e+00   0.000000e+00      6s
#    50445    2.6932155e+04   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 2.693216e+04, 50445 iterations, 3.82 seconds (1.87 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    26932.155000 26932.1550  0.00%     -   10s
#
# Explored 1 nodes (60893 simplex iterations) in 10.46 seconds (6.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 26932.2 28467 6.608e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.693215500000e+04, best bound 2.693215500000e+04, gap 0.0000%
# trial_size 94
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 113918 rows, 156632 columns and 1878582 nonzeros
# Model fingerprint: 0x99657694
# ...
# H    0     0                    67710.558532 56604.3646  16.4%     -    5s
# H    0     0                    66477.750860 56604.3646  14.9%     -    6s
# H    0     0                    66343.341071 56604.3646  14.7%     -    6s
#      0     0 56762.1172    0 1900 66343.3411 56762.1172  14.4%     -    7s
# H    0     0                    66325.465079 56762.1172  14.4%     -    7s
# H    0     0                    57975.654398 57688.5761  0.50%     -    8s
# H    0     0                    57972.404398 57688.5761  0.49%     -    8s
# H    0     0                    57832.971892 57688.5761  0.25%     -    8s
#      0     0 57688.5761    0  430 57832.9719 57688.5761  0.25%     -    8s
#      0     0 57746.9893    0  266 57832.9719 57746.9893  0.15%     -    9s
#      0     0          -    0      57832.9719 57827.3608  0.01%     -    9s
#
# Cutting planes:
#   Implied bound: 526
#   Zero half: 425
#
# Explored 1 nodes (84848 simplex iterations) in 9.60 seconds (6.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 57833 57972.4 57975.7 ... 67726.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.783297189153e+04, best bound 5.782736078042e+04, gap 0.0097%
# trial_size 78
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 108783 rows, 141963 columns and 1416262 nonzeros
# Model fingerprint: 0x8c191f36
# Variable types: 99120 continuous, 42843 integer (42843 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101326 rows and 111310 columns
# Presolve time: 0.40s
# Presolved: 7457 rows, 30653 columns, 148269 nonzeros
# Variable types: 1735 continuous, 28918 integer (28918 binary)
# Found heuristic solution: objective 67566.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.666429e+04, 25617 iterations, 0.33 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56664.2859    0 1866 67566.2748 56664.2859  16.1%     -    4s
# H    0     0                    67550.558532 56664.2859  16.1%     -    4s
# H    0     0                    66932.660317 56664.2859  15.3%     -    4s
# H    0     0                    66230.604365 56664.2859  14.4%     -    4s
#      0     0 56845.8509    0 1554 66230.6044 56845.8509  14.2%     -    5s
# H    0     0                    66220.482738 56845.8509  14.2%     -    5s
# H    0     0                    58051.480291 57595.8927  0.78%     -    6s
# H    0     0                    58045.411839 57595.8927  0.77%     -    6s
# H    0     0                    57863.564319 57595.8927  0.46%     -    6s
#      0     0 57595.8927    0  704 57863.5643 57595.8927  0.46%     -    6s
#      0     0 57659.9274    0  699 57863.5643 57659.9274  0.35%     -    6s
# H    0     0                    57862.467097 57659.9274  0.35%     -    7s
#      0     0          -    0      57862.4671 57861.7449  0.00%     -    7s
#
# Cutting planes:
#   Implied bound: 469
#   MIR: 1
#   Zero half: 366
#
# Explored 1 nodes (67942 simplex iterations) in 7.73 seconds (4.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 57862.5 57863.6 58045.4 ... 67566.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.786246709656e+04, best bound 5.786174487434e+04, gap 0.0012%
# trial_size 70
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 108914 rows, 142535 columns and 1434009 nonzeros
# Model fingerprint: 0x39fd3bf8
# Variable types: 99120 continuous, 43415 integer (43415 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101360 rows and 111472 columns
# Presolve time: 0.43s
# Presolved: 7554 rows, 31063 columns, 150349 nonzeros
# Variable types: 1735 continuous, 29328 integer (29328 binary)
# Found heuristic solution: objective 67586.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.664890e+04, 26312 iterations, 0.35 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56648.9039    0 1948 67586.2748 56648.9039  16.2%     -    4s
# H    0     0                    67570.558532 56648.9039  16.2%     -    4s
# H    0     0                    66495.741270 56648.9039  14.8%     -    4s
#      0     0 56837.3762    0 1632 66495.7413 56837.3762  14.5%     -    5s
# H    0     0                    66481.403373 56837.3762  14.5%     -    6s
# H    0     0                    58043.905225 57703.6393  0.59%     -    7s
# H    0     0                    58037.349669 57703.6393  0.57%     -    7s
#      0     0 57703.6393    0  488 58037.3497 57703.6393  0.57%     -    7s
# H    0     0                    57964.966997 57703.6393  0.45%     -    7s
# H    0     0                    57857.472652 57761.1845  0.17%     -    7s
#      0     0 57761.1845    0  471 57857.4727 57761.1845  0.17%     -    8s
#      0     0          -    0      57857.4727 57856.5088  0.00%     -    8s
#
# Cutting planes:
#   Implied bound: 468
#   MIR: 1
#   Zero half: 389
#
# Explored 1 nodes (70190 simplex iterations) in 8.75 seconds (5.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 57857.5 57965 58037.3 ... 67586.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.785747265212e+04, best bound 5.785650876323e+04, gap 0.0017%
# trial_size 71
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 109045 rows, 143107 columns and 1451756 nonzeros
# Model fingerprint: 0x4fc5c66f
# Variable types: 99120 continuous, 43987 integer (43987 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101394 rows and 111634 columns
# Presolve time: 0.43s
# Presolved: 7651 rows, 31473 columns, 152429 nonzeros
# Variable types: 1735 continuous, 29738 integer (29738 binary)
# Found heuristic solution: objective 67606.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.663627e+04, 26738 iterations, 0.43 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56636.2750    0 2020 67606.2748 56636.2750  16.2%     -    3s
# H    0     0                    67590.558532 56636.2750  16.2%     -    4s
# H    0     0                    66298.725165 56636.2750  14.6%     -    4s
#      0     0 56831.3519    0 1684 66298.7252 56831.3519  14.3%     -    5s
# H    0     0                    66285.231515 56831.3519  14.3%     -    5s
# H    0     0                    57943.079266 57760.1928  0.32%     -    6s
# H    0     0                    57936.245933 57760.1928  0.30%     -    6s
# H    0     0                    57852.194874 57760.1928  0.16%     -    6s
#      0     0 57760.1928    0  354 57852.1949 57760.1928  0.16%     -    6s
#      0     0 57802.9706    0  230 57852.1949 57802.9706  0.09%     -    7s
# H    0     0                    57851.828208 57802.9706  0.08%     -    7s
#      0     0          -    0      57851.8282 57851.2310  0.00%     -    7s
#
# Cutting planes:
#   Implied bound: 479
#   MIR: 2
#   Zero half: 383
#
# Explored 1 nodes (60882 simplex iterations) in 7.83 seconds (4.59 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 57851.8 57852.2 57936.2 ... 67606.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.785182820767e+04, best bound 5.785123098545e+04, gap 0.0010%
# trial_size 72
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 109176 rows, 143679 columns and 1469503 nonzeros
# Model fingerprint: 0xbe6ca661
# Variable types: 99120 continuous, 44559 integer (44559 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101428 rows and 111796 columns
# Presolve time: 0.44s
# Presolved: 7748 rows, 31883 columns, 154509 nonzeros
# Variable types: 1735 continuous, 30148 integer (30148 binary)
# Found heuristic solution: objective 67626.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.662572e+04, 27411 iterations, 0.33 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56625.7244    0 2064 67626.2748 56625.7244  16.3%     -    3s
# H    0     0                    67610.558532 56625.7244  16.2%     -    4s
# H    0     0                    66463.532341 56625.7244  14.8%     -    4s
# H    0     0                    66289.743056 56625.7244  14.6%     -    4s
#      0     0 56811.3161    0 1658 66289.7431 56811.3161  14.3%     -    5s
# H    0     0                    66277.489087 56811.3161  14.3%     -    5s
# H    0     0                    57958.725562 57766.1005  0.33%     -    6s
# H    0     0                    57953.975562 57766.1005  0.32%     -    6s
# H    0     0                    57846.838128 57766.1005  0.14%     -    7s
#      0     0 57766.1005    0  304 57846.8381 57766.1005  0.14%     -    7s
#      0     0 57803.9527    0  321 57846.8381 57803.9527  0.07%     -    7s
#      0     0 57840.1707    0  264 57846.8381 57840.1707  0.01%     -    8s
#      0     0          -    0      57846.8381 57841.7048  0.01%     -    9s
#
# Cutting planes:
#   Implied bound: 474
#   MIR: 2
#   Zero half: 353
#   Mod-K: 4
#   RLT: 12
#
# Explored 1 nodes (65110 simplex iterations) in 9.63 seconds (6.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 57846.8 57954 57958.7 ... 67626.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.784683812831e+04, best bound 5.784170479497e+04, gap 0.0089%
# trial_size 73
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 109307 rows, 144251 columns and 1487250 nonzeros
# Model fingerprint: 0xbc83c902
# Variable types: 99120 continuous, 45131 integer (45131 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101462 rows and 111958 columns
# Presolve time: 0.41s
# Presolved: 7845 rows, 32293 columns, 156589 nonzeros
# Variable types: 1735 continuous, 30558 integer (30558 binary)
# Found heuristic solution: objective 67646.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.661671e+04, 28357 iterations, 0.49 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56616.7128    0 2060 67646.2748 56616.7128  16.3%     -    4s
# H    0     0                    67630.558532 56616.7128  16.3%     -    4s
# H    0     0                    66553.643651 56616.7128  14.9%     -    4s
# H    0     0                    66534.735913 56616.7128  14.9%     -    4s
#      0     0 56792.5860    0 1680 66534.7359 56792.5860  14.6%     -    5s
# H    0     0                    66519.587698 56792.5860  14.6%     -    6s
# H    0     0                    66402.332937 57723.8228  13.1%     -    7s
# H    0     0                    58000.081415 57723.8228  0.48%     -    7s
# H    0     0                    57997.664749 57723.8228  0.47%     -    7s
# H    0     0                    57841.937335 57723.8228  0.20%     -    7s
#      0     0 57723.8228    0  453 57841.9373 57723.8228  0.20%     -    7s
#      0     0 57766.4096    0  403 57841.9373 57766.4096  0.13%     -    7s
#      0     0          -    0      57841.9373 57841.0415  0.00%     -    7s
#
# Cutting planes:
#   Implied bound: 484
#   Zero half: 412
#
# Explored 1 nodes (66116 simplex iterations) in 7.91 seconds (4.82 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 57841.9 57997.7 58000.1 ... 67646.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.784193733466e+04, best bound 5.784104150132e+04, gap 0.0015%
# trial_size 74
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 109438 rows, 144823 columns and 1504997 nonzeros
# Model fingerprint: 0xb4230273
# Variable types: 99120 continuous, 45703 integer (45703 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 101496 rows and 112120 columns
# Presolve time: 0.58s
# Presolved: 7942 rows, 32703 columns, 158669 nonzeros
# Variable types: 1735 continuous, 30968 integer (30968 binary)
# Found heuristic solution: objective 67666.274802
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.661009e+04, 28241 iterations, 0.42 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56610.0878    0 2112 67666.2748 56610.0878  16.3%     -    4s
# H    0     0                    67650.558532 56610.0878  16.3%     -    4s
# H    0     0                    66305.643948 56610.0878  14.6%     -    4s
#      0     0 56789.8082    0 1788 66305.6439 56789.8082  14.4%     -    6s
# H    0     0                    66288.486078 56789.8082  14.3%     -    6s
# H    0     0                    58735.330688 56789.8082  3.31%     -    7s
# H    0     0                    58030.688261 56789.8082  2.14%     -    7s
# H    0     0                    58015.820205 57682.1040  0.58%     -    7s
#      0     0 57682.1040    0  525 58015.8202 57682.1040  0.58%     -    7s
# H    0     0                    57991.196594 57682.1040  0.53%     -    8s
#      0     0 57745.9998    0  424 57991.1966 57745.9998  0.42%     -    8s
# H    0     0                    57982.723016 57745.9998  0.41%     -    8s
#      0     0 57837.4234    0  117 57982.7230 57837.4234  0.25%     -    8s
# H    0     0                    57841.375827 57837.4234  0.01%     -    9s
#
# Cutting planes:
#   Implied bound: 508
#   MIR: 1
#   StrongCG: 1
#   Zero half: 390
#
# Explored 1 nodes (65539 simplex iterations) in 9.35 seconds (5.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 57841.4 57982.7 57991.2 ... 67666.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.784137582672e+04, best bound 5.783742344577e+04, gap 0.0068%
# trial_size 75

# %%
df_view = pd.read_excel(f'../workforce_size/berlin_db=2.00_all_trials.xlsx')
df_view.sort_values(by = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts', 'workforce_size_trial'], ascending = [True, True, True, True, True, False], inplace = True)
df_view.drop_duplicates(subset = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts'], inplace = True)
df_view.sort_values(by = ['workforce_size_trial'], inplace = True)
df_view.head()
# Out:
#            instance    city  demand_baseline  outsourcing_cost_multiplier  \
# 137  berlin_db=2.00  berlin                2                          1.2
# 377  berlin_db=2.00  berlin                2                          1.5
# 619  berlin_db=2.00  berlin                2                          1.8
# 864  berlin_db=2.00  berlin                2                          2.0
# 97   berlin_db=2.00  berlin                2                          1.2
#
#      region_multiplier  global_multiplier     model  max_n_shifts  \
# 137                1.5                0.8  partflex           2.0
# 377                1.5                0.8  partflex           2.0
# 619                1.5                0.8  partflex           2.0
# 864                1.5                0.8  partflex           2.0
# 97                 1.5                0.8      flex           NaN
#
#      workforce_size  wage_costs  objective_value  objective_value_post_wage  \
# 137              43       844.0     14182.163333               13338.163333
# 377              45       900.0     17510.425000               16610.425000
# 619              46       948.0     20826.365000               19878.365000
# 864              47       948.0     23035.072222               22087.072222
# 97               47      1084.0     13266.540000               12182.540000
#
#      workforce_size_trial
# 137                    40
# 377                    42
# 619                    43
# 864                    44
# 97                     44

# %%
df_view.tail()
# Out:
#             instance    city  demand_baseline  outsourcing_cost_multiplier  \
# 53    berlin_db=2.00  berlin                2                          1.2
# 289   berlin_db=2.00  berlin                2                          1.5
# 529   berlin_db=2.00  berlin                2                          1.8
# 773   berlin_db=2.00  berlin                2                          2.0
# 1020  berlin_db=2.00  berlin                2                          2.5
#
#       region_multiplier  global_multiplier  model  max_n_shifts  \
# 53                  1.5                0.8  fixed           NaN
# 289                 1.5                0.8  fixed           NaN
# 529                 1.5                0.8  fixed           NaN
# 773                 1.5                0.8  fixed           NaN
# 1020                1.5                0.8  fixed           NaN
#
#       workforce_size  wage_costs  objective_value  objective_value_post_wage  \
# 53                57      1324.0     13368.893333               12044.893333
# 289               61      1420.0     16367.629167               14947.629167
# 529               63      1468.0     19351.010000               17883.010000
# 773               63      1468.0     21338.011111               19870.011111
# 1020              65      1532.0     26295.972222               24763.972222
#
#       workforce_size_trial
# 53                      54
# 289                     58
# 529                     60
# 773                     60
# 1020                    62
