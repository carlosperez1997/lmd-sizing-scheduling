# %%
from glob import glob
from os import path
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']
# 16

# %%
#Subset to France

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('lyon') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt_subset)
# Out:
# ['lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00']

# %%
def dict_append_workforce(dict_, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, workforce_size, objvalprev, objval, objvalnext):
    dict_['instance_file_base'].append(base_file)
    dict_['city'].append(city)
    dict_['demand_baseline'].append(demand_baseline)
    dict_['model'].append(model)
    dict_['max_n_shifts'].append(max_n_shifts)
    dict_['outsourcing_cost_multiplier'].append(OC)
    dict_['regional_multiplier'].append(RM)
    dict_['global_multiplier'].append(GM)
    dict_['workforce_size_region0'].append(workforce_size)
    dict_['objective_value_prev'].append(objvalprev)
    dict_['objective_value'].append(objval)
    dict_['objective_value_next'].append(objvalnext)
    return dict_

# %%
#Code that determines optimal workforce size

MAX_TRIES = 120

RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

for base_file in list_city_dt_subset:
# for base_file in ['berlin_db=1.00']:
    print(base_file+'============================================')

    if f'{base_file}.json' not in os.listdir(r'../workforce_size'):

        list_results = []

        #create inputs to run a trial workforce size
        weekday_ = f'{base_file}_dt=doublepeak.json'
        weekend_ = f'{base_file}_dt=uniform.json'

        instance_file_weekday = f"../instances/{weekday_}"
        instance_file_weekend = f"../instances/{weekend_}"

        shift_file_weekday = f"../shifts/{weekday_}"
        shift_file_weekend = f"../shifts/{weekend_}"

        #create dictionary for evaluating optimal workforce size
        workforce_out = f"../workforce_size/{base_file}.json"
        dict_out = {
            'instance_file_base':[],
            'city':[],
            'demand_baseline':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'workforce_size_region0':[],
            'objective_value_prev':[],
            'objective_value':[],
            'objective_value_next':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'

        city_match = re.search(city_pattern, base_file)
        db_match = re.search(db_pattern, base_file)

        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None

        #Set min_tries based on demand_baseline
        if demand_baseline == 0.5:
            MIN_TRIES = 5
        elif demand_baseline == 1.0:
            MIN_TRIES = 5
        elif demand_baseline == 2.0:
            MIN_TRIES = 5
        elif demand_baseline == 4.0:
            MIN_TRIES = 5

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
        # for OC in [1.2]:
            print(f'OC = {OC}++++++++++++++++++++++')
            for model in ['fixed', 'flex', 'partflex']:
            # for model in ['fixed']:
                print(f'model = {model}-------------------------')
                if model == 'partflex':
                    for max_n_shifts in range(2,5):
                    # for max_n_shifts in [4]:
                        objvalprev = 1e8
                        objval = 1e7
                        for trial_size in range(MIN_TRIES, MAX_TRIES):
                            workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                            if (objval < objvalprev)&(np.isnan(objval) == False):
                                objvalprev = objval
                                dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
                                objval = dict_results['objective_value'][0]
                                print("trial_size",trial_size)
                                df_ = pd.DataFrame(dict_results)
                                df_['workforce_size_trial'] = trial_size
                                list_results.append(df_)
                            else:
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size-1, np.nan, objvalprev, objval)
                                break
                            if trial_size == int(MAX_TRIES-1):
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size, objvalprev, objval, np.nan)
                else:
                    objvalprev = 1e8
                    objval = 1e7
                    for trial_size in range(MIN_TRIES, MAX_TRIES):
                        workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                        if (objval < objvalprev)&(np.isnan(objval) == False):
                            objvalprev = objval
                            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
                            objval = dict_results['objective_value'][0]
                            print("trial_size",trial_size)
                            df_ = pd.DataFrame(dict_results)
                            df_['workforce_size_trial'] = trial_size
                            list_results.append(df_)
                        else: 
                            #keep track of optimal (trial size - 1)
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size-1, np.nan, objvalprev, objval)
                            break
                        if trial_size == int(MAX_TRIES-1):
                            #keep track of optimal
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size, objvalprev, objval, np.nan)
        #export optimal workforce size values
        with open(workforce_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
        df_trials = pd.concat(list_results, ignore_index = True)
        df_trials.to_excel(f'../workforce_size/{base_file}_all_trials.xlsx', index = False)
# Out:
# lyon_db=0.50============================================
# OC = 1.2++++++++++++++++++++++
# model = fixed-------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28088 rows, 28800 columns and 74076 nonzeros
# Model fingerprint: 0x70a935e1
# Variable types: 26880 continuous, 1920 integer (1920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 3311.4633385
# Presolve removed 27189 rows and 27004 columns
# Presolve time: 0.03s
# Presolved: 899 rows, 1796 columns, 6766 nonzeros
# Found heuristic solution: objective 3200.2466667
# Variable types: 586 continuous, 1210 integer (1210 binary)
#
# Root relaxation: objective 3.063780e+03, 1525 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    3063.7800000 2469.32667  19.4%     -    0s
#      0     0          -    0      3063.78000 3063.78000  0.00%     -    0s
#
# Explored 1 nodes (1724 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3063.78 3200.25 3311.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.063779999999e+03, best bound 3.063779999999e+03, gap 0.0000%
# trial_size 5
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28239 rows, 29040 columns and 80650 nonzeros
# Model fingerprint: 0x1f500734
# Variable types: 26880 continuous, 2160 integer (2160 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27205 rows and 27006 columns
# Presolve time: 0.04s
# Presolved: 1034 rows, 2034 columns, 7998 nonzeros
# Found heuristic solution: objective 3183.1466667
# Variable types: 586 continuous, 1448 integer (1448 binary)
#
# Root relaxation: objective 3.024420e+03, 2075 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3024.4200000 3024.42000  0.00%     -    0s
#
# Explored 1 nodes (2075 simplex iterations) in 0.09 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3024.42 3183.15 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.024419999999e+03, best bound 3.024419999999e+03, gap 0.0000%
# trial_size 6
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28390 rows, 29280 columns and 87224 nonzeros
# Model fingerprint: 0x81cad35f
# Variable types: 26880 continuous, 2400 integer (2400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27221 rows and 27008 columns
# Presolve time: 0.04s
# Presolved: 1169 rows, 2272 columns, 9230 nonzeros
# Found heuristic solution: objective 3192.2200000
# Variable types: 586 continuous, 1686 integer (1686 binary)
#
# Root relaxation: objective 2.986520e+03, 2907 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2986.5200000 2986.52000  0.00%     -    0s
#
# Explored 1 nodes (2907 simplex iterations) in 0.11 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2986.52 3192.22 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.986519999999e+03, best bound 2.986519999999e+03, gap 0.0000%
# trial_size 7
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28541 rows, 29520 columns and 93798 nonzeros
# Model fingerprint: 0x04a76b0e
# Variable types: 26880 continuous, 2640 integer (2640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27237 rows and 27010 columns
# Presolve time: 0.04s
# Presolved: 1304 rows, 2510 columns, 10462 nonzeros
# Found heuristic solution: objective 3197.7266667
# Variable types: 586 continuous, 1924 integer (1924 binary)
#
# Root relaxation: objective 2.951280e+03, 2964 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2951.2800000 2951.28000  0.00%     -    0s
#
# Explored 1 nodes (2964 simplex iterations) in 0.12 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2951.28 3197.73 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.951279999999e+03, best bound 2.951279999999e+03, gap 0.0000%
# trial_size 8
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28692 rows, 29760 columns and 100372 nonzeros
# Model fingerprint: 0x7f99ca9d
# Variable types: 26880 continuous, 2880 integer (2880 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27253 rows and 27012 columns
# Presolve time: 0.05s
# Presolved: 1439 rows, 2748 columns, 11694 nonzeros
# Variable types: 586 continuous, 2162 integer (2162 binary)
# Found heuristic solution: objective 3457.1466667
#
# Root relaxation: objective 2.918340e+03, 3592 iterations, 0.07 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2918.3400000 2918.34000  0.00%     -    0s
#
# Explored 1 nodes (3592 simplex iterations) in 0.15 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2918.34 3457.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.918339999999e+03, best bound 2.918339999999e+03, gap 0.0000%
# trial_size 9
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28843 rows, 30000 columns and 106946 nonzeros
# Model fingerprint: 0x9497171b
# Variable types: 26880 continuous, 3120 integer (3120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27269 rows and 27014 columns
# Presolve time: 0.05s
# Presolved: 1574 rows, 2986 columns, 12926 nonzeros
# Found heuristic solution: objective 3112.5133333
# Variable types: 586 continuous, 2400 integer (2400 binary)
#
# Root relaxation: objective 2.893567e+03, 4048 iterations, 0.09 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2893.5666667 2893.56667  0.00%     -    0s
#
# Explored 1 nodes (4695 simplex iterations) in 0.19 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2893.57 3112.51 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.893566666666e+03, best bound 2.893566666666e+03, gap 0.0000%
# trial_size 10
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28994 rows, 30240 columns and 113520 nonzeros
# Model fingerprint: 0x4bb773c0
# Variable types: 26880 continuous, 3360 integer (3360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27285 rows and 27016 columns
# Presolve time: 0.06s
# Presolved: 1709 rows, 3224 columns, 14158 nonzeros
# Found heuristic solution: objective 3112.5600000
# Variable types: 586 continuous, 2638 integer (2638 binary)
#
# Root relaxation: objective 2.873427e+03, 4643 iterations, 0.11 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2873.4266667 2873.42667  0.00%     -    0s
#
# Explored 1 nodes (4643 simplex iterations) in 0.20 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2873.43 3112.56 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.873426666666e+03, best bound 2.873426666666e+03, gap 0.0000%
# trial_size 11
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29145 rows, 30480 columns and 120094 nonzeros
# Model fingerprint: 0xe0d08e98
# Variable types: 26880 continuous, 3600 integer (3600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27301 rows and 27018 columns
# Presolve time: 0.06s
# Presolved: 1844 rows, 3462 columns, 15390 nonzeros
# Found heuristic solution: objective 3087.8933333
# Variable types: 586 continuous, 2876 integer (2876 binary)
#
# Root relaxation: objective 2.860827e+03, 4933 iterations, 0.13 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    2860.8266667 2469.32667  13.7%     -    0s
#      0     0          -    0      2860.82667 2860.82667  0.00%     -    0s
#
# Explored 1 nodes (5719 simplex iterations) in 0.23 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2860.83 3087.89 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.860826666666e+03, best bound 2.860826666666e+03, gap 0.0000%
# trial_size 12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29296 rows, 30720 columns and 126668 nonzeros
# Model fingerprint: 0x78349c25
# Variable types: 26880 continuous, 3840 integer (3840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27317 rows and 27020 columns
# Presolve time: 0.08s
# Presolved: 1979 rows, 3700 columns, 16622 nonzeros
# Variable types: 586 continuous, 3114 integer (3114 binary)
# Found heuristic solution: objective 3553.1466667
#
# Root relaxation: objective 2.852527e+03, 5182 iterations, 0.14 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2852.5266667 2852.52667  0.00%     -    0s
#
# Explored 1 nodes (5182 simplex iterations) in 0.27 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2852.53 3553.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.852526666666e+03, best bound 2.852526666666e+03, gap 0.0000%
# trial_size 13
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29447 rows, 30960 columns and 133242 nonzeros
# Model fingerprint: 0x77f4638f
# Variable types: 26880 continuous, 4080 integer (4080 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27333 rows and 27022 columns
# Presolve time: 0.07s
# Presolved: 2114 rows, 3938 columns, 17854 nonzeros
# Found heuristic solution: objective 3065.0000000
# Variable types: 586 continuous, 3352 integer (3352 binary)
#
# Root relaxation: objective 2.850593e+03, 5646 iterations, 0.16 seconds (0.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2850.5933333 2850.59333  0.00%     -    0s
#
# Explored 1 nodes (6523 simplex iterations) in 0.27 seconds (0.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2850.59 3065 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850593333333e+03, best bound 2.850593333333e+03, gap 0.0000%
# trial_size 14
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29598 rows, 31200 columns and 139816 nonzeros
# Model fingerprint: 0xd7380cf8
# Variable types: 26880 continuous, 4320 integer (4320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27349 rows and 27024 columns
# Presolve time: 0.10s
# Presolved: 2249 rows, 4176 columns, 19086 nonzeros
# Variable types: 586 continuous, 3590 integer (3590 binary)
# Found heuristic solution: objective 3601.1466667
#
# Root relaxation: objective 2.850593e+03, 5518 iterations, 0.18 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2850.5933333 2850.59333  0.00%     -    0s
#
# Explored 1 nodes (7085 simplex iterations) in 0.33 seconds (0.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2850.59 3601.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850593333333e+03, best bound 2.850593333333e+03, gap 0.0000%
# trial_size 15
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29749 rows, 31440 columns and 146390 nonzeros
# Model fingerprint: 0x485f5b34
# Variable types: 26880 continuous, 4560 integer (4560 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27365 rows and 27026 columns
# Presolve time: 0.09s
# Presolved: 2384 rows, 4414 columns, 20318 nonzeros
# Found heuristic solution: objective 3071.1066667
# Variable types: 586 continuous, 3828 integer (3828 binary)
#
# Root relaxation: objective 2.850593e+03, 5930 iterations, 0.19 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2850.5933333 2850.59333  0.00%     -    0s
#
# Explored 1 nodes (5930 simplex iterations) in 0.31 seconds (0.35 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2850.59 3071.11 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850593333333e+03, best bound 2.850593333333e+03, gap 0.0000%
# trial_size 16
# model = flex-------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28288 rows, 28848 columns and 75164 nonzeros
# Model fingerprint: 0x4aa8cf34
# Variable types: 26880 continuous, 1968 integer (1968 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27289 rows and 27027 columns
# Presolve time: 0.04s
# Presolved: 999 rows, 1821 columns, 7366 nonzeros
# Variable types: 586 continuous, 1235 integer (1235 binary)
#
# Root relaxation: objective 2.915193e+03, 1503 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2915.1933333 2915.19333  0.00%     -    0s
#
# Explored 1 nodes (1503 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2915.19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.915193333333e+03, best bound 2.915193333333e+03, gap 0.0000%
# trial_size 5
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28464 rows, 29094 columns and 81874 nonzeros
# Model fingerprint: 0xbd608d6b
# Variable types: 26880 continuous, 2214 integer (2214 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27310 rows and 27030 columns
# Presolve time: 0.10s
# Presolved: 1154 rows, 2064 columns, 8718 nonzeros
# Variable types: 586 continuous, 1478 integer (1478 binary)
#
# Root relaxation: objective 2.858773e+03, 1953 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2858.77333    0   85          - 2858.77333      -     -    0s
# H    0     0                    2941.3666667 2858.77333  2.81%     -    0s
# H    0     0                    2881.0466667 2858.77333  0.77%     -    0s
# H    0     0                    2880.3933333 2858.77333  0.75%     -    0s
# H    0     0                    2872.1933333 2858.77333  0.47%     -    0s
#      0     0 2858.77333    0  119 2872.19333 2858.77333  0.47%     -    0s
# H    0     0                    2871.1466667 2858.77333  0.43%     -    0s
#      0     0 2859.13333    0   95 2871.14667 2859.13333  0.42%     -    0s
#      0     0 2859.13333    0   95 2871.14667 2859.13333  0.42%     -    0s
# H    0     0                    2868.7733333 2859.13333  0.34%     -    0s
# H    0     0                    2864.3933333 2859.13333  0.18%     -    0s
#      0     2 2859.13333    0   95 2864.39333 2859.13333  0.18%     -    0s
# *   41    26               9    2863.4666667 2860.09333  0.12%  53.1    0s
# *   44    26               8    2861.0933331 2860.09333  0.03%  52.6    0s
#
# Cutting planes:
#   Gomory: 35
#   Zero half: 26
#
# Explored 56 nodes (6436 simplex iterations) in 0.62 seconds (0.47 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 2861.09 2863.47 2864.39 ... 2941.37
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.861093333141e+03, best bound 2.861093333141e+03, gap 0.0000%
# trial_size 6
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28640 rows, 29340 columns and 88584 nonzeros
# Model fingerprint: 0x92168a19
# Variable types: 26880 continuous, 2460 integer (2460 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27331 rows and 27033 columns
# Presolve time: 0.05s
# Presolved: 1309 rows, 2307 columns, 10070 nonzeros
# Variable types: 586 continuous, 1721 integer (1721 binary)
#
# Root relaxation: objective 2.811713e+03, 2461 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2811.71333    0   82          - 2811.71333      -     -    0s
# H    0     0                    2906.2533333 2811.71333  3.25%     -    0s
# H    0     0                    2895.9933333 2811.71333  2.91%     -    0s
# H    0     0                    2853.9000000 2811.71333  1.48%     -    0s
# H    0     0                    2851.0400000 2811.71333  1.38%     -    0s
# H    0     0                    2848.2333333 2811.71333  1.28%     -    0s
#      0     0 2811.71333    0  201 2848.23333 2811.71333  1.28%     -    0s
# H    0     0                    2840.8133333 2811.71333  1.02%     -    0s
#      0     0 2811.71333    0   84 2840.81333 2811.71333  1.02%     -    0s
#      0     0 2812.43333    0   76 2840.81333 2812.43333  1.00%     -    0s
#      0     0 2812.79333    0  137 2840.81333 2812.79333  0.99%     -    0s
# H    0     0                    2840.3066667 2812.79333  0.97%     -    0s
#      0     0 2812.91333    0  104 2840.30667 2812.91333  0.96%     -    0s
# H    0     0                    2824.2466667 2813.85333  0.37%     -    0s
#      0     0 2813.85333    0  203 2824.24667 2813.85333  0.37%     -    0s
#      0     0 2817.13000    0  112 2824.24667 2817.13000  0.25%     -    0s
#      0     0 2817.13000    0  139 2824.24667 2817.13000  0.25%     -    0s
#      0     0 2819.03000    0  122 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0  122 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0  132 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0  141 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0   66 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0   90 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0   66 2824.24667 2819.03000  0.18%     -    0s
#      0     0 2819.03000    0   58 2824.24667 2819.03000  0.18%     -    0s
# H    0     0                    2822.8400000 2819.03000  0.13%     -    0s
#      0     2 2819.03000    0   58 2822.84000 2819.03000  0.13%     -    0s
# *   10     8               4    2822.2933333 2819.74167  0.09%  70.3    0s
# *   12     8               4    2820.4400000 2819.74167  0.02%  62.2    0s
# *   64     9              11    2820.4133333 2819.79000  0.02%  23.7    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 2
#   Zero half: 131
#
# Explored 76 nodes (11701 simplex iterations) in 0.90 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2820.41 2820.44 2822.29 ... 2853.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.820413333333e+03, best bound 2.820190000000e+03, gap 0.0079%
# trial_size 7
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28816 rows, 29586 columns and 95294 nonzeros
# Model fingerprint: 0xd01baf7c
# Variable types: 26880 continuous, 2706 integer (2706 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27352 rows and 27036 columns
# Presolve time: 0.05s
# Presolved: 1464 rows, 2550 columns, 11422 nonzeros
# Found heuristic solution: objective 3050.7266667
# Variable types: 586 continuous, 1964 integer (1964 binary)
#
# Root relaxation: objective 2.771380e+03, 3233 iterations, 0.07 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2771.38000    0  165 3050.72667 2771.38000  9.16%     -    0s
# H    0     0                    2869.3666667 2771.38000  3.41%     -    0s
# H    0     0                    2864.8066667 2771.38000  3.26%     -    0s
# H    0     0                    2857.8866667 2771.38000  3.03%     -    0s
# H    0     0                    2843.1466667 2771.38000  2.52%     -    0s
# H    0     0                    2838.3200000 2771.38000  2.36%     -    0s
# H    0     0                    2837.6066667 2771.38000  2.33%     -    0s
#      0     0 2771.38000    0  245 2837.60667 2771.38000  2.33%     -    0s
# H    0     0                    2815.2466667 2771.38000  1.56%     -    0s
# H    0     0                    2801.9133333 2771.54000  1.08%     -    0s
#      0     0 2771.54000    0  128 2801.91333 2771.54000  1.08%     -    0s
#      0     0 2771.54000    0  124 2801.91333 2771.54000  1.08%     -    0s
#      0     0 2772.26000    0  247 2801.91333 2772.26000  1.06%     -    0s
#      0     0 2772.30364    0  232 2801.91333 2772.30364  1.06%     -    0s
#      0     0 2773.34444    0  195 2801.91333 2773.34444  1.02%     -    0s
# H    0     0                    2801.6600000 2773.40476  1.01%     -    0s
#      0     0 2773.40476    0  171 2801.66000 2773.40476  1.01%     -    0s
#      0     0 2777.25333    0  100 2801.66000 2777.25333  0.87%     -    0s
# H    0     0                    2801.5600000 2777.25333  0.87%     -    0s
#      0     0 2781.69000    0  175 2801.56000 2781.69000  0.71%     -    0s
# H    0     0                    2800.9066667 2781.69000  0.69%     -    0s
#      0     0 2781.69000    0  175 2800.90667 2781.69000  0.69%     -    0s
#      0     0 2782.99333    0  215 2800.90667 2782.99333  0.64%     -    0s
#      0     0 2782.99333    0  201 2800.90667 2782.99333  0.64%     -    0s
#      0     0 2783.09333    0  101 2800.90667 2783.09333  0.64%     -    0s
#      0     0 2783.09333    0  112 2800.90667 2783.09333  0.64%     -    0s
# H    0     0                    2800.3266667 2783.57333  0.60%     -    0s
# H    0     0                    2799.1533333 2783.57333  0.56%     -    0s
#      0     0 2783.57333    0  122 2799.15333 2783.57333  0.56%     -    0s
# H    0     0                    2786.9333333 2783.57333  0.12%     -    0s
# H    0     0                    2786.9066667 2783.57333  0.12%     -    0s
#      0     0 2784.08000    0   88 2786.90667 2784.08000  0.10%     -    0s
#      0     0 2785.00000    0  120 2786.90667 2785.00000  0.07%     -    0s
# *    0     0               0    2785.0000000 2785.00000  0.00%     -    0s
#
# Cutting planes:
#   MIR: 12
#   Zero half: 166
#
# Explored 1 nodes (13218 simplex iterations) in 0.99 seconds (0.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2785 2786.91 2786.93 ... 2815.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.784999999999e+03, best bound 2.784999999999e+03, gap 0.0000%
# trial_size 8
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28992 rows, 29832 columns and 102004 nonzeros
# Model fingerprint: 0x92cb32f7
# Variable types: 26880 continuous, 2952 integer (2952 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27373 rows and 27039 columns
# Presolve time: 0.05s
# Presolved: 1619 rows, 2793 columns, 12774 nonzeros
# Variable types: 586 continuous, 2207 integer (2207 binary)
#
# Root relaxation: objective 2.749340e+03, 3551 iterations, 0.09 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2749.34000    0  138          - 2749.34000      -     -    0s
# H    0     0                    2854.1466667 2749.34000  3.67%     -    0s
# H    0     0                    2849.2800000 2749.34000  3.51%     -    0s
# H    0     0                    2816.5333333 2749.34000  2.39%     -    0s
# H    0     0                    2816.0333333 2749.34000  2.37%     -    0s
# H    0     0                    2802.2000000 2749.34000  1.89%     -    0s
# H    0     0                    2799.8000000 2749.34000  1.80%     -    0s
#      0     0 2749.34000    0  317 2799.80000 2749.34000  1.80%     -    0s
# H    0     0                    2790.5066667 2749.34000  1.48%     -    0s
# H    0     0                    2789.2066667 2749.34000  1.43%     -    0s
#      0     0 2749.34000    0  302 2789.20667 2749.34000  1.43%     -    0s
#      0     0 2749.78571    0  205 2789.20667 2749.78571  1.41%     -    0s
#      0     0 2749.78571    0  220 2789.20667 2749.78571  1.41%     -    0s
#      0     0 2750.35000    0  293 2789.20667 2750.35000  1.39%     -    0s
#      0     0 2750.63000    0  268 2789.20667 2750.63000  1.38%     -    0s
#      0     0 2752.70778    0  283 2789.20667 2752.70778  1.31%     -    0s
#      0     0 2752.88111    0  265 2789.20667 2752.88111  1.30%     -    0s
#      0     0 2757.59667    0  176 2789.20667 2757.59667  1.13%     -    0s
#      0     0 2757.85667    0  210 2789.20667 2757.85667  1.12%     -    0s
#      0     0 2757.91333    0  184 2789.20667 2757.91333  1.12%     -    0s
#      0     0 2760.66667    0  146 2789.20667 2760.66667  1.02%     -    0s
# H    0     0                    2788.7466667 2760.66667  1.01%     -    0s
# H    0     0                    2787.4533333 2762.04667  0.91%     -    0s
#      0     0 2762.04667    0  197 2787.45333 2762.04667  0.91%     -    0s
# H    0     0                    2787.2533333 2762.04667  0.90%     -    0s
#      0     0 2762.04667    0  178 2787.25333 2762.04667  0.90%     -    0s
#      0     0 2762.44000    0  180 2787.25333 2762.44000  0.89%     -    0s
# H    0     0                    2786.0000000 2762.44000  0.85%     -    0s
# H    0     0                    2775.8066667 2762.44000  0.48%     -    0s
#      0     0 2762.47000    0  193 2775.80667 2762.47000  0.48%     -    0s
# H    0     0                    2766.1133333 2762.47000  0.13%     -    0s
#      0     0 2762.50000    0  193 2766.11333 2762.50000  0.13%     -    0s
# *    0     0               0    2762.5000000 2762.50000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 15
#   MIR: 8
#   Zero half: 182
#
# Explored 1 nodes (12168 simplex iterations) in 0.89 seconds (0.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2762.5 2766.11 2775.81 ... 2799.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.762499999999e+03, best bound 2.762499999999e+03, gap 0.0000%
# trial_size 9
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29168 rows, 30078 columns and 108714 nonzeros
# Model fingerprint: 0x1e997780
# Variable types: 26880 continuous, 3198 integer (3198 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27394 rows and 27042 columns
# Presolve time: 0.05s
# Presolved: 1774 rows, 3036 columns, 14126 nonzeros
# Variable types: 586 continuous, 2450 integer (2450 binary)
#
# Root relaxation: objective 2.737820e+03, 4273 iterations, 0.14 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2737.82000    0  135          - 2737.82000      -     -    0s
# H    0     0                    2836.5200000 2737.82000  3.48%     -    0s
# H    0     0                    2834.9266667 2737.82000  3.43%     -    0s
# H    0     0                    2834.0600000 2737.82000  3.40%     -    0s
# H    0     0                    2830.8400000 2737.82000  3.29%     -    0s
# H    0     0                    2813.4533333 2737.82000  2.69%     -    0s
# H    0     0                    2807.9133333 2737.82000  2.50%     -    0s
# H    0     0                    2787.2066667 2737.82000  1.77%     -    0s
#      0     0 2737.82000    0  322 2787.20667 2737.82000  1.77%     -    0s
#      0     0 2737.82000    0  183 2787.20667 2737.82000  1.77%     -    0s
#      0     0 2737.82000    0  242 2787.20667 2737.82000  1.77%     -    0s
#      0     0 2741.51778    0  233 2787.20667 2741.51778  1.64%     -    0s
#      0     0 2745.54778    0  313 2787.20667 2745.54778  1.49%     -    0s
#      0     0 2745.54778    0  317 2787.20667 2745.54778  1.49%     -    0s
#      0     0 2751.25333    0  265 2787.20667 2751.25333  1.29%     -    1s
#      0     0 2751.47667    0  110 2787.20667 2751.47667  1.28%     -    1s
#      0     0 2751.47667    0  198 2787.20667 2751.47667  1.28%     -    1s
#      0     0 2751.79000    0   24 2787.20667 2751.79000  1.27%     -    1s
# H    0     0                    2756.2600000 2751.79000  0.16%     -    1s
# *    0     0               0    2751.8200000 2751.82000  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 32
#   MIR: 1
#   Zero half: 183
#
# Explored 1 nodes (16998 simplex iterations) in 1.12 seconds (1.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 2751.82 2756.26 2787.21 ... 2836.52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.751819999999e+03, best bound 2.751819999999e+03, gap 0.0000%
# trial_size 10
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29344 rows, 30324 columns and 115424 nonzeros
# Model fingerprint: 0x61f22767
# Variable types: 26880 continuous, 3444 integer (3444 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27415 rows and 27045 columns
# Presolve time: 0.06s
# Presolved: 1929 rows, 3279 columns, 15478 nonzeros
# Variable types: 586 continuous, 2693 integer (2693 binary)
#
# Root relaxation: objective 2.729680e+03, 4226 iterations, 0.13 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2729.68000    0  297          - 2729.68000      -     -    0s
# H    0     0                    2832.6866667 2729.68000  3.64%     -    0s
# H    0     0                    2820.2266667 2729.68000  3.21%     -    0s
# H    0     0                    2811.9800000 2729.68000  2.93%     -    0s
#      0     0 2729.68000    0  481 2811.98000 2729.68000  2.93%     -    0s
#      0     0 2729.68000    0  438 2811.98000 2729.68000  2.93%     -    0s
#      0     0 2730.86556    0  302 2811.98000 2730.86556  2.88%     -    0s
#      0     0 2735.47500    0  370 2811.98000 2735.47500  2.72%     -    0s
#      0     0 2735.55611    0  357 2811.98000 2735.55611  2.72%     -    0s
# H    0     0                    2810.1000000 2747.98333  2.21%     -    0s
# H    0     0                    2795.3933333 2747.98333  1.70%     -    0s
#      0     0 2747.98333    0  317 2795.39333 2747.98333  1.70%     -    0s
# H    0     0                    2794.6333333 2747.98333  1.67%     -    0s
#      0     0 2748.12333    0  359 2794.63333 2748.12333  1.66%     -    0s
#      0     0 2748.19333    0  307 2794.63333 2748.19333  1.66%     -    0s
#      0     0 2749.22333    0  286 2794.63333 2749.22333  1.62%     -    0s
# H    0     0                    2793.8400000 2749.22333  1.60%     -    0s
#      0     0 2749.55333    0  146 2793.84000 2749.55333  1.59%     -    1s
# *    0     0               0    2749.5533333 2749.55333  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 39
#   MIR: 2
#   Zero half: 200
#
# Explored 1 nodes (17103 simplex iterations) in 1.09 seconds (1.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2749.55 2793.84 2794.63 ... 2832.69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.749553333333e+03, best bound 2.749553333333e+03, gap 0.0000%
# trial_size 11
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29520 rows, 30570 columns and 122134 nonzeros
# Model fingerprint: 0xce3e288e
# Variable types: 26880 continuous, 3690 integer (3690 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27436 rows and 27048 columns
# Presolve time: 0.06s
# Presolved: 2084 rows, 3522 columns, 16830 nonzeros
# Variable types: 586 continuous, 2936 integer (2936 binary)
#
# Root relaxation: objective 2.729220e+03, 4694 iterations, 0.16 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2729.22000    0  329          - 2729.22000      -     -    0s
# H    0     0                    2824.4400000 2729.22000  3.37%     -    0s
# H    0     0                    2817.3600000 2729.22000  3.13%     -    0s
# H    0     0                    2810.5933333 2729.22000  2.90%     -    0s
#      0     0 2729.22000    0  403 2810.59333 2729.22000  2.90%     -    0s
#      0     0 2732.32476    0  291 2810.59333 2732.32476  2.78%     -    0s
#      0     0 2737.41333    0  353 2810.59333 2737.41333  2.60%     -    0s
#      0     0 2737.41333    0  346 2810.59333 2737.41333  2.60%     -    0s
#      0     0 2747.34333    0  374 2810.59333 2747.34333  2.25%     -    0s
#      0     0 2747.39333    0  369 2810.59333 2747.39333  2.25%     -    0s
# H    0     0                    2807.8800000 2747.39333  2.15%     -    0s
# H    0     0                    2806.5466667 2747.39333  2.11%     -    0s
# H    0     0                    2805.1266667 2748.62333  2.01%     -    0s
#      0     0 2748.62333    0  291 2805.12667 2748.62333  2.01%     -    0s
# H    0     0                    2793.2466667 2748.62333  1.60%     -    0s
# H    0     0                    2790.0866667 2748.62333  1.49%     -    0s
#      0     0 2748.73333    0  330 2790.08667 2748.73333  1.48%     -    0s
#      0     0 2748.74333    0  328 2790.08667 2748.74333  1.48%     -    0s
#      0     0 2749.23333    0  226 2790.08667 2749.23333  1.46%     -    0s
#      0     0 2749.55333    0  162 2790.08667 2749.55333  1.45%     -    0s
# H    0     0                    2789.6466667 2749.55333  1.44%     -    0s
#      0     0 2749.55333    0  162 2789.64667 2749.55333  1.44%     -    0s
# H    0     0                    2751.4333320 2749.55333  0.07%     -    1s
# H    0     0                    2750.7133333 2749.55333  0.04%     -    1s
# *    0     0               0    2749.5533318 2749.55333  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 37
#   MIR: 2
#   Zero half: 221
#
# Explored 1 nodes (17857 simplex iterations) in 1.11 seconds (1.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2749.55 2750.71 2751.43 ... 2817.36
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (5.3322e-06) exceeds tolerance
# Best objective 2.749553331759e+03, best bound 2.749553331759e+03, gap 0.0000%
# trial_size 12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29696 rows, 30816 columns and 128844 nonzeros
# Model fingerprint: 0xfdc72c5e
# Variable types: 26880 continuous, 3936 integer (3936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 27457 rows and 27051 columns
# Presolve time: 0.06s
# Presolved: 2239 rows, 3765 columns, 18182 nonzeros
# Variable types: 586 continuous, 3179 integer (3179 binary)
#
# Root relaxation: objective 2.729220e+03, 5588 iterations, 0.21 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2729.22000    0  299          - 2729.22000      -     -    0s
# H    0     0                    2823.5200000 2729.22000  3.34%     -    0s
# H    0     0                    2810.4000000 2729.22000  2.89%     -    0s
# H    0     0                    2807.6266667 2729.22000  2.79%     -    0s
#      0     0 2729.22000    0  489 2807.62667 2729.22000  2.79%     -    0s
#      0     0 2729.22000    0  486 2807.62667 2729.22000  2.79%     -    0s
#      0     0 2730.97833    0  282 2807.62667 2730.97833  2.73%     -    0s
#      0     0 2736.44000    0  333 2807.62667 2736.44000  2.54%     -    0s
#      0     0 2745.71333    0  382 2807.62667 2745.71333  2.21%     -    0s
#      0     0 2745.71333    0  358 2807.62667 2745.71333  2.21%     -    0s
# H    0     0                    2806.1333333 2745.71333  2.15%     -    0s
# H    0     0                    2804.3666667 2745.71333  2.09%     -    0s
# H    0     0                    2802.0066667 2745.71333  2.01%     -    0s
#      0     0 2748.60333    0  373 2802.00667 2748.60333  1.91%     -    0s
# H    0     0                    2798.9600000 2748.60333  1.80%     -    0s
#      0     0 2748.68333    0  310 2798.96000 2748.68333  1.80%     -    1s
#      0     0 2748.99333    0  174 2798.96000 2748.99333  1.79%     -    1s
# H    0     0                    2764.3266667 2748.99333  0.55%     -    1s
#      0     0 2749.23333    0  215 2764.32667 2749.23333  0.55%     -    1s
# H    0     0                    2762.6266667 2749.23333  0.48%     -    1s
# H    0     0                    2761.3066667 2749.23333  0.44%     -    1s
#      0     0 2749.31333    0  231 2761.30667 2749.31333  0.43%     -    1s
#      0     0 2749.55333    0  178 2761.30667 2749.55333  0.43%     -    1s
# H    0     0                    2758.3400000 2749.55333  0.32%     -    1s
# *    0     0               0    2749.5533333 2749.55333  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 31
#   MIR: 2
#   GUB cover: 1
#   Zero half: 243
#
# Explored 1 nodes (19986 simplex iterations) in 1.20 seconds (1.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2749.55 2758.34 2761.31 ... 2807.63
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.749553333333e+03, best bound 2.749553333333e+03, gap 0.0000%
# trial_size 13
# model = partflex-------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28088 rows, 28800 columns and 74076 nonzeros
# Model fingerprint: 0x70a935e1
# Variable types: 26880 continuous, 1920 integer (1920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 3311.4633385
# Presolve removed 27189 rows and 27004 columns
# Presolve time: 0.03s
# Presolved: 899 rows, 1796 columns, 6766 nonzeros
# Found heuristic solution: objective 3200.2466667
# Variable types: 586 continuous, 1210 integer (1210 binary)
#
# Root relaxation: objective 3.063780e+03, 1525 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    3063.7800000 2469.32667  19.4%     -    0s
#      0     0          -    0      3063.78000 3063.78000  0.00%     -    0s
#
# Explored 1 nodes (1724 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3063.78 3200.25 3311.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.063779999999e+03, best bound 3.063779999999e+03, gap 0.0000%
# trial_size 5
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28239 rows, 29040 columns and 80650 nonzeros
# Model fingerprint: 0x1f500734
# Variable types: 26880 continuous, 2160 integer (2160 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27205 rows and 27006 columns
# Presolve time: 0.06s
# Presolved: 1034 rows, 2034 columns, 7998 nonzeros
# Found heuristic solution: objective 3183.1466667
# Variable types: 586 continuous, 1448 integer (1448 binary)
#
# Root relaxation: objective 3.024420e+03, 2075 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3024.4200000 3024.42000  0.00%     -    0s
#
# Explored 1 nodes (2075 simplex iterations) in 0.12 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3024.42 3183.15 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.024419999999e+03, best bound 3.024419999999e+03, gap 0.0000%
# trial_size 6
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28390 rows, 29280 columns and 87224 nonzeros
# Model fingerprint: 0x81cad35f
# Variable types: 26880 continuous, 2400 integer (2400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 27221 rows and 27008 columns
# Presolve time: 0.04s
# Presolved: 1169 rows, 2272 columns, 9230 nonzeros
# Found heuristic solution: objective 3192.2200000
# Variable types: 586 continuous, 1686 integer (1686 binary)
#
# Root relaxation: objective 2.986520e+03, 2907 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2986.5200000 2986.52000  0.00%     -    0s
#
# Explored 1 nodes (2907 simplex iterations) in 0.11 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2986.52 3192.22 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.986519999999e+03, best bound 2.986519999999e+03, gap 0.0000%
# trial_size 7
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28541 rows, 29520 columns and 93798 nonzeros
# Model fingerprint: 0x04a76b0e
# Variable types: 26880 continuous, 2640 integer (2640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
# ...
# Presolve removed 27285 rows and 27024 columns
# Presolve time: 0.05s
# Presolved: 1154 rows, 2064 columns, 8718 nonzeros
# Variable types: 586 continuous, 1478 integer (1478 binary)
#
# Root relaxation: objective 3.551883e+03, 1632 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3551.88333    0  102          - 3551.88333      -     -    0s
# H    0     0                    3673.1583333 3551.88333  3.30%     -    0s
# H    0     0                    3668.9416667 3551.88333  3.19%     -    0s
# H    0     0                    3571.8083333 3551.88333  0.56%     -    0s
# H    0     0                    3570.2250000 3551.88333  0.51%     -    0s
# H    0     0                    3567.1000000 3551.88333  0.43%     -    0s
#      0     0 3551.90833    0  159 3567.10000 3551.90833  0.43%     -    0s
#      0     0 3552.33333    0  213 3567.10000 3552.33333  0.41%     -    0s
#      0     0 3552.33333    0  101 3567.10000 3552.33333  0.41%     -    0s
#      0     2 3552.33333    0   86 3567.10000 3552.33333  0.41%     -    0s
# H    5     6                    3554.7833333 3552.40000  0.07%   207    0s
#
# Cutting planes:
#   Gomory: 25
#   MIR: 4
#   Zero half: 15
#
# Explored 12 nodes (4663 simplex iterations) in 0.54 seconds (0.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 3554.78 3567.1 3570.23 ... 3673.16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.554783333333e+03, best bound 3.554783333333e+03, gap 0.0000%
# trial_size 6
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28615 rows, 29334 columns and 88428 nonzeros
# Model fingerprint: 0x13a593d5
# Variable types: 26880 continuous, 2454 integer (2454 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 3989.7483333
# Presolve removed 27306 rows and 27027 columns
# Presolve time: 0.06s
# Presolved: 1309 rows, 2307 columns, 10070 nonzeros
# Found heuristic solution: objective 3822.8750000
# Variable types: 586 continuous, 1721 integer (1721 binary)
#
# Root relaxation: objective 3.487058e+03, 1937 iterations, 0.03 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3487.05833    0   80 3822.87500 3487.05833  8.78%     -    0s
# H    0     0                    3566.5750000 3487.05833  2.23%     -    0s
# H    0     0                    3556.3250000 3487.05833  1.95%     -    0s
# H    0     0                    3552.3750000 3487.05833  1.84%     -    0s
# H    0     0                    3534.4666667 3487.05833  1.34%     -    0s
# H    0     0                    3531.9166667 3487.05833  1.27%     -    0s
#      0     0 3487.05833    0  221 3531.91667 3487.05833  1.27%     -    0s
#      0     0 3487.20833    0   90 3531.91667 3487.20833  1.27%     -    0s
#      0     0 3487.20833    0  139 3531.91667 3487.20833  1.27%     -    0s
#      0     0 3487.20833    0  122 3531.91667 3487.20833  1.27%     -    0s
#      0     0 3488.10833    0   78 3531.91667 3488.10833  1.24%     -    0s
# H    0     0                    3503.9000000 3488.25833  0.45%     -    0s
#      0     0 3488.25833    0   74 3503.90000 3488.25833  0.45%     -    0s
#      0     0 3488.55833    0  162 3503.90000 3488.55833  0.44%     -    0s
#      0     0 3488.55833    0  211 3503.90000 3488.55833  0.44%     -    0s
# H    0     0                    3500.3833333 3491.83333  0.24%     -    0s
# H    0     0                    3500.3500000 3491.83333  0.24%     -    0s
#      0     0 3491.83333    0   68 3500.35000 3491.83333  0.24%     -    0s
#      0     0 3496.20417    0  116 3500.35000 3496.20417  0.12%     -    0s
#      0     0 3496.20417    0  123 3500.35000 3496.20417  0.12%     -    0s
#      0     0 3496.20417    0  107 3500.35000 3496.20417  0.12%     -    0s
#      0     0 3496.20417    0   82 3500.35000 3496.20417  0.12%     -    0s
#      0     0 3496.55000    0   38 3500.35000 3496.55000  0.11%     -    0s
#      0     0 3497.37083    0  135 3500.35000 3497.37083  0.09%     -    0s
# *    0     0               0    3497.9333333 3497.93333  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 146
#
# Explored 1 nodes (11895 simplex iterations) in 0.80 seconds (0.60 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3497.93 3500.35 3500.38 ... 3989.75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.497933333333e+03, best bound 3.497933333333e+03, gap 0.0000%
# trial_size 7
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28791 rows, 29580 columns and 95138 nonzeros
# Model fingerprint: 0x39d23a76
# Variable types: 26880 continuous, 2700 integer (2700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 3983.1208333
# Presolve removed 27327 rows and 27030 columns
# Presolve time: 0.07s
# Presolved: 1464 rows, 2550 columns, 11422 nonzeros
# Found heuristic solution: objective 3783.6416667
# Variable types: 586 continuous, 1964 integer (1964 binary)
#
# Root relaxation: objective 3.430642e+03, 2945 iterations, 0.07 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3430.64167    0  153 3783.64167 3430.64167  9.33%     -    0s
# H    0     0                    3534.6583333 3430.64167  2.94%     -    0s
# H    0     0                    3527.6083333 3430.64167  2.75%     -    0s
# H    0     0                    3515.2083333 3430.64167  2.41%     -    0s
# H    0     0                    3514.0166667 3430.64167  2.37%     -    0s
# H    0     0                    3458.1500000 3430.64167  0.80%     -    0s
#      0     0 3430.64167    0  225 3458.15000 3430.64167  0.80%     -    0s
#      0     0 3430.64167    0  206 3458.15000 3430.64167  0.80%     -    0s
#      0     0 3430.70833    0  145 3458.15000 3430.70833  0.79%     -    0s
#      0     0 3432.36944    0  216 3458.15000 3432.36944  0.75%     -    0s
#      0     0 3432.36944    0  190 3458.15000 3432.36944  0.75%     -    0s
#      0     0 3433.62500    0  163 3458.15000 3433.62500  0.71%     -    0s
#      0     0 3438.76042    0  151 3458.15000 3438.76042  0.56%     -    0s
#      0     0 3438.76042    0  147 3458.15000 3438.76042  0.56%     -    0s
#      0     0 3442.74167    0  174 3458.15000 3442.74167  0.45%     -    0s
#      0     0 3443.71875    0  182 3458.15000 3443.71875  0.42%     -    0s
#      0     0 3443.90833    0  181 3458.15000 3443.90833  0.41%     -    0s
#      0     0 3445.59792    0  215 3458.15000 3445.59792  0.36%     -    0s
#      0     0 3445.59792    0  217 3458.15000 3445.59792  0.36%     -    0s
#      0     0 3445.78750    0  158 3458.15000 3445.78750  0.36%     -    0s
#      0     0 3446.00833    0  114 3458.15000 3446.00833  0.35%     -    0s
#      0     0 3446.00833    0  214 3458.15000 3446.00833  0.35%     -    0s
#      0     0 3446.51667    0  110 3458.15000 3446.51667  0.34%     -    1s
#      0     0 3446.51667    0  174 3458.15000 3446.51667  0.34%     -    1s
#      0     0 3447.28333    0   24 3458.15000 3447.28333  0.31%     -    1s
# H    0     0                    3453.5416667 3447.28333  0.18%     -    1s
#      0     0 3447.28333    0   28 3453.54167 3447.28333  0.18%     -    1s
# H    0     0                    3453.3416667 3447.28333  0.18%     -    1s
#      0     0 3447.28333    0   26 3453.34167 3447.28333  0.18%     -    1s
#      0     0 3447.28333    0   24 3453.34167 3447.28333  0.18%     -    1s
# H    0     0                    3448.8750000 3447.28333  0.05%     -    1s
# H    0     0                    3447.6666667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0   83 3447.66667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0  102 3447.66667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0  120 3447.66667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0   74 3447.66667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0  112 3447.66667 3447.28333  0.01%     -    1s
#      0     0 3447.28333    0  159 3447.66667 3447.28333  0.01%     -    1s
#      0     0     cutoff    0      3447.66667 3447.66667  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 2
#   Zero half: 76
#
# Explored 1 nodes (16767 simplex iterations) in 1.50 seconds (1.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3447.67 3448.88 3453.34 ... 3983.12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.447666666667e+03, best bound 3.447666666667e+03, gap 0.0000%
# trial_size 8
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28967 rows, 29826 columns and 101848 nonzeros
# Model fingerprint: 0xe5ddfb12
# Variable types: 26880 continuous, 2946 integer (2946 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 27348 rows and 27033 columns
# Presolve time: 0.09s
# Presolved: 1619 rows, 2793 columns, 12774 nonzeros
# Variable types: 586 continuous, 2207 integer (2207 binary)
#
# Root relaxation: objective 3.397092e+03, 3068 iterations, 0.08 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3397.09167    0  148          - 3397.09167      -     -    0s
# H    0     0                    3521.3583333 3397.09167  3.53%     -    0s
# H    0     0                    3520.6833333 3397.09167  3.51%     -    0s
# H    0     0                    3487.5750000 3397.09167  2.59%     -    0s
# H    0     0                    3485.6500000 3397.09167  2.54%     -    0s
# H    0     0                    3469.8083333 3397.09167  2.10%     -    0s
#      0     0 3397.09167    0  295 3469.80833 3397.09167  2.10%     -    0s
# H    0     0                    3469.3833333 3397.09167  2.08%     -    0s
#      0     0 3397.09167    0  266 3469.38333 3397.09167  2.08%     -    0s
#      0     0 3397.18167    0  219 3469.38333 3397.18167  2.08%     -    0s
#      0     0 3397.18167    0  221 3469.38333 3397.18167  2.08%     -    0s
# H    0     0                    3459.5833333 3397.44510  1.80%     -    0s
#      0     0 3397.44510    0  315 3459.58333 3397.44510  1.80%     -    0s
# H    0     0                    3453.1083333 3397.44510  1.61%     -    0s
#      0     0 3397.44510    0  321 3453.10833 3397.44510  1.61%     -    0s
# H    0     0                    3446.1416667 3398.95417  1.37%     -    0s
#      0     0 3398.95417    0  266 3446.14167 3398.95417  1.37%     -    0s
# H    0     0                    3439.4166667 3398.95417  1.18%     -    0s
# H    0     0                    3417.9250000 3398.95417  0.56%     -    0s
#      0     0 3398.95417    0  278 3417.92500 3398.95417  0.56%     -    0s
# H    0     0                    3414.3666667 3400.84167  0.40%     -    0s
#      0     0 3400.84167    0  225 3414.36667 3400.84167  0.40%     -    0s
#      0     0 3405.15556    0  233 3414.36667 3405.15556  0.27%     -    0s
#      0     0 3405.42639    0  217 3414.36667 3405.42639  0.26%     -    1s
#      0     0 3412.55833    0  106 3414.36667 3412.55833  0.05%     -    1s
#      0     0 3413.54167    0  104 3414.36667 3413.54167  0.02%     -    1s
#      0     0 3413.54167    0  178 3414.36667 3413.54167  0.02%     -    1s
# *    0     0               0    3413.5416667 3413.54167  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 13
#   MIR: 2
#   StrongCG: 2
#   Zero half: 207
#
# Explored 1 nodes (11021 simplex iterations) in 1.19 seconds (0.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3413.54 3414.37 3417.93 ... 3485.65
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.413541666667e+03, best bound 3.413541666667e+03, gap 0.0000%
# trial_size 9
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29143 rows, 30072 columns and 108558 nonzeros
# Model fingerprint: 0x9ffe9f0a
# Variable types: 26880 continuous, 3192 integer (3192 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 27369 rows and 27036 columns
# Presolve time: 0.06s
# Presolved: 1774 rows, 3036 columns, 14126 nonzeros
# Variable types: 586 continuous, 2450 integer (2450 binary)
#
# Root relaxation: objective 3.376692e+03, 3724 iterations, 0.14 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3376.69167    0  149          - 3376.69167      -     -    0s
# H    0     0                    3471.5000000 3376.69167  2.73%     -    0s
# H    0     0                    3463.9750000 3376.69167  2.52%     -    0s
# H    0     0                    3461.6083333 3376.69167  2.45%     -    0s
# H    0     0                    3454.0333333 3376.69167  2.24%     -    0s
# H    0     0                    3438.7583333 3376.69167  1.80%     -    0s
#      0     0 3376.69167    0  335 3438.75833 3376.69167  1.80%     -    0s
# H    0     0                    3423.1750000 3376.69167  1.36%     -    0s
#      0     0 3376.69167    0  231 3423.17500 3376.69167  1.36%     -    0s
# H    0     0                    3420.6750000 3376.69167  1.29%     -    0s
#      0     0 3376.69167    0  288 3420.67500 3376.69167  1.29%     -    0s
#      0     0 3377.68750    0  234 3420.67500 3377.68750  1.26%     -    0s
#      0     0 3377.68750    0  224 3420.67500 3377.68750  1.26%     -    0s
#      0     0 3386.26944    0  311 3420.67500 3386.26944  1.01%     -    1s
#      0     0 3386.26944    0  304 3420.67500 3386.26944  1.01%     -    1s
#      0     0 3393.60417    0  184 3420.67500 3393.60417  0.79%     -    1s
#      0     0 3394.19167    0  236 3420.67500 3394.19167  0.77%     -    1s
# H    0     0                    3414.9666667 3394.19167  0.61%     -    1s
# H    0     0                    3409.8416667 3394.19167  0.46%     -    1s
# *    0     0               0    3394.1916667 3394.19167  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Zero half: 201
#   Mod-K: 1
#
# Explored 1 nodes (15968 simplex iterations) in 1.20 seconds (1.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3394.19 3409.84 3414.97 ... 3471.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.394191666667e+03, best bound 3.394191666667e+03, gap 0.0000%
# trial_size 10
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 29319 rows, 30318 columns and 115268 nonzeros
# Model fingerprint: 0xe15cc4c3
# Variable types: 26880 continuous, 3438 integer (3438 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 27390 rows and 27039 columns
# Presolve time: 0.07s
# Presolved: 1929 rows, 3279 columns, 15478 nonzeros
# Variable types: 586 continuous, 2693 integer (2693 binary)
