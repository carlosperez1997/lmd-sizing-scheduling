# %%
from glob import glob
from os import path
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']
# 16

# %%
#Subset to France

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('lyon') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt_subset)
# Out:
# ['lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00']

# %%
def dict_append_workforce(dict_, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, workforce_size, objvalprev, objval, objvalnext):
    dict_['instance_file_base'].append(base_file)
    dict_['city'].append(city)
    dict_['demand_baseline'].append(demand_baseline)
    dict_['model'].append(model)
    dict_['max_n_shifts'].append(max_n_shifts)
    dict_['outsourcing_cost_multiplier'].append(OC)
    dict_['regional_multiplier'].append(RM)
    dict_['global_multiplier'].append(GM)
    dict_['workforce_size_region0'].append(workforce_size)
    dict_['objective_value_prev'].append(objvalprev)
    dict_['objective_value'].append(objval)
    dict_['objective_value_next'].append(objvalnext)
    return dict_

# %%
#Code that determines optimal workforce size

MAX_TRIES = 120

RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

#for base_file in list_city_dt_subset:
for base_file in ['lyon_db=4.00']:
    print(base_file+'============================================')

    if f'{base_file}.json' not in os.listdir(r'../workforce_size'):

        list_results = []

        #create inputs to run a trial workforce size
        weekday_ = f'{base_file}_dt=doublepeak.json'
        weekend_ = f'{base_file}_dt=uniform.json'

        instance_file_weekday = f"../instances/{weekday_}"
        instance_file_weekend = f"../instances/{weekend_}"

        shift_file_weekday = f"../shifts/{weekday_}"
        shift_file_weekend = f"../shifts/{weekend_}"

        #create dictionary for evaluating optimal workforce size
        workforce_out = f"../workforce_size/{base_file}.json"
        dict_out = {
            'instance_file_base':[],
            'city':[],
            'demand_baseline':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'workforce_size_region0':[],
            'objective_value_prev':[],
            'objective_value':[],
            'objective_value_next':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'

        city_match = re.search(city_pattern, base_file)
        db_match = re.search(db_pattern, base_file)

        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None

        #Set min_tries based on demand_baseline
        if demand_baseline == 0.5:
            MIN_TRIES = 5
        elif demand_baseline == 1.0:
            MIN_TRIES = 5
        elif demand_baseline == 2.0:
            MIN_TRIES = 5
        elif demand_baseline == 4.0:
            MIN_TRIES = 70

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
        # for OC in [1.2]:
            print(f'OC = {OC}++++++++++++++++++++++')
            for model in ['fixed', 'flex', 'partflex']:
            # for model in ['fixed']:
                print(f'model = {model}-------------------------')
                if model == 'partflex':
                    for max_n_shifts in range(2,5):
                    # for max_n_shifts in [4]:
                        objvalprev = 1e8
                        objval = 1e7
                        for trial_size in range(MIN_TRIES, MAX_TRIES):
                            workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                            if (objval < objvalprev)&(np.isnan(objval) == False):
                                objvalprev = objval
                                dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
                                objval = dict_results['objective_value'][0]
                                print("trial_size",trial_size)
                                df_ = pd.DataFrame(dict_results)
                                df_['workforce_size_trial'] = trial_size
                                list_results.append(df_)
                            else:
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size-1, np.nan, objvalprev, objval)
                                break
                            if trial_size == int(MAX_TRIES-1):
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size, objvalprev, objval, np.nan)
                else:
                    objvalprev = 1e8
                    objval = 1e7
                    for trial_size in range(MIN_TRIES, MAX_TRIES):
                        workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                        if (objval < objvalprev)&(np.isnan(objval) == False):
                            objvalprev = objval
                            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
                            objval = dict_results['objective_value'][0]
                            print("trial_size",trial_size)
                            df_ = pd.DataFrame(dict_results)
                            df_['workforce_size_trial'] = trial_size
                            list_results.append(df_)
                        else: 
                            #keep track of optimal (trial size - 1)
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size-1, np.nan, objvalprev, objval)
                            break
                        if trial_size == int(MAX_TRIES-1):
                            #keep track of optimal
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size, objvalprev, objval, np.nan)
        #export optimal workforce size values
        with open(workforce_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
        df_trials = pd.concat(list_results, ignore_index = True)
        df_trials.to_excel(f'../workforce_size/{base_file}_all_trials.xlsx', index = False)
# Out:
# lyon_db=4.00============================================
# OC = 1.2++++++++++++++++++++++
# model = fixed-------------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 37903 rows, 44400 columns and 581416 nonzeros
# Model fingerprint: 0xbc2f2ae8
# Variable types: 26880 continuous, 17520 integer (17520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28229 rows and 26307 columns
# Presolve time: 0.22s
# Presolved: 9674 rows, 18093 columns, 87673 nonzeros
# Found heuristic solution: objective 26105.826884
# Variable types: 1433 continuous, 16660 integer (16660 binary)
#
# Root relaxation: objective 2.461618e+04, 23752 iterations, 2.12 seconds (2.64 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24616.175037 24616.1750  0.00%     -    2s
#
# Explored 1 nodes (27310 simplex iterations) in 2.76 seconds (3.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24616.2 26105.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.461617503695e+04, best bound 2.461617503695e+04, gap 0.0000%
# trial_size 70
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38054 rows, 44640 columns and 589028 nonzeros
# Model fingerprint: 0x483f45f6
# Variable types: 26880 continuous, 17760 integer (17760 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28245 rows and 26309 columns
# Presolve time: 0.20s
# Presolved: 9809 rows, 18331 columns, 88905 nonzeros
# Found heuristic solution: objective 25980.833706
# Variable types: 1433 continuous, 16898 integer (16898 binary)
#
# Root relaxation: objective 2.459598e+04, 23758 iterations, 1.89 seconds (2.42 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24595.984055 24595.9841  0.00%     -    2s
#
# Explored 1 nodes (27416 simplex iterations) in 2.43 seconds (3.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24596 25980.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.459598405548e+04, best bound 2.459598405548e+04, gap 0.0000%
# trial_size 71
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38205 rows, 44880 columns and 596640 nonzeros
# Model fingerprint: 0x23031e45
# Variable types: 26880 continuous, 18000 integer (18000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28261 rows and 26311 columns
# Presolve time: 0.21s
# Presolved: 9944 rows, 18569 columns, 90137 nonzeros
# Found heuristic solution: objective 25955.280531
# Variable types: 1433 continuous, 17136 integer (17136 binary)
#
# Root relaxation: objective 2.457732e+04, 24201 iterations, 1.84 seconds (2.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24577.317325 24577.3173  0.00%     -    2s
#
# Explored 1 nodes (27992 simplex iterations) in 2.40 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24577.3 25955.3 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.457731732533e+04, best bound 2.457731732533e+04, gap 0.0000%
# trial_size 72
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38356 rows, 45120 columns and 604252 nonzeros
# Model fingerprint: 0xe25db857
# Variable types: 26880 continuous, 18240 integer (18240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28277 rows and 26313 columns
# Presolve time: 0.21s
# Presolved: 10079 rows, 18807 columns, 91369 nonzeros
# Found heuristic solution: objective 26003.900592
# Variable types: 1433 continuous, 17374 integer (17374 binary)
#
# Root relaxation: objective 2.455994e+04, 24579 iterations, 1.95 seconds (2.52 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24559.942438 24559.9424  0.00%     -    2s
#
# Explored 1 nodes (28991 simplex iterations) in 2.63 seconds (3.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24559.9 26003.9 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.455994243806e+04, best bound 2.455994243806e+04, gap 0.0000%
# trial_size 73
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38507 rows, 45360 columns and 611864 nonzeros
# Model fingerprint: 0x8ea3da92
# Variable types: 26880 continuous, 18480 integer (18480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28293 rows and 26315 columns
# Presolve time: 0.22s
# Presolved: 10214 rows, 19045 columns, 92601 nonzeros
# Found heuristic solution: objective 25931.066129
# Variable types: 1433 continuous, 17612 integer (17612 binary)
#
# Root relaxation: objective 2.454410e+04, 25399 iterations, 2.19 seconds (2.74 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24544.099455 24544.0995  0.00%     -    2s
#
# Explored 1 nodes (29677 simplex iterations) in 2.85 seconds (3.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24544.1 25931.1 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.454409945500e+04, best bound 2.454409945500e+04, gap 0.0000%
# trial_size 74
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38658 rows, 45600 columns and 619476 nonzeros
# Model fingerprint: 0x682ee949
# Variable types: 26880 continuous, 18720 integer (18720 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28309 rows and 26317 columns
# Presolve time: 0.23s
# Presolved: 10349 rows, 19283 columns, 93833 nonzeros
# Found heuristic solution: objective 25839.223120
# Variable types: 1433 continuous, 17850 integer (17850 binary)
#
# Root relaxation: objective 2.452883e+04, 27565 iterations, 2.76 seconds (3.56 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    24528.833994 22110.8899  9.86%     -    3s
#      0     0          -    0      24528.8340 24528.8340  0.00%     -    3s
#
# Explored 1 nodes (30860 simplex iterations) in 3.35 seconds (4.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24528.8 25839.2 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.452883399436e+04, best bound 2.452883399436e+04, gap 0.0000%
# trial_size 75
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38809 rows, 45840 columns and 627088 nonzeros
# Model fingerprint: 0xde493864
# Variable types: 26880 continuous, 18960 integer (18960 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28325 rows and 26319 columns
# Presolve time: 0.23s
# Presolved: 10484 rows, 19521 columns, 95065 nonzeros
# Found heuristic solution: objective 25879.691152
# Variable types: 1433 continuous, 18088 integer (18088 binary)
#
# Root relaxation: objective 2.451512e+04, 27513 iterations, 2.57 seconds (3.32 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24515.124333 24515.1243  0.00%     -    3s
#
# Explored 1 nodes (31209 simplex iterations) in 3.21 seconds (4.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24515.1 25879.7 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.451512433313e+04, best bound 2.451512433313e+04, gap 0.0000%
# trial_size 76
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38960 rows, 46080 columns and 634700 nonzeros
# Model fingerprint: 0x66f87221
# Variable types: 26880 continuous, 19200 integer (19200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28341 rows and 26321 columns
# Presolve time: 0.23s
# Presolved: 10619 rows, 19759 columns, 96297 nonzeros
# Found heuristic solution: objective 25850.879294
# Variable types: 1433 continuous, 18326 integer (18326 binary)
#
# Root relaxation: objective 2.450315e+04, 25898 iterations, 2.22 seconds (2.79 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24503.153182 24503.1532  0.00%     -    2s
#
# Explored 1 nodes (29608 simplex iterations) in 2.78 seconds (3.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24503.2 25850.9 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.450315318162e+04, best bound 2.450315318162e+04, gap 0.0000%
# trial_size 77
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39111 rows, 46320 columns and 642312 nonzeros
# Model fingerprint: 0x59768d6e
# Variable types: 26880 continuous, 19440 integer (19440 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28357 rows and 26323 columns
# Presolve time: 0.22s
# Presolved: 10754 rows, 19997 columns, 97529 nonzeros
# Found heuristic solution: objective 25764.792219
# Variable types: 1433 continuous, 18564 integer (18564 binary)
#
# Root relaxation: objective 2.449197e+04, 28220 iterations, 2.42 seconds (3.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    24491.966931 22110.8899  9.72%     -    2s
#      0     0          -    0      24491.9669 24491.9669  0.00%     -    3s
#
# Explored 1 nodes (31864 simplex iterations) in 3.10 seconds (4.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24492 25764.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.449196693142e+04, best bound 2.449196693142e+04, gap 0.0000%
# trial_size 78
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39262 rows, 46560 columns and 649924 nonzeros
# Model fingerprint: 0x14e864b2
# Variable types: 26880 continuous, 19680 integer (19680 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28373 rows and 26325 columns
# Presolve time: 0.23s
# Presolved: 10889 rows, 20235 columns, 98761 nonzeros
# Found heuristic solution: objective 25848.015321
# Variable types: 1433 continuous, 18802 integer (18802 binary)
#
# Root relaxation: objective 2.448353e+04, 27704 iterations, 1.90 seconds (2.52 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24483.526905 24483.5269  0.00%     -    2s
#
# Explored 1 nodes (32174 simplex iterations) in 2.67 seconds (3.62 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24483.5 25848 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.448352690491e+04, best bound 2.448352690491e+04, gap 0.0000%
# trial_size 79
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39413 rows, 46800 columns and 657536 nonzeros
# Model fingerprint: 0x41a92889
# Variable types: 26880 continuous, 19920 integer (19920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28389 rows and 26327 columns
# Presolve time: 0.24s
# Presolved: 11024 rows, 20473 columns, 99993 nonzeros
# Found heuristic solution: objective 25650.776236
# Variable types: 1433 continuous, 19040 integer (19040 binary)
#
# Root relaxation: objective 2.447677e+04, 30310 iterations, 3.84 seconds (5.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24476.769251 24476.7693  0.00%     -    4s
#
# Explored 1 nodes (33682 simplex iterations) in 4.45 seconds (5.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24476.8 25650.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.447676925125e+04, best bound 2.447676925125e+04, gap 0.0000%
# trial_size 80
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39564 rows, 47040 columns and 665148 nonzeros
# Model fingerprint: 0x74f92dca
# Variable types: 26880 continuous, 20160 integer (20160 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28405 rows and 26329 columns
# Presolve time: 0.24s
# Presolved: 11159 rows, 20711 columns, 101225 nonzeros
# Found heuristic solution: objective 25778.539945
# Variable types: 1433 continuous, 19278 integer (19278 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.447201e+04, 16747 iterations, 0.32 seconds (0.39 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24472.012289 24472.0123  0.00%     -    1s
#
# Explored 1 nodes (22097 simplex iterations) in 1.26 seconds (1.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24472 25778.5 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.447201228888e+04, best bound 2.447201228888e+04, gap 0.0000%
# trial_size 81
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39715 rows, 47280 columns and 672760 nonzeros
# Model fingerprint: 0x6a994563
# Variable types: 26880 continuous, 20400 integer (20400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28421 rows and 26331 columns
# Presolve time: 0.24s
# Presolved: 11294 rows, 20949 columns, 102457 nonzeros
# Found heuristic solution: objective 25810.454968
# Variable types: 1433 continuous, 19516 integer (19516 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446836e+04, 16537 iterations, 0.24 seconds (0.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24468.363299 24468.3633  0.00%     -    1s
#
# Explored 1 nodes (21539 simplex iterations) in 1.08 seconds (1.53 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24468.4 25810.5 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446836329942e+04, best bound 2.446836329942e+04, gap 0.0000%
# trial_size 82
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39866 rows, 47520 columns and 680372 nonzeros
# Model fingerprint: 0x143eaa62
# Variable types: 26880 continuous, 20640 integer (20640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28437 rows and 26333 columns
# Presolve time: 0.24s
# Presolved: 11429 rows, 21187 columns, 103689 nonzeros
# Found heuristic solution: objective 25708.211878
# Variable types: 1433 continuous, 19754 integer (19754 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446542e+04, 16738 iterations, 0.30 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24465.423841 24465.4238  0.00%     -    1s
#
# Explored 1 nodes (21262 simplex iterations) in 1.14 seconds (1.53 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24465.4 25708.2 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446542384065e+04, best bound 2.446542384065e+04, gap 0.0000%
# trial_size 83
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40017 rows, 47760 columns and 687984 nonzeros
# Model fingerprint: 0xc2a10c2d
# Variable types: 26880 continuous, 20880 integer (20880 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28453 rows and 26335 columns
# Presolve time: 0.25s
# Presolved: 11564 rows, 21425 columns, 104921 nonzeros
# Found heuristic solution: objective 25665.035724
# Variable types: 1433 continuous, 19992 integer (19992 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446316e+04, 16779 iterations, 0.26 seconds (0.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24463.163841 24463.1638  0.00%     -    1s
#
# Explored 1 nodes (21698 simplex iterations) in 1.13 seconds (1.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24463.2 25665 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446316384073e+04, best bound 2.446316384073e+04, gap 0.0000%
# trial_size 84
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40168 rows, 48000 columns and 695596 nonzeros
# Model fingerprint: 0xdcce658f
# Variable types: 26880 continuous, 21120 integer (21120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28469 rows and 26337 columns
# Presolve time: 0.25s
# Presolved: 11699 rows, 21663 columns, 106153 nonzeros
# Found heuristic solution: objective 25644.283006
# Variable types: 1433 continuous, 20230 integer (20230 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446193e+04, 17553 iterations, 0.32 seconds (0.38 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24461.925852 24461.9259  0.00%     -    1s
#
# Explored 1 nodes (22820 simplex iterations) in 1.30 seconds (1.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24461.9 25644.3 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446192585156e+04, best bound 2.446192585156e+04, gap 0.0000%
# trial_size 85
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40319 rows, 48240 columns and 703208 nonzeros
# Model fingerprint: 0x051c9af7
# Variable types: 26880 continuous, 21360 integer (21360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28485 rows and 26339 columns
# Presolve time: 0.28s
# Presolved: 11834 rows, 21901 columns, 107385 nonzeros
# Found heuristic solution: objective 25644.334052
# Variable types: 1433 continuous, 20468 integer (20468 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446175e+04, 18042 iterations, 0.28 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24461.750018 24461.7500  0.00%     -    1s
#
# Explored 1 nodes (22959 simplex iterations) in 1.24 seconds (1.73 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24461.8 25644.3 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446175001752e+04, best bound 2.446175001752e+04, gap 0.0000%
# trial_size 86
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40470 rows, 48480 columns and 710820 nonzeros
# Model fingerprint: 0xf56fe348
# Variable types: 26880 continuous, 21600 integer (21600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28501 rows and 26341 columns
# Presolve time: 0.27s
# Presolved: 11969 rows, 22139 columns, 108617 nonzeros
# Found heuristic solution: objective 25526.095005
# Variable types: 1433 continuous, 20706 integer (20706 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.446175e+04, 18228 iterations, 0.28 seconds (0.33 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24461.750018 24461.7500  0.00%     -    1s
#
# Explored 1 nodes (23695 simplex iterations) in 1.25 seconds (1.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24461.8 25526.1 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446175001752e+04, best bound 2.446175001752e+04, gap 0.0000%
# trial_size 87
# model = flex-------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39728 rows, 44838 columns and 591344 nonzeros
# Model fingerprint: 0x0694364d
# Variable types: 26880 continuous, 17958 integer (17958 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Presolve removed 28654 rows and 26395 columns
# Presolve time: 0.21s
# Presolved: 11074 rows, 18443 columns, 96073 nonzeros
# Variable types: 1433 continuous, 17010 integer (17010 binary)
# Found heuristic solution: objective 30562.948113
#
# Root relaxation: objective 2.385510e+04, 20511 iterations, 2.92 seconds (4.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23855.1035    0 1359 30562.9481 23855.1035  21.9%     -    5s
# H    0     0                    30537.668256 23855.1035  21.9%     -    5s
# H    0     0                    29458.259540 23855.1035  19.0%     -    5s
#      0     0 23855.1035    0 1798 29458.2595 23855.1035  19.0%     -    5s
# H    0     0                    29444.554720 23855.1035  19.0%     -    6s
#      0     0 23855.6815    0 1317 29444.5547 23855.6815  19.0%     -    8s
# H    0     0                    28666.024688 23855.6815  16.8%     -    8s
#      0     0 23857.6175    0 1442 28666.0247 23857.6175  16.8%     -    9s
#      0     0 23857.6175    0 1486 28666.0247 23857.6175  16.8%     -    9s
#      0     0 23952.3816    0 1336 28666.0247 23952.3816  16.4%     -   10s
# H    0     0                    28663.098384 23952.3816  16.4%     -   10s
# H    0     0                    24265.093416 23952.3816  1.29%     -   10s
#      0     0 23954.7150    0 1355 24265.0934 23954.7150  1.28%     -   10s
#      0     0 23954.7150    0 1336 24265.0934 23954.7150  1.28%     -   10s
#      0     0 24025.2708    0  529 24265.0934 24025.2708  0.99%     -   11s
# H    0     0                    24263.099448 24025.2708  0.98%     -   11s
# H    0     0                    24235.608537 24025.2708  0.87%     -   11s
#      0     0 24025.2708    0  544 24235.6085 24025.2708  0.87%     -   11s
#      0     0 24025.2708    0  432 24235.6085 24025.2708  0.87%     -   12s
# H    0     0                    24152.912647 24025.2708  0.53%     -   12s
#      0     0 24025.2708    0  414 24152.9126 24025.2708  0.53%     -   12s
#      0     0 24025.2708    0  111 24152.9126 24025.2708  0.53%     -   15s
# H    0     0                    24031.902971 24025.2708  0.03%     -   15s
# H    0     0                    24031.288245 24025.2708  0.03%     -   15s
#      0     0 24025.2708    0  131 24031.2882 24025.2708  0.03%     -   15s
#      0     0 24025.2708    0  130 24031.2882 24025.2708  0.03%     -   18s
# H    0     0                    24027.152346 24025.2708  0.01%     -   18s
#
# Cutting planes:
#   Gomory: 202
#   Cover: 3
#   MIR: 5
#   StrongCG: 1
#   GUB cover: 4
#   Zero half: 1117
#
# Explored 1 nodes (177631 simplex iterations) in 18.69 seconds (24.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 24027.2 24031.3 24031.9 ... 29444.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.402715234647e+04, best bound 2.402527076086e+04, gap 0.0078%
# trial_size 70
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 39904 rows, 45084 columns and 599092 nonzeros
# Model fingerprint: 0xa79cc23c
# Variable types: 26880 continuous, 18204 integer (18204 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28675 rows and 26398 columns
# Presolve time: 0.23s
# Presolved: 11229 rows, 18686 columns, 97425 nonzeros
# Found heuristic solution: objective 25512.817496
# Variable types: 1433 continuous, 17253 integer (17253 binary)
#
# Root relaxation: objective 2.385510e+04, 18712 iterations, 2.19 seconds (3.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23855.1035    0 1435 25512.8175 23855.1035  6.50%     -    3s
# H    0     0                    25485.528994 23855.1035  6.40%     -    4s
# H    0     0                    25226.112794 23855.1035  5.43%     -    4s
# H    0     0                    24467.859046 23855.1035  2.50%     -    4s
# H    0     0                    24458.308561 23855.1035  2.47%     -    4s
# H    0     0                    24422.456172 23855.1035  2.32%     -    4s
#      0     0 23855.1035    0 1718 24422.4562 23855.1035  2.32%     -    4s
# H    0     0                    24421.923791 23855.1035  2.32%     -    5s
#      0     0 23855.1035    0 1335 24421.9238 23855.1035  2.32%     -    7s
# H    0     0                    24392.217203 23855.1035  2.20%     -    7s
#      0     0 23855.1035    0 1418 24392.2172 23855.1035  2.20%     -    7s
#      0     0 23956.3816    0  658 24392.2172 23956.3816  1.79%     -    9s
# H    0     0                    24392.032346 23956.3816  1.79%     -    9s
#      0     0 23958.3816    0  762 24392.0323 23958.3816  1.78%     -   10s
#      0     0 23958.3816    0  800 24392.0323 23958.3816  1.78%     -   10s
#      0     0 24022.4845    0  436 24392.0323 24022.4845  1.52%     -   10s
# H    0     0                    24058.235746 24022.4845  0.15%     -   11s
# H    0     0                    24044.764487 24022.4845  0.09%     -   11s
#      0     0 24022.4845    0  353 24044.7645 24022.4845  0.09%     -   11s
#      0     0 24022.4845    0  250 24044.7645 24022.4845  0.09%     -   11s
# H    0     0                    24024.328287 24022.4845  0.01%     -   11s
#
# Cutting planes:
#   Gomory: 181
#   Cover: 4
#   MIR: 25
#   StrongCG: 3
#   GUB cover: 7
#   Zero half: 1058
#
# Explored 1 nodes (133350 simplex iterations) in 11.79 seconds (15.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 24024.3 24044.8 24058.2 ... 25226.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.402432828720e+04, best bound 2.402248450659e+04, gap 0.0077%
# trial_size 71
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40080 rows, 45330 columns and 606840 nonzeros
# Model fingerprint: 0xdf63559e
# Variable types: 26880 continuous, 18450 integer (18450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Presolve removed 28696 rows and 26401 columns
# Presolve time: 0.23s
# Presolved: 11384 rows, 18929 columns, 98777 nonzeros
# Variable types: 1433 continuous, 17496 integer (17496 binary)
# Found heuristic solution: objective 30610.948113
#
# Root relaxation: objective 2.385510e+04, 20673 iterations, 3.09 seconds (4.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23855.1035    0 1449 30610.9481 23855.1035  22.1%     -    5s
# H    0     0                    24475.295288 23855.1035  2.53%     -    5s
# H    0     0                    24467.898955 23855.1035  2.50%     -    5s
# H    0     0                    24413.335819 23855.1035  2.29%     -    5s
#      0     0 23855.1035    0 1751 24413.3358 23855.1035  2.29%     -    6s
# H    0     0                    24413.231914 23855.1035  2.29%     -    6s
# H    0     0                    24360.752069 23855.1035  2.08%     -    6s
#      0     0 23855.1035    0 1746 24360.7521 23855.1035  2.08%     -    6s
# H    0     0                    24354.898021 23855.1035  2.05%     -    8s
#      0     0 23855.1035    0 1342 24354.8980 23855.1035  2.05%     -    8s
# H    0     0                    24343.235692 23855.1035  2.01%     -    8s
#      0     0 23855.3075    0 1401 24343.2357 23855.3075  2.00%     -    9s
#      0     0 23856.0114    0 1381 24343.2357 23856.0114  2.00%     -    9s
#      0     0 23856.0114    0 1399 24343.2357 23856.0114  2.00%     -    9s
#      0     0 23977.3816    0  490 24343.2357 23977.3816  1.50%     -   11s
# H    0     0                    24343.050834 23977.3816  1.50%     -   11s
# H    0     0                    24093.730032 23977.3816  0.48%     -   11s
# H    0     0                    24035.670942 23977.3816  0.24%     -   11s
#      0     0 23982.0483    0  548 24035.6709 23982.0483  0.22%     -   11s
#      0     0 24021.4942    0  390 24035.6709 24021.4942  0.06%     -   12s
# H    0     0                    24034.998228 24021.4942  0.06%     -   12s
#      0     0 24021.4942    0  386 24034.9982 24021.4942  0.06%     -   12s
# *    0     0               0    24021.494174 24021.4942  0.00%     -   13s
#
# Cutting planes:
#   Gomory: 302
#   Cover: 5
#   MIR: 17
#   StrongCG: 3
#   GUB cover: 9
#   Zero half: 1035
#
# Explored 1 nodes (139061 simplex iterations) in 13.61 seconds (17.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 24021.5 24035 24035.7 ... 24413.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.402149417387e+04, best bound 2.402149417365e+04, gap 0.0000%
# trial_size 72
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 40256 rows, 45576 columns and 614588 nonzeros
# Model fingerprint: 0x295fc8da
# Variable types: 26880 continuous, 18696 integer (18696 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Presolve removed 28717 rows and 26404 columns
# Presolve time: 0.22s
# Presolved: 11539 rows, 19172 columns, 100129 nonzeros
# Variable types: 1433 continuous, 17739 integer (17739 binary)
# Found heuristic solution: objective 30634.948113
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 2.385510e+04, 16384 iterations, 0.19 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23855.1035    0 1410 30634.9481 23855.1035  22.1%     -    2s
# H    0     0                    24396.033343 23855.1035  2.22%     -    2s
# H    0     0                    24383.591708 23855.1035  2.17%     -    2s
# H    0     0                    24344.588605 23855.1035  2.01%     -    2s
#      0     0 23855.1035    0 1736 24344.5886 23855.1035  2.01%     -    3s
# H    0     0                    24344.076748 23855.1035  2.01%     -    3s
#      0     0 23855.1035    0 1370 24344.0767 23855.1035  2.01%     -    6s
# H    0     0                    24330.261413 23855.1035  1.95%     -    6s
#      0     0 23855.4095    0 1390 24330.2614 23855.4095  1.95%     -    6s
#      0     0 23856.0740    0 1449 24330.2614 23856.0740  1.95%     -    6s
#      0     0 23856.0740    0 1448 24330.2614 23856.0740  1.95%     -    6s
#      0     0 23973.9531    0  503 24330.2614 23973.9531  1.46%     -    8s
# H    0     0                    24330.184746 23973.9531  1.46%     -    8s
# H    0     0                    24117.339773 23973.9531  0.59%     -    8s
# H    0     0                    24061.955082 23973.9531  0.37%     -    8s
#      0     0 23978.2864    0  497 24061.9551 23978.2864  0.35%     -    9s
#      0     0 23978.2864    0  501 24061.9551 23978.2864  0.35%     -    9s
#      0     0 24021.2864    0  423 24061.9551 24021.2864  0.17%     -    9s
# H    0     0                    24061.474257 24021.2864  0.17%     -    9s
# H    0     0                    24058.807590 24021.2864  0.16%     -    9s
#      0     0 24021.2864    0  279 24058.8076 24021.2864  0.16%     -    9s
#      0     0 24021.2864    0  233 24058.8076 24021.2864  0.16%     -   10s
# H    0     0                    24026.903576 24021.2864  0.02%     -   10s
# H    0     0                    24022.427025 24021.2864  0.00%     -   10s
#
# Cutting planes:
#   Gomory: 217
#   Cover: 7
#   MIR: 10
#   GUB cover: 7
#   Zero half: 1072
#
# Explored 1 nodes (134595 simplex iterations) in 10.61 seconds (14.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 24022.4 24026.9 24058.8 ... 24344.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.402242702483e+04, best bound 2.402128640168e+04, gap 0.0047%
# trial_size 73
# model = partflex-------------------------
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 37903 rows, 44400 columns and 581416 nonzeros
# Model fingerprint: 0xbc2f2ae8
# Variable types: 26880 continuous, 17520 integer (17520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28229 rows and 26307 columns
# Presolve time: 0.22s
# Presolved: 9674 rows, 18093 columns, 87673 nonzeros
# Found heuristic solution: objective 26105.826884
# Variable types: 1433 continuous, 16660 integer (16660 binary)
#
# Root relaxation: objective 2.461618e+04, 23752 iterations, 2.12 seconds (2.64 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24616.175037 24616.1750  0.00%     -    2s
#
# Explored 1 nodes (27310 simplex iterations) in 2.79 seconds (3.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24616.2 26105.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.461617503695e+04, best bound 2.461617503695e+04, gap 0.0000%
# trial_size 70
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38054 rows, 44640 columns and 589028 nonzeros
# Model fingerprint: 0x483f45f6
# Variable types: 26880 continuous, 17760 integer (17760 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28245 rows and 26309 columns
# Presolve time: 0.20s
# Presolved: 9809 rows, 18331 columns, 88905 nonzeros
# Found heuristic solution: objective 25980.833706
# Variable types: 1433 continuous, 16898 integer (16898 binary)
#
# Root relaxation: objective 2.459598e+04, 23758 iterations, 1.88 seconds (2.42 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24595.984055 24595.9841  0.00%     -    2s
#
# Explored 1 nodes (27416 simplex iterations) in 2.43 seconds (3.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24596 25980.8 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.459598405548e+04, best bound 2.459598405548e+04, gap 0.0000%
# trial_size 71
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38205 rows, 44880 columns and 596640 nonzeros
# Model fingerprint: 0x23031e45
# Variable types: 26880 continuous, 18000 integer (18000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28261 rows and 26311 columns
# Presolve time: 0.20s
# Presolved: 9944 rows, 18569 columns, 90137 nonzeros
# Found heuristic solution: objective 25955.280531
# Variable types: 1433 continuous, 17136 integer (17136 binary)
#
# Root relaxation: objective 2.457732e+04, 24201 iterations, 1.84 seconds (2.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24577.317325 24577.3173  0.00%     -    2s
#
# Explored 1 nodes (27992 simplex iterations) in 2.39 seconds (3.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24577.3 25955.3 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.457731732533e+04, best bound 2.457731732533e+04, gap 0.0000%
# trial_size 72
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38356 rows, 45120 columns and 604252 nonzeros
# Model fingerprint: 0xe25db857
# Variable types: 26880 continuous, 18240 integer (18240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28277 rows and 26313 columns
# Presolve time: 0.21s
# Presolved: 10079 rows, 18807 columns, 91369 nonzeros
# Found heuristic solution: objective 26003.900592
# Variable types: 1433 continuous, 17374 integer (17374 binary)
#
# Root relaxation: objective 2.455994e+04, 24579 iterations, 1.95 seconds (2.52 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24559.942438 24559.9424  0.00%     -    2s
#
# Explored 1 nodes (28991 simplex iterations) in 2.63 seconds (3.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24559.9 26003.9 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.455994243806e+04, best bound 2.455994243806e+04, gap 0.0000%
# trial_size 73
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38507 rows, 45360 columns and 611864 nonzeros
# Model fingerprint: 0x8ea3da92
# Variable types: 26880 continuous, 18480 integer (18480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28293 rows and 26315 columns
# Presolve time: 0.21s
# Presolved: 10214 rows, 19045 columns, 92601 nonzeros
# Found heuristic solution: objective 25931.066129
# Variable types: 1433 continuous, 17612 integer (17612 binary)
#
# Root relaxation: objective 2.454410e+04, 25399 iterations, 2.18 seconds (2.74 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    24544.099455 24544.0995  0.00%     -    2s
#
# Explored 1 nodes (29677 simplex iterations) in 2.86 seconds (3.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24544.1 25931.1 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.454409945500e+04, best bound 2.454409945500e+04, gap 0.0000%
# trial_size 74
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38658 rows, 45600 columns and 619476 nonzeros
# Model fingerprint: 0x682ee949
# Variable types: 26880 continuous, 18720 integer (18720 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28309 rows and 26317 columns
# Presolve time: 0.21s
# Presolved: 10349 rows, 19283 columns, 93833 nonzeros
# Found heuristic solution: objective 25839.223120
# Variable types: 1433 continuous, 17850 integer (17850 binary)
#
# Root relaxation: objective 2.452883e+04, 27565 iterations, 2.74 seconds (3.56 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    24528.833994 22110.8899  9.86%     -    3s
#      0     0          -    0      24528.8340 24528.8340  0.00%     -    3s
#
# Explored 1 nodes (30860 simplex iterations) in 3.30 seconds (4.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 24528.8 25839.2 1.792e+12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.452883399436e+04, best bound 2.452883399436e+04, gap 0.0000%
# trial_size 75
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38809 rows, 45840 columns and 627088 nonzeros
# Model fingerprint: 0xde493864
# Variable types: 26880 continuous, 18960 integer (18960 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28325 rows and 26319 columns
# Presolve time: 0.22s
# Presolved: 10484 rows, 19521 columns, 95065 nonzeros
# Found heuristic solution: objective 25879.691152
# Variable types: 1433 continuous, 18088 integer (18088 binary)
#
# ...
#
# Explored 1 nodes (110418 simplex iterations) in 10.95 seconds (13.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47992.9 48042.2 48059.1 ... 61990.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.799294390586e+04, best bound 4.799105545447e+04, gap 0.0039%
# trial_size 79
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 41488 rows, 47298 columns and 668824 nonzeros
# Model fingerprint: 0x1ad011c6
# Variable types: 26880 continuous, 20418 integer (20418 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28864 rows and 26425 columns
# Presolve time: 0.39s
# Presolved: 12624 rows, 20873 columns, 109593 nonzeros
# Found heuristic solution: objective 51321.363185
# Variable types: 1433 continuous, 19440 integer (19440 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.778921e+04, 17718 iterations, 0.24 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47789.2128    0 1729 51321.3632 47789.2128  6.88%     -    3s
# H    0     0                    48833.848860 47789.2128  2.14%     -    3s
# H    0     0                    48825.242247 47789.2128  2.12%     -    3s
# H    0     0                    48737.105917 47789.2128  1.94%     -    3s
#      0     0 47789.2128    0 1970 48737.1059 47789.2128  1.94%     -    4s
# H    0     0                    48545.293584 47789.2128  1.56%     -    4s
#      0     0 47789.2128    0 1972 48545.2936 47789.2128  1.56%     -    4s
#      0     0 47790.7167    0 1520 48545.2936 47790.7167  1.55%     -    7s
# H    0     0                    48536.644113 47790.7167  1.54%     -    7s
#      0     0 47802.0083    0 1473 48536.6441 47802.0083  1.51%     -    7s
#      0     0 47802.0083    0 1474 48536.6441 47802.0083  1.51%     -    7s
#      0     0 47983.7802    0  542 48536.6441 47983.7802  1.14%     -    8s
# H    0     0                    48093.114709 47983.7802  0.23%     -    9s
# H    0     0                    48001.032986 47983.7802  0.04%     -    9s
#      0     0 47983.7802    0  485 48001.0330 47983.7802  0.04%     -    9s
#      0     0 47988.8789    0  177 48001.0330 47988.8789  0.03%     -   10s
# H    0     0                    47998.675825 47988.8789  0.02%     -   10s
#      0     0 47988.8789    0  178 47998.6758 47988.8789  0.02%     -   10s
#      0     0 47988.8789    0  154 47998.6758 47988.8789  0.02%     -   11s
# H    0     0                    47991.132246 47988.8789  0.00%     -   12s
#
# Cutting planes:
#   Gomory: 412
#   Cover: 3
#   MIR: 24
#   StrongCG: 1
#   GUB cover: 9
#   Zero half: 1291
#
# Explored 1 nodes (110828 simplex iterations) in 12.20 seconds (12.98 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47991.1 47998.7 48001 ... 51321.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.799113224603e+04, best bound 4.798887891532e+04, gap 0.0047%
# trial_size 80
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 41664 rows, 47544 columns and 676572 nonzeros
# Model fingerprint: 0x58a9240a
# Variable types: 26880 continuous, 20664 integer (20664 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 28885 rows and 26428 columns
# Presolve time: 0.32s
# Presolved: 12779 rows, 21116 columns, 110945 nonzeros
# Variable types: 1433 continuous, 19683 integer (19683 binary)
# Found heuristic solution: objective 62038.808569
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.778921e+04, 18003 iterations, 0.22 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47789.2128    0 1722 62038.8086 47789.2128  23.0%     -    3s
# H    0     0                    61986.142200 47789.2128  22.9%     -    3s
# H    0     0                    60059.569388 47789.2128  20.4%     -    3s
#      0     0 47789.2128    0 1952 60059.5694 47789.2128  20.4%     -    4s
# H    0     0                    60039.761065 47789.2128  20.4%     -    4s
# H    0     0                    49013.144489 47789.2128  2.50%     -    4s
# H    0     0                    48734.509301 47789.2128  1.94%     -    4s
# H    0     0                    48722.000042 47789.5883  1.91%     -    7s
#      0     0 47789.5883    0 1582 48722.0000 47789.5883  1.91%     -    7s
# H    0     0                    48699.248232 47789.5883  1.87%     -    7s
#      0     0 47792.9315    0 1608 48699.2482 47792.9315  1.86%     -    8s
#      0     0 47792.9315    0 1594 48699.2482 47792.9315  1.86%     -    8s
#      0     0 47941.1597    0 1065 48699.2482 47941.1597  1.56%     -    9s
# H    0     0                    48698.314700 47941.1597  1.55%     -    9s
# H    0     0                    48169.597526 47941.1597  0.47%     -    9s
# H    0     0                    48032.208449 47941.1597  0.19%     -    9s
#      0     0 47941.1597    0 1078 48032.2084 47941.1597  0.19%     -    9s
#      0     0 47988.6263    0  372 48032.2084 47988.6263  0.09%     -   10s
# H    0     0                    48030.773594 47988.6263  0.09%     -   10s
#      0     0 47988.6263    0  337 48030.7736 47988.6263  0.09%     -   11s
#      0     0 47988.6263    0  219 48030.7736 47988.6263  0.09%     -   11s
#      0     0 47988.6263    0  250 48030.7736 47988.6263  0.09%     -   11s
#      0     0 47988.6263    0   59 48030.7736 47988.6263  0.09%     -   13s
# H    0     0                    48023.952097 47988.6263  0.07%     -   13s
#      0     0 47988.6263    0   59 48023.9521 47988.6263  0.07%     -   14s
# H    0     0                    47990.027440 47988.6263  0.00%     -   14s
#
# Cutting planes:
#   Gomory: 196
#   Cover: 3
#   MIR: 29
#   StrongCG: 2
#   GUB cover: 12
#   Zero half: 1273
#
# Explored 1 nodes (164944 simplex iterations) in 14.56 seconds (15.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47990 48024 48030.8 ... 49013.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.799002744045e+04, best bound 4.798862632497e+04, gap 0.0029%
# trial_size 81
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 41840 rows, 47790 columns and 684320 nonzeros
# Model fingerprint: 0x7ea926cd
# Variable types: 26880 continuous, 20910 integer (20910 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 28906 rows and 26431 columns
# Presolve time: 0.32s
# Presolved: 12934 rows, 21359 columns, 112297 nonzeros
# Variable types: 1433 continuous, 19926 integer (19926 binary)
# Found heuristic solution: objective 62062.808569
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.778921e+04, 18011 iterations, 0.22 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47789.2128    0 1641 62062.8086 47789.2128  23.0%     -    2s
# H    0     0                    62010.142200 47789.2128  22.9%     -    2s
# H    0     0                    59930.550467 47789.2128  20.3%     -    2s
# H    0     0                    48812.180722 47789.2128  2.10%     -    3s
# H    0     0                    48803.705292 47789.2128  2.08%     -    3s
# H    0     0                    48737.660947 47789.2128  1.95%     -    3s
#      0     0 47789.2128    0 1940 48737.6609 47789.2128  1.95%     -    4s
#      0     0 47789.2128    0 1952 48737.6609 47789.2128  1.95%     -    4s
#      0     0 47789.2128    0 1685 48737.6609 47789.2128  1.95%     -    7s
# H    0     0                    48683.043918 47789.2128  1.84%     -    8s
#      0     0 47789.6272    0 1729 48683.0439 47789.6272  1.84%     -    8s
#      0     0 47789.6272    0 1700 48683.0439 47789.6272  1.84%     -    8s
#      0     0 47925.3882    0  546 48683.0439 47925.3882  1.56%     -   10s
#      0     0 47927.3882    0  552 48683.0439 47927.3882  1.55%     -   11s
#      0     0 47988.6263    0  281 48683.0439 47988.6263  1.43%     -   11s
# H    0     0                    48618.972411 47988.6263  1.30%     -   12s
#      0     0 47988.6263    0  328 48618.9724 47988.6263  1.30%     -   12s
#      0     0 47988.6263    0  287 48618.9724 47988.6263  1.30%     -   12s
# H    0     0                    48391.752211 47988.6263  0.83%     -   12s
#      0     0 47988.6263    0   65 48391.7522 47988.6263  0.83%     -   13s
# H    0     0                    48356.579530 47988.6263  0.76%     -   13s
#      0     0 47988.6263    0   72 48356.5795 47988.6263  0.76%     -   14s
#      0     0 47988.6263    0   71 48356.5795 47988.6263  0.76%     -   14s
# H    0     0                    47989.111713 47988.6263  0.00%     -   15s
#
# Cutting planes:
#   Gomory: 163
#   Cover: 2
#   MIR: 19
#   StrongCG: 3
#   GUB cover: 9
#   Zero half: 1165
#
# Explored 1 nodes (198652 simplex iterations) in 15.07 seconds (16.62 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47989.1 48356.6 48391.8 ... 62010.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.798911171256e+04, best bound 4.798862632197e+04, gap 0.0010%
# trial_size 82
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42016 rows, 48036 columns and 692068 nonzeros
# Model fingerprint: 0x74e25b42
# Variable types: 26880 continuous, 21156 integer (21156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 28927 rows and 26434 columns
# Presolve time: 0.32s
# Presolved: 13089 rows, 21602 columns, 113649 nonzeros
# Variable types: 1433 continuous, 20169 integer (20169 binary)
# Found heuristic solution: objective 62086.808569
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.778921e+04, 18384 iterations, 0.22 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47789.2128    0 1679 62086.8086 47789.2128  23.0%     -    2s
# H    0     0                    62034.142200 47789.2128  23.0%     -    2s
# H    0     0                    59901.927417 47789.2128  20.2%     -    2s
#      0     0 47789.2128    0 1990 59901.9274 47789.2128  20.2%     -    3s
# H    0     0                    59879.524380 47789.2128  20.2%     -    3s
#      0     0 47789.2128    0 1589 59879.5244 47789.2128  20.2%     -    6s
# H    0     0                    58081.015828 47789.2128  17.7%     -    6s
#      0     0 47789.2128    0 1761 58081.0158 47789.2128  17.7%     -    7s
#      0     0 47902.9597    0  678 58081.0158 47902.9597  17.5%     -   10s
# H    0     0                    58071.504745 47902.9597  17.5%     -   10s
# H    0     0                    56158.778757 47902.9597  14.7%     -   10s
#      0     0 47905.2930    0  728 56158.7788 47905.2930  14.7%     -   10s
#      0     0 47988.6263    0  395 56158.7788 47988.6263  14.5%     -   11s
# H    0     0                    56145.142349 47988.6263  14.5%     -   11s
# H    0     0                    48028.374233 47988.6263  0.08%     -   11s
# H    0     0                    48011.536733 47988.6263  0.05%     -   11s
#      0     0 47988.6263    0  301 48011.5367 47988.6263  0.05%     -   11s
#      0     0 47988.6263    0  223 48011.5367 47988.6263  0.05%     -   11s
# H    0     0                    47988.721022 47988.6263  0.00%     -   11s
#
# Cutting planes:
#   Gomory: 219
#   Cover: 4
#   MIR: 14
#   GUB cover: 11
#   Zero half: 1223
#
# Explored 1 nodes (142451 simplex iterations) in 11.83 seconds (13.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47988.7 48011.5 48028.4 ... 62034.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.798872102194e+04, best bound 4.798862632397e+04, gap 0.0002%
# trial_size 83
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42192 rows, 48282 columns and 699816 nonzeros
# Model fingerprint: 0x8f2f0a37
# Variable types: 26880 continuous, 21402 integer (21402 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1.792000e+12
# Presolve removed 28948 rows and 26437 columns
# Presolve time: 0.37s
# Presolved: 13244 rows, 21845 columns, 115001 nonzeros
# Found heuristic solution: objective 51065.435475
# Variable types: 1433 continuous, 20412 integer (20412 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.778921e+04, 18604 iterations, 0.21 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47789.2128    0 1673 51065.4355 47789.2128  6.42%     -    2s
# H    0     0                    51026.131223 47789.2128  6.34%     -    2s
# H    0     0                    50157.814742 47789.2128  4.72%     -    3s
#      0     0 47789.2128    0 1905 50157.8147 47789.2128  4.72%     -    3s
# H    0     0                    50156.286965 47789.2128  4.72%     -    3s
# H    0     0                    49044.195247 47789.2128  2.56%     -    4s
# H    0     0                    48991.153918 47789.2128  2.45%     -    7s
# H    0     0                    48660.114378 47789.2128  1.79%     -    7s
#      0     0 47789.2128    0 1646 48660.1144 47789.2128  1.79%     -    7s
# H    0     0                    48616.773895 47789.2128  1.70%     -    7s
#      0     0 47791.6546    0 1605 48616.7739 47791.6546  1.70%     -    8s
#      0     0 47791.9356    0 1694 48616.7739 47791.9356  1.70%     -    8s
#      0     0 47791.9356    0 1702 48616.7739 47791.9356  1.70%     -    8s
#      0     0 47970.6263    0  172 48616.7739 47970.6263  1.33%     -   10s
#      0     0 47971.6263    0  179 48616.7739 47971.6263  1.33%     -   10s
#      0     0 47971.6263    0  181 48616.7739 47971.6263  1.33%     -   10s
#      0     0 47988.6263    0  170 48616.7739 47988.6263  1.29%     -   11s
# H    0     0                    48014.587343 47988.6263  0.05%     -   11s
# H    0     0                    48005.940663 47988.6263  0.04%     -   11s
#      0     0 47988.6263    0  168 48005.9407 47988.6263  0.04%     -   11s
#      0     0 47988.6263    0  115 48005.9407 47988.6263  0.04%     -   11s
# H    0     0                    47989.713566 47988.6263  0.00%     -   11s
#
# Cutting planes:
#   Gomory: 207
#   Cover: 6
#   MIR: 23
#   StrongCG: 2
#   GUB cover: 10
#   Zero half: 1225
#
# Explored 1 nodes (139756 simplex iterations) in 11.99 seconds (14.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 47989.7 48005.9 48014.6 ... 51026.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.798971356644e+04, best bound 4.798862632397e+04, gap 0.0023%
# trial_size 84
