# %%
from glob import glob
from os import path
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext
import time

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering_w_run_limits import run_roster_solver_objval

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']
# 16

# %%
#Subset to Berlin

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('frank') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt_subset)
# Out:
# ['frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00']

# %%
def dict_append_workforce(dict_, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, workforce_size, objvalprev, objval, objvalnext):
    dict_['instance_file_base'].append(base_file)
    dict_['city'].append(city)
    dict_['demand_baseline'].append(demand_baseline)
    dict_['model'].append(model)
    dict_['max_n_shifts'].append(max_n_shifts)
    dict_['outsourcing_cost_multiplier'].append(OC)
    dict_['regional_multiplier'].append(RM)
    dict_['global_multiplier'].append(GM)
    dict_['workforce_size_region0'].append(workforce_size)
    dict_['objective_value_prev'].append(objvalprev)
    dict_['objective_value'].append(objval)
    dict_['objective_value_next'].append(objvalnext)
    return dict_

# %%
#Code that determines optimal workforce size

MAX_TRIES = 200

RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

for base_file in list_city_dt_subset:
# for base_file in ['berlin_db=0.50']:

    if f'{base_file}.json' not in os.listdir(r'../workforce_size'):

        list_results = []

        #create inputs to run a trial workforce size
        weekday_ = f'{base_file}_dt=doublepeak.json'
        weekend_ = f'{base_file}_dt=uniform.json'

        instance_file_weekday = f"../instances/{weekday_}"
        instance_file_weekend = f"../instances/{weekend_}"

        shift_file_weekday = f"../shifts/{weekday_}"
        shift_file_weekend = f"../shifts/{weekend_}"

        #create dictionary for evaluating optimal workforce size
        workforce_out = f"../workforce_size/{base_file}.json"
        dict_out = {
            'instance_file_base':[],
            'city':[],
            'demand_baseline':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'workforce_size_region0':[],
            'objective_value_prev':[],
            'objective_value':[],
            'objective_value_next':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'

        city_match = re.search(city_pattern, base_file)
        db_match = re.search(db_pattern, base_file)

        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None

        #Set min_tries based on demand_baseline
        if demand_baseline == 0.5:
            MIN_TRIES = 5
        elif demand_baseline == 1.0:
            MIN_TRIES = 10
        elif demand_baseline == 2.0:
            MIN_TRIES = 20
        elif demand_baseline == 4.0:
            MIN_TRIES = 50

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
        # for OC in [1.2]:
            for model in ['fixed', 'flex', 'partflex']:
            # for model in ['fixed']:
                if model == 'partflex':
                    for max_n_shifts in range(2,5):
                    # for max_n_shifts in [4]:
                        objvalprev = 1e8
                        objval = 1e7
                        for trial_size in range(MIN_TRIES, MAX_TRIES):
                            workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                            if (objval < objvalprev)&(np.isnan(objval) == False):
                                objvalprev = objval
                                start_time = time.time()
                                dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
                                end_time = time.time()
                                run_time = end_time - start_time
                                objval = dict_results['objective_value'][0]
                                print(f'DB: {demand_baseline}, OC: {OC}, model: {model}-{max_n_shifts}, trial_size: {trial_size}, run_time: {run_time}')
                                df_ = pd.DataFrame(dict_results)
                                df_['workforce_size_trial'] = trial_size
                                list_results.append(df_)
                            else:
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size-1, np.nan, objvalprev, objval)
                                break
                            if trial_size == int(MAX_TRIES-1):
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size, objvalprev, objval, np.nan)
                else:
                    objvalprev = 1e8
                    objval = 1e7
                    for trial_size in range(MIN_TRIES, MAX_TRIES):
                        workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                        if (objval < objvalprev)&(np.isnan(objval) == False):
                            objvalprev = objval
                            start_time = time.time()
                            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
                            end_time = time.time()
                            run_time = end_time - start_time
                            objval = dict_results['objective_value'][0]
                            print(f'DB: {demand_baseline}, OC: {OC}, model: {model}, trial_size: {trial_size}, run_time: {run_time}')
                            df_ = pd.DataFrame(dict_results)
                            df_['workforce_size_trial'] = trial_size
                            list_results.append(df_)
                        else: 
                            #keep track of optimal (trial size - 1)
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size-1, np.nan, objvalprev, objval)
                            break
                        if trial_size == int(MAX_TRIES-1):
                            #keep track of optimal
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size, objvalprev, objval, np.nan)
        #export optimal workforce size values
        with open(workforce_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
        df_trials = pd.concat(list_results, ignore_index = True)
        df_trials.to_excel(f'../workforce_size/{base_file}_all_trials.xlsx', index = False)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 5, run_time: 2.15803599357605
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 6, run_time: 2.2017064094543457
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 7, run_time: 2.145470142364502
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 8, run_time: 2.1770644187927246
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 9, run_time: 2.35866117477417
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 10, run_time: 2.472306966781616
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 11, run_time: 2.5627024173736572
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 12, run_time: 2.739356279373169
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 13, run_time: 2.861269950866699
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 14, run_time: 2.9858250617980957
# DB: 0.5, OC: 1.2, model: fixed, trial_size: 15, run_time: 2.948106050491333
# DB: 0.5, OC: 1.2, model: flex, trial_size: 5, run_time: 2.0009684562683105
# DB: 0.5, OC: 1.2, model: flex, trial_size: 6, run_time: 2.0522382259368896
# DB: 0.5, OC: 1.2, model: flex, trial_size: 7, run_time: 2.124694585800171
# DB: 0.5, OC: 1.2, model: flex, trial_size: 8, run_time: 2.1650047302246094
# DB: 0.5, OC: 1.2, model: flex, trial_size: 9, run_time: 2.255340337753296
# DB: 0.5, OC: 1.2, model: flex, trial_size: 10, run_time: 2.358584403991699
# DB: 0.5, OC: 1.2, model: flex, trial_size: 11, run_time: 2.4495701789855957
# DB: 0.5, OC: 1.2, model: flex, trial_size: 12, run_time: 2.5378658771514893
# DB: 0.5, OC: 1.2, model: flex, trial_size: 13, run_time: 2.5711700916290283
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 5, run_time: 2.093069553375244
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 6, run_time: 2.1886136531829834
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 7, run_time: 2.2340123653411865
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 8, run_time: 2.3216161727905273
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 9, run_time: 2.508747100830078
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 10, run_time: 2.7698302268981934
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 11, run_time: 2.5273821353912354
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 12, run_time: 2.5814878940582275
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 13, run_time: 2.743446111679077
# DB: 0.5, OC: 1.2, model: partflex-2, trial_size: 14, run_time: 2.756755828857422
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 5, run_time: 2.1416237354278564
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 6, run_time: 2.280221462249756
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 7, run_time: 2.2799243927001953
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 8, run_time: 2.3470935821533203
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 9, run_time: 2.448976755142212
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 10, run_time: 2.47170352935791
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 11, run_time: 2.701672077178955
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 12, run_time: 2.8329150676727295
# DB: 0.5, OC: 1.2, model: partflex-3, trial_size: 13, run_time: 2.844259023666382
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 5, run_time: 2.223320722579956
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 6, run_time: 2.285735845565796
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 7, run_time: 2.348968744277954
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 8, run_time: 2.5119168758392334
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 9, run_time: 3.0816779136657715
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 10, run_time: 2.7120521068573
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 11, run_time: 2.80029296875
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 12, run_time: 2.8250133991241455
# DB: 0.5, OC: 1.2, model: partflex-4, trial_size: 13, run_time: 2.9398205280303955
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 5, run_time: 2.3611316680908203
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 6, run_time: 2.637901782989502
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 7, run_time: 2.5575008392333984
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 8, run_time: 2.711061954498291
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 9, run_time: 2.7242555618286133
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 10, run_time: 2.9892337322235107
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 11, run_time: 2.9122302532196045
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 12, run_time: 3.0288498401641846
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 13, run_time: 3.2759382724761963
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 14, run_time: 3.292120933532715
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 15, run_time: 3.5268516540527344
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 16, run_time: 3.6574363708496094
# DB: 0.5, OC: 1.5, model: fixed, trial_size: 17, run_time: 3.6762518882751465
# DB: 0.5, OC: 1.5, model: flex, trial_size: 5, run_time: 2.3275201320648193
# DB: 0.5, OC: 1.5, model: flex, trial_size: 6, run_time: 2.2660470008850098
# DB: 0.5, OC: 1.5, model: flex, trial_size: 7, run_time: 2.3612749576568604
# DB: 0.5, OC: 1.5, model: flex, trial_size: 8, run_time: 2.8074405193328857
# DB: 0.5, OC: 1.5, model: flex, trial_size: 9, run_time: 2.5734519958496094
# DB: 0.5, OC: 1.5, model: flex, trial_size: 10, run_time: 2.5507924556732178
# DB: 0.5, OC: 1.5, model: flex, trial_size: 11, run_time: 2.5090081691741943
# DB: 0.5, OC: 1.5, model: flex, trial_size: 12, run_time: 2.6646194458007812
# DB: 0.5, OC: 1.5, model: flex, trial_size: 13, run_time: 2.7239303588867188
# DB: 0.5, OC: 1.5, model: flex, trial_size: 14, run_time: 2.789111375808716
# DB: 0.5, OC: 1.5, model: flex, trial_size: 15, run_time: 2.9423651695251465
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 5, run_time: 2.267982006072998
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 6, run_time: 2.309401273727417
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 7, run_time: 2.343858242034912
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 8, run_time: 2.4665262699127197
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 9, run_time: 2.4788215160369873
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 10, run_time: 2.535121440887451
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 11, run_time: 2.658066749572754
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 12, run_time: 2.6541907787323
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 13, run_time: 2.755425453186035
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 14, run_time: 2.8457889556884766
# DB: 0.5, OC: 1.5, model: partflex-2, trial_size: 15, run_time: 2.6613333225250244
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 5, run_time: 2.0892858505249023
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 6, run_time: 2.0868990421295166
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 7, run_time: 2.2295117378234863
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 8, run_time: 2.272300958633423
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 9, run_time: 2.7038018703460693
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 10, run_time: 2.5059452056884766
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 11, run_time: 2.425198793411255
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 12, run_time: 2.56075119972229
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 13, run_time: 2.6726462841033936
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 14, run_time: 2.709568500518799
# DB: 0.5, OC: 1.5, model: partflex-3, trial_size: 15, run_time: 2.807013750076294
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 5, run_time: 2.1640079021453857
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 6, run_time: 2.164944887161255
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 7, run_time: 2.2854206562042236
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 8, run_time: 2.417088031768799
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 9, run_time: 2.3649652004241943
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 10, run_time: 2.4625978469848633
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 11, run_time: 2.473294258117676
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 12, run_time: 2.7270376682281494
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 13, run_time: 2.7159996032714844
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 14, run_time: 2.7075796127319336
# DB: 0.5, OC: 1.5, model: partflex-4, trial_size: 15, run_time: 2.842050552368164
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 5, run_time: 2.2551610469818115
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 6, run_time: 2.193030834197998
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 7, run_time: 2.352139711380005
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 8, run_time: 2.4853408336639404
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 9, run_time: 2.6037726402282715
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 10, run_time: 2.69537091255188
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 11, run_time: 3.2676331996917725
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 12, run_time: 3.106733798980713
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 13, run_time: 2.9726662635803223
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 14, run_time: 3.241030693054199
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 15, run_time: 3.339629888534546
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 16, run_time: 3.527937173843384
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 17, run_time: 3.7928578853607178
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 18, run_time: 4.030475616455078
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 19, run_time: 4.179980754852295
# DB: 0.5, OC: 1.8, model: fixed, trial_size: 20, run_time: 4.20593523979187
# DB: 0.5, OC: 1.8, model: flex, trial_size: 5, run_time: 2.2364706993103027
# DB: 0.5, OC: 1.8, model: flex, trial_size: 6, run_time: 2.367739200592041
# DB: 0.5, OC: 1.8, model: flex, trial_size: 7, run_time: 2.4191489219665527
# DB: 0.5, OC: 1.8, model: flex, trial_size: 8, run_time: 2.439540147781372
# DB: 0.5, OC: 1.8, model: flex, trial_size: 9, run_time: 2.640761375427246
# DB: 0.5, OC: 1.8, model: flex, trial_size: 10, run_time: 2.6872715950012207
# DB: 0.5, OC: 1.8, model: flex, trial_size: 11, run_time: 4.5844714641571045
# DB: 0.5, OC: 1.8, model: flex, trial_size: 12, run_time: 4.514837265014648
# DB: 0.5, OC: 1.8, model: flex, trial_size: 13, run_time: 5.327155113220215
# DB: 0.5, OC: 1.8, model: flex, trial_size: 14, run_time: 4.726858615875244
# DB: 0.5, OC: 1.8, model: flex, trial_size: 15, run_time: 4.489924430847168
# DB: 0.5, OC: 1.8, model: flex, trial_size: 16, run_time: 5.329957485198975
# DB: 0.5, OC: 1.8, model: flex, trial_size: 17, run_time: 6.24606466293335
# DB: 0.5, OC: 1.8, model: flex, trial_size: 18, run_time: 11.68329668045044
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 5, run_time: 2.2726452350616455
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 6, run_time: 2.276442050933838
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 7, run_time: 2.32149076461792
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 8, run_time: 2.306412696838379
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 9, run_time: 2.400110960006714
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 10, run_time: 2.4109902381896973
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 11, run_time: 2.4283969402313232
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 12, run_time: 2.5045816898345947
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 13, run_time: 2.5744054317474365
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 14, run_time: 2.6977031230926514
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 15, run_time: 2.686581611633301
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 16, run_time: 3.2485132217407227
# DB: 0.5, OC: 1.8, model: partflex-2, trial_size: 17, run_time: 3.279611825942993
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 5, run_time: 2.1451754570007324
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 6, run_time: 2.216395854949951
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 7, run_time: 2.33772873878479
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 8, run_time: 2.4313786029815674
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 9, run_time: 2.531187057495117
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 10, run_time: 2.5916953086853027
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 11, run_time: 9.192126035690308
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 12, run_time: 7.603827953338623
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 13, run_time: 6.429413080215454
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 14, run_time: 6.192756414413452
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 15, run_time: 6.473646879196167
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 16, run_time: 8.3327956199646
# DB: 0.5, OC: 1.8, model: partflex-3, trial_size: 17, run_time: 9.699683666229248
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 5, run_time: 2.409121513366699
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 6, run_time: 2.471379280090332
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 7, run_time: 2.5019381046295166
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 8, run_time: 2.583120584487915
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 9, run_time: 2.6396753787994385
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 10, run_time: 2.7439348697662354
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 11, run_time: 9.363931655883789
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 12, run_time: 7.672992706298828
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 13, run_time: 6.299010992050171
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 14, run_time: 6.004884719848633
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 15, run_time: 6.794230699539185
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 16, run_time: 7.4257519245147705
# DB: 0.5, OC: 1.8, model: partflex-4, trial_size: 17, run_time: 9.58206844329834
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 5, run_time: 2.2902867794036865
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 6, run_time: 2.339989185333252
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 7, run_time: 2.3592910766601562
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 8, run_time: 2.4128849506378174
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 9, run_time: 2.563936710357666
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 10, run_time: 2.6639368534088135
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 11, run_time: 2.699394702911377
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 12, run_time: 2.8371856212615967
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 13, run_time: 3.024726152420044
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 14, run_time: 3.0303616523742676
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 15, run_time: 3.2202045917510986
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 16, run_time: 3.216705799102783
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 17, run_time: 3.5077195167541504
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 18, run_time: 3.8164069652557373
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 19, run_time: 3.9395968914031982
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 20, run_time: 3.983264446258545
# DB: 0.5, OC: 2.0, model: fixed, trial_size: 21, run_time: 3.916914701461792
# DB: 0.5, OC: 2.0, model: flex, trial_size: 5, run_time: 2.282470941543579
# DB: 0.5, OC: 2.0, model: flex, trial_size: 6, run_time: 2.2850277423858643
# DB: 0.5, OC: 2.0, model: flex, trial_size: 7, run_time: 2.3340375423431396
# DB: 0.5, OC: 2.0, model: flex, trial_size: 8, run_time: 2.4673986434936523
# DB: 0.5, OC: 2.0, model: flex, trial_size: 9, run_time: 2.440268039703369
# DB: 0.5, OC: 2.0, model: flex, trial_size: 10, run_time: 2.6073124408721924
# DB: 0.5, OC: 2.0, model: flex, trial_size: 11, run_time: 5.759687423706055
# DB: 0.5, OC: 2.0, model: flex, trial_size: 12, run_time: 6.3237621784210205
# DB: 0.5, OC: 2.0, model: flex, trial_size: 13, run_time: 5.613461971282959
# DB: 0.5, OC: 2.0, model: flex, trial_size: 14, run_time: 6.62588906288147
# DB: 0.5, OC: 2.0, model: flex, trial_size: 15, run_time: 7.23832368850708
# DB: 0.5, OC: 2.0, model: flex, trial_size: 16, run_time: 7.387007236480713
# DB: 0.5, OC: 2.0, model: flex, trial_size: 17, run_time: 7.965717792510986
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 5, run_time: 2.238251209259033
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 6, run_time: 2.2544355392456055
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 7, run_time: 2.344156503677368
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 8, run_time: 2.470250368118286
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 9, run_time: 2.515031337738037
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 10, run_time: 2.6403212547302246
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 11, run_time: 2.7118778228759766
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 12, run_time: 2.809293031692505
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 13, run_time: 2.896199941635132
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 14, run_time: 2.9403204917907715
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 15, run_time: 3.1534554958343506
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 16, run_time: 3.168187141418457
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 17, run_time: 3.5238630771636963
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 18, run_time: 3.8900840282440186
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 19, run_time: 3.9074556827545166
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 20, run_time: 4.36170768737793
# DB: 0.5, OC: 2.0, model: partflex-2, trial_size: 21, run_time: 4.005635738372803
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 5, run_time: 2.1904542446136475
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 6, run_time: 2.245551347732544
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 7, run_time: 2.3972105979919434
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 8, run_time: 2.3907511234283447
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 9, run_time: 2.4463553428649902
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 10, run_time: 2.6375632286071777
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 11, run_time: 5.839354753494263
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 12, run_time: 6.411229848861694
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 13, run_time: 5.718203067779541
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 14, run_time: 6.5362443923950195
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 15, run_time: 7.122969627380371
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 16, run_time: 7.568142652511597
# DB: 0.5, OC: 2.0, model: partflex-3, trial_size: 17, run_time: 8.591569662094116
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 5, run_time: 2.52652907371521
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 6, run_time: 2.422886610031128
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 7, run_time: 2.4387552738189697
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 8, run_time: 2.5235092639923096
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 9, run_time: 2.5406928062438965
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 10, run_time: 2.670680046081543
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 11, run_time: 5.8030784130096436
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 12, run_time: 6.4971818923950195
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 13, run_time: 5.805934906005859
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 14, run_time: 6.474853754043579
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 15, run_time: 7.223292350769043
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 16, run_time: 7.944787502288818
# DB: 0.5, OC: 2.0, model: partflex-4, trial_size: 17, run_time: 8.356540441513062
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 5, run_time: 2.222116470336914
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 6, run_time: 2.2805445194244385
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 7, run_time: 2.4111506938934326
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 8, run_time: 2.4505159854888916
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 9, run_time: 2.6444051265716553
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 10, run_time: 2.690262794494629
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 11, run_time: 2.8159890174865723
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 12, run_time: 2.9438674449920654
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 13, run_time: 3.0828187465667725
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 14, run_time: 3.086725950241089
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 15, run_time: 3.2849929332733154
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 16, run_time: 3.3573296070098877
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 17, run_time: 3.653820753097534
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 18, run_time: 3.7531204223632812
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 19, run_time: 4.004809141159058
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 20, run_time: 4.014440059661865
# DB: 0.5, OC: 2.5, model: fixed, trial_size: 21, run_time: 4.043197393417358
# DB: 0.5, OC: 2.5, model: flex, trial_size: 5, run_time: 2.212475061416626
# DB: 0.5, OC: 2.5, model: flex, trial_size: 6, run_time: 2.3471932411193848
# DB: 0.5, OC: 2.5, model: flex, trial_size: 7, run_time: 2.6747210025787354
# DB: 0.5, OC: 2.5, model: flex, trial_size: 8, run_time: 2.5035817623138428
# DB: 0.5, OC: 2.5, model: flex, trial_size: 9, run_time: 2.541300058364868
# DB: 0.5, OC: 2.5, model: flex, trial_size: 10, run_time: 2.5905489921569824
# DB: 0.5, OC: 2.5, model: flex, trial_size: 11, run_time: 82.0971565246582
# DB: 0.5, OC: 2.5, model: flex, trial_size: 12, run_time: 7.1480872631073
# DB: 0.5, OC: 2.5, model: flex, trial_size: 13, run_time: 7.263319253921509
# DB: 0.5, OC: 2.5, model: flex, trial_size: 14, run_time: 7.614322900772095
# DB: 0.5, OC: 2.5, model: flex, trial_size: 15, run_time: 8.483433246612549
# DB: 0.5, OC: 2.5, model: flex, trial_size: 16, run_time: 7.7462382316589355
# DB: 0.5, OC: 2.5, model: flex, trial_size: 17, run_time: 8.11477017402649
# DB: 0.5, OC: 2.5, model: flex, trial_size: 18, run_time: 8.187446355819702
# DB: 0.5, OC: 2.5, model: flex, trial_size: 19, run_time: 8.510901689529419
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 5, run_time: 2.4202866554260254
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 6, run_time: 2.359900951385498
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 7, run_time: 2.9352521896362305
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 8, run_time: 2.6719231605529785
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 9, run_time: 2.621734142303467
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 10, run_time: 2.784278154373169
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 11, run_time: 2.8653740882873535
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 12, run_time: 2.956331729888916
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 13, run_time: 3.0954160690307617
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 14, run_time: 3.098041534423828
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 15, run_time: 3.3677241802215576
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 16, run_time: 3.5329813957214355
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 17, run_time: 3.8238039016723633
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 18, run_time: 3.88177752494812
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 19, run_time: 4.059329986572266
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 20, run_time: 4.137653112411499
# DB: 0.5, OC: 2.5, model: partflex-2, trial_size: 21, run_time: 4.193915128707886
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 5, run_time: 2.269744396209717
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 6, run_time: 2.3030130863189697
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 7, run_time: 2.4326119422912598
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 8, run_time: 2.4800078868865967
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 9, run_time: 2.611372709274292
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 10, run_time: 2.663048267364502
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 11, run_time: 82.26602458953857
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 12, run_time: 7.249238967895508
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 13, run_time: 7.285971641540527
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 14, run_time: 7.774462461471558
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 15, run_time: 8.001468896865845
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 16, run_time: 7.900848865509033
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 17, run_time: 7.95255184173584
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 18, run_time: 8.254785537719727
# DB: 0.5, OC: 2.5, model: partflex-3, trial_size: 19, run_time: 8.335822582244873
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 5, run_time: 2.260544776916504
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 6, run_time: 2.3338072299957275
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 7, run_time: 2.446896553039551
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 8, run_time: 2.576153039932251
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 9, run_time: 2.556694984436035
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 10, run_time: 2.706202268600464
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 11, run_time: 82.91861963272095
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 12, run_time: 7.541499137878418
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 13, run_time: 7.455657005310059
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 14, run_time: 7.846426725387573
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 15, run_time: 8.851807832717896
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 16, run_time: 8.078385353088379
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 17, run_time: 8.067857503890991
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 18, run_time: 8.225961923599243
# DB: 0.5, OC: 2.5, model: partflex-4, trial_size: 19, run_time: 8.42491102218628
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 10, run_time: 2.8493330478668213
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 11, run_time: 2.8920395374298096
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 12, run_time: 3.0038578510284424
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 13, run_time: 3.0687999725341797
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 14, run_time: 3.5472233295440674
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 15, run_time: 3.4590086936950684
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 16, run_time: 3.3119747638702393
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 17, run_time: 3.4193670749664307
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 18, run_time: 3.630779981613159
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 19, run_time: 3.758843183517456
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 20, run_time: 3.8940818309783936
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 21, run_time: 3.9953958988189697
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 22, run_time: 4.077208518981934
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 23, run_time: 4.256576776504517
# DB: 1.0, OC: 1.2, model: fixed, trial_size: 24, run_time: 4.470215797424316
# DB: 1.0, OC: 1.2, model: flex, trial_size: 10, run_time: 2.7414655685424805
# DB: 1.0, OC: 1.2, model: flex, trial_size: 11, run_time: 8.28911018371582
# DB: 1.0, OC: 1.2, model: flex, trial_size: 12, run_time: 100.35327100753784
# DB: 1.0, OC: 1.2, model: flex, trial_size: 13, run_time: 6.170459508895874
# DB: 1.0, OC: 1.2, model: flex, trial_size: 14, run_time: 7.865747690200806
# DB: 1.0, OC: 1.2, model: flex, trial_size: 15, run_time: 7.68310022354126
# DB: 1.0, OC: 1.2, model: flex, trial_size: 16, run_time: 9.201331615447998
# DB: 1.0, OC: 1.2, model: flex, trial_size: 17, run_time: 8.45664930343628
# DB: 1.0, OC: 1.2, model: flex, trial_size: 18, run_time: 8.21191120147705
# DB: 1.0, OC: 1.2, model: flex, trial_size: 19, run_time: 8.037869453430176
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 10, run_time: 2.857713222503662
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 11, run_time: 2.8895444869995117
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 12, run_time: 3.056797981262207
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 13, run_time: 3.0759706497192383
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 14, run_time: 3.0438520908355713
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 15, run_time: 3.3729634284973145
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 16, run_time: 3.3865678310394287
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 17, run_time: 3.5911402702331543
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 18, run_time: 3.7826952934265137
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 19, run_time: 3.8771533966064453
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 20, run_time: 3.878322124481201
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 21, run_time: 4.610656023025513
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 22, run_time: 4.368103981018066
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 23, run_time: 4.485288619995117
# DB: 1.0, OC: 1.2, model: partflex-2, trial_size: 24, run_time: 4.558363914489746
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 10, run_time: 2.822493076324463
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 11, run_time: 8.359636783599854
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 12, run_time: 100.04820775985718
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 13, run_time: 6.087437391281128
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 14, run_time: 7.91050124168396
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 15, run_time: 7.809551477432251
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 16, run_time: 8.65832257270813
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 17, run_time: 8.345269680023193
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 18, run_time: 8.648502111434937
# DB: 1.0, OC: 1.2, model: partflex-3, trial_size: 19, run_time: 8.429340839385986
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 10, run_time: 2.909907579421997
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 11, run_time: 8.618496417999268
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 12, run_time: 99.48370623588562
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 13, run_time: 6.235696077346802
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 14, run_time: 8.099786758422852
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 15, run_time: 8.118052005767822
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 16, run_time: 8.744515419006348
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 17, run_time: 8.547040462493896
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 18, run_time: 8.323193788528442
# DB: 1.0, OC: 1.2, model: partflex-4, trial_size: 19, run_time: 8.100817203521729
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 10, run_time: 3.1423799991607666
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 11, run_time: 3.266875982284546
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 12, run_time: 3.153081178665161
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 13, run_time: 3.1692047119140625
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 14, run_time: 3.165395736694336
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 15, run_time: 3.4288711547851562
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 16, run_time: 3.3891334533691406
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 17, run_time: 3.579580783843994
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 18, run_time: 3.708848476409912
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 19, run_time: 3.856900691986084
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 20, run_time: 4.085554838180542
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 21, run_time: 4.03226375579834
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 22, run_time: 4.230052947998047
# DB: 1.0, OC: 1.5, model: fixed, trial_size: 23, run_time: 4.359903812408447
# DB: 1.0, OC: 1.5, model: flex, trial_size: 10, run_time: 2.726309299468994
# DB: 1.0, OC: 1.5, model: flex, trial_size: 11, run_time: 5.03862190246582
# DB: 1.0, OC: 1.5, model: flex, trial_size: 12, run_time: 6.919951677322388
# DB: 1.0, OC: 1.5, model: flex, trial_size: 13, run_time: 7.215339422225952
# DB: 1.0, OC: 1.5, model: flex, trial_size: 14, run_time: 6.916789770126343
# DB: 1.0, OC: 1.5, model: flex, trial_size: 15, run_time: 8.493844747543335
# DB: 1.0, OC: 1.5, model: flex, trial_size: 16, run_time: 8.481050252914429
# DB: 1.0, OC: 1.5, model: flex, trial_size: 17, run_time: 8.701480865478516
# DB: 1.0, OC: 1.5, model: flex, trial_size: 18, run_time: 11.140532493591309
# DB: 1.0, OC: 1.5, model: flex, trial_size: 19, run_time: 10.29446530342102
# DB: 1.0, OC: 1.5, model: flex, trial_size: 20, run_time: 11.505764961242676
# DB: 1.0, OC: 1.5, model: flex, trial_size: 21, run_time: 10.86671233177185
# DB: 1.0, OC: 1.5, model: flex, trial_size: 22, run_time: 9.919382095336914
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 10, run_time: 2.7767386436462402
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 11, run_time: 2.908637046813965
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 12, run_time: 2.954136610031128
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 13, run_time: 2.990487813949585
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 14, run_time: 3.098956823348999
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 15, run_time: 3.276085138320923
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 16, run_time: 3.328996419906616
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 17, run_time: 4.332377910614014
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 18, run_time: 4.073018789291382
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 19, run_time: 3.9518165588378906
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 20, run_time: 4.141979932785034
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 21, run_time: 4.326797723770142
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 22, run_time: 4.53838324546814
# DB: 1.0, OC: 1.5, model: partflex-2, trial_size: 23, run_time: 4.420918941497803
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 10, run_time: 2.8634161949157715
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 11, run_time: 5.210151672363281
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 12, run_time: 7.178206443786621
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 13, run_time: 7.279342174530029
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 14, run_time: 7.045370578765869
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 15, run_time: 8.606451272964478
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 16, run_time: 8.411686420440674
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 17, run_time: 8.880315780639648
# DB: 1.0, OC: 1.5, model: partflex-3, trial_size: 18, run_time: 147.44328665733337
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 10, run_time: 3.0731897354125977
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 11, run_time: 6.020031690597534
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 12, run_time: 7.50434947013855
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 13, run_time: 6.95451807975769
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 14, run_time: 6.678007125854492
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 15, run_time: 8.086949586868286
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 16, run_time: 7.493139028549194
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 17, run_time: 8.059430599212646
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 18, run_time: 10.84367847442627
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 19, run_time: 11.27639126777649
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 20, run_time: 11.626118659973145
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 21, run_time: 10.373983383178711
# DB: 1.0, OC: 1.5, model: partflex-4, trial_size: 22, run_time: 9.602766990661621
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 10, run_time: 2.599337100982666
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 11, run_time: 2.671011209487915
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 12, run_time: 2.6893434524536133
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 13, run_time: 2.7184505462646484
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 14, run_time: 2.9314961433410645
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 15, run_time: 3.0989809036254883
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 16, run_time: 3.254667043685913
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 17, run_time: 3.305549383163452
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 18, run_time: 3.433551788330078
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 19, run_time: 3.442617416381836
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 20, run_time: 3.5429046154022217
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 21, run_time: 3.7785837650299072
# DB: 1.0, OC: 1.8, model: fixed, trial_size: 22, run_time: 4.522063255310059
# DB: 1.0, OC: 1.8, model: flex, trial_size: 10, run_time: 2.6339402198791504
# DB: 1.0, OC: 1.8, model: flex, trial_size: 11, run_time: 14.671393156051636
# DB: 1.0, OC: 1.8, model: flex, trial_size: 12, run_time: 24.813565015792847
# DB: 1.0, OC: 1.8, model: flex, trial_size: 13, run_time: 6.329696416854858
# DB: 1.0, OC: 1.8, model: flex, trial_size: 14, run_time: 8.165812969207764
# DB: 1.0, OC: 1.8, model: flex, trial_size: 15, run_time: 7.634573936462402
# DB: 1.0, OC: 1.8, model: flex, trial_size: 16, run_time: 7.5334672927856445
# DB: 1.0, OC: 1.8, model: flex, trial_size: 17, run_time: 8.347743511199951
# DB: 1.0, OC: 1.8, model: flex, trial_size: 18, run_time: 9.027209520339966
# DB: 1.0, OC: 1.8, model: flex, trial_size: 19, run_time: 10.820993661880493
# DB: 1.0, OC: 1.8, model: flex, trial_size: 20, run_time: 10.5543954372406
# DB: 1.0, OC: 1.8, model: flex, trial_size: 21, run_time: 11.486093997955322
# DB: 1.0, OC: 1.8, model: flex, trial_size: 22, run_time: 10.453831672668457
# DB: 1.0, OC: 1.8, model: flex, trial_size: 23, run_time: 11.010305166244507
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 10, run_time: 2.6076667308807373
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 11, run_time: 2.6624372005462646
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 12, run_time: 2.7577877044677734
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 13, run_time: 2.6047511100769043
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 14, run_time: 2.859286069869995
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 15, run_time: 3.152993679046631
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 16, run_time: 3.1764237880706787
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 17, run_time: 3.2899320125579834
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 18, run_time: 3.3776326179504395
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 19, run_time: 3.5041849613189697
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 20, run_time: 3.9473116397857666
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 21, run_time: 3.7015247344970703
# DB: 1.0, OC: 1.8, model: partflex-2, trial_size: 22, run_time: 3.8101680278778076
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 10, run_time: 2.338305711746216
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 11, run_time: 15.022268533706665
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 12, run_time: 24.52122139930725
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 13, run_time: 6.1584954261779785
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 14, run_time: 7.230403423309326
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 15, run_time: 7.524083375930786
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 16, run_time: 7.179325819015503
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 17, run_time: 8.281152486801147
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 18, run_time: 8.986743927001953
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 19, run_time: 10.81538200378418
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 20, run_time: 10.370885372161865
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 21, run_time: 10.207146883010864
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 22, run_time: 11.186910152435303
# DB: 1.0, OC: 1.8, model: partflex-3, trial_size: 23, run_time: 11.226801872253418
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 10, run_time: 2.4745311737060547
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 11, run_time: 15.426533699035645
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 12, run_time: 24.40138268470764
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 13, run_time: 7.161328554153442
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 14, run_time: 7.165944814682007
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 15, run_time: 7.571593761444092
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 16, run_time: 7.173826456069946
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 17, run_time: 8.374435901641846
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 18, run_time: 9.002429008483887
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 19, run_time: 11.599294424057007
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 20, run_time: 10.525335311889648
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 21, run_time: 10.367222547531128
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 22, run_time: 10.40693211555481
# DB: 1.0, OC: 1.8, model: partflex-4, trial_size: 23, run_time: 11.090323686599731
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 10, run_time: 2.4140689373016357
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 11, run_time: 2.5166983604431152
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 12, run_time: 2.6494181156158447
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 13, run_time: 3.2579002380371094
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 14, run_time: 2.846994161605835
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 15, run_time: 2.9925830364227295
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 16, run_time: 3.004542589187622
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 17, run_time: 3.097297191619873
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 18, run_time: 3.3352062702178955
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 19, run_time: 3.496048927307129
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 20, run_time: 3.616464853286743
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 21, run_time: 3.660210132598877
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 22, run_time: 3.6639864444732666
# DB: 1.0, OC: 2.0, model: fixed, trial_size: 23, run_time: 3.8213136196136475
# DB: 1.0, OC: 2.0, model: flex, trial_size: 10, run_time: 2.401873826980591
# DB: 1.0, OC: 2.0, model: flex, trial_size: 11, run_time: 2.542870044708252
# DB: 1.0, OC: 2.0, model: flex, trial_size: 12, run_time: 2.6373391151428223
# DB: 1.0, OC: 2.0, model: flex, trial_size: 13, run_time: 2.718477725982666
# DB: 1.0, OC: 2.0, model: flex, trial_size: 14, run_time: 2.8188254833221436
# DB: 1.0, OC: 2.0, model: flex, trial_size: 15, run_time: 3.0235002040863037
# DB: 1.0, OC: 2.0, model: flex, trial_size: 16, run_time: 3.0286314487457275
# DB: 1.0, OC: 2.0, model: flex, trial_size: 17, run_time: 3.1695592403411865
# DB: 1.0, OC: 2.0, model: flex, trial_size: 18, run_time: 3.3680849075317383
# DB: 1.0, OC: 2.0, model: flex, trial_size: 19, run_time: 3.491071939468384
# DB: 1.0, OC: 2.0, model: flex, trial_size: 20, run_time: 3.565532684326172
# DB: 1.0, OC: 2.0, model: flex, trial_size: 21, run_time: 3.6710875034332275
# DB: 1.0, OC: 2.0, model: flex, trial_size: 22, run_time: 3.59330415725708
# DB: 1.0, OC: 2.0, model: flex, trial_size: 23, run_time: 3.8128890991210938
# DB: 1.0, OC: 2.0, model: flex, trial_size: 24, run_time: 3.897756338119507
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 10, run_time: 2.3986289501190186
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 11, run_time: 2.442200183868408
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 12, run_time: 2.5819900035858154
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 13, run_time: 2.686354637145996
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 14, run_time: 2.815159559249878
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 15, run_time: 2.961899518966675
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 16, run_time: 2.996744394302368
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 17, run_time: 3.153265953063965
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 18, run_time: 3.3358356952667236
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 19, run_time: 3.3932290077209473
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 20, run_time: 3.5641226768493652
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 21, run_time: 3.64813232421875
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 22, run_time: 3.6790106296539307
# DB: 1.0, OC: 2.0, model: partflex-2, trial_size: 23, run_time: 3.7826743125915527
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 10, run_time: 2.3278772830963135
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 11, run_time: 2.497037410736084
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 12, run_time: 2.569566249847412
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 13, run_time: 2.6302552223205566
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 14, run_time: 3.314877986907959
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 15, run_time: 3.2415828704833984
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 16, run_time: 3.011439561843872
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 17, run_time: 3.1180367469787598
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 18, run_time: 3.293799877166748
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 19, run_time: 3.4346752166748047
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 20, run_time: 3.6693215370178223
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 21, run_time: 3.5099217891693115
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 22, run_time: 3.688255786895752
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 23, run_time: 3.7553415298461914
# DB: 1.0, OC: 2.0, model: partflex-3, trial_size: 24, run_time: 3.814635992050171
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 10, run_time: 2.3488872051239014
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 11, run_time: 2.419430732727051
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 12, run_time: 2.5069422721862793
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 13, run_time: 2.6565535068511963
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 14, run_time: 2.794722080230713
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 15, run_time: 2.9252843856811523
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 16, run_time: 3.0080134868621826
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 17, run_time: 3.0543084144592285
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 18, run_time: 3.3022446632385254
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 19, run_time: 4.538989782333374
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 20, run_time: 3.7465572357177734
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 21, run_time: 3.5666041374206543
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 22, run_time: 3.6969048976898193
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 23, run_time: 3.910703420639038
# DB: 1.0, OC: 2.0, model: partflex-4, trial_size: 24, run_time: 3.9054207801818848
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 10, run_time: 2.287520408630371
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 11, run_time: 2.5205605030059814
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 12, run_time: 2.643219470977783
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 13, run_time: 2.6847598552703857
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 14, run_time: 2.808218240737915
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 15, run_time: 2.951960802078247
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 16, run_time: 3.031592845916748
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 17, run_time: 3.0171823501586914
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 18, run_time: 3.29561448097229
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 19, run_time: 3.125530481338501
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 20, run_time: 3.3995847702026367
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 21, run_time: 3.5933754444122314
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 22, run_time: 4.038536548614502
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 23, run_time: 4.263467788696289
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 24, run_time: 3.7721235752105713
# DB: 1.0, OC: 2.5, model: fixed, trial_size: 25, run_time: 3.9988532066345215
# DB: 1.0, OC: 2.5, model: flex, trial_size: 10, run_time: 2.341338872909546
# ...
# DB: 4.0, OC: 1.5, model: partflex-4, trial_size: 53, run_time: 69.69571566581726
# DB: 4.0, OC: 1.5, model: partflex-4, trial_size: 54, run_time: 70.33901715278625
# DB: 4.0, OC: 1.5, model: partflex-4, trial_size: 55, run_time: 65.06241250038147
# DB: 4.0, OC: 1.5, model: partflex-4, trial_size: 56, run_time: 124.8817675113678
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 50, run_time: 6.371967315673828
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 51, run_time: 5.610610008239746
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 52, run_time: 5.692989826202393
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 53, run_time: 5.765192747116089
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 54, run_time: 5.9298999309539795
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 55, run_time: 6.157316207885742
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 56, run_time: 5.838318347930908
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 57, run_time: 5.883574962615967
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 58, run_time: 6.094218730926514
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 59, run_time: 5.974029541015625
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 60, run_time: 7.046392202377319
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 61, run_time: 6.250111103057861
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 62, run_time: 6.504289388656616
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 63, run_time: 6.670055389404297
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 64, run_time: 6.610863924026489
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 65, run_time: 6.724576950073242
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 66, run_time: 6.5372843742370605
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 67, run_time: 6.635623931884766
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 68, run_time: 6.933050870895386
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 69, run_time: 7.940941095352173
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 70, run_time: 7.178784370422363
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 71, run_time: 7.282332420349121
# DB: 4.0, OC: 1.8, model: fixed, trial_size: 72, run_time: 6.752131462097168
# DB: 4.0, OC: 1.8, model: flex, trial_size: 50, run_time: 55.30488991737366
# DB: 4.0, OC: 1.8, model: flex, trial_size: 51, run_time: 58.41404747962952
# DB: 4.0, OC: 1.8, model: flex, trial_size: 52, run_time: 70.98423290252686
# DB: 4.0, OC: 1.8, model: flex, trial_size: 53, run_time: 77.5185112953186
# DB: 4.0, OC: 1.8, model: flex, trial_size: 54, run_time: 82.55240535736084
# DB: 4.0, OC: 1.8, model: flex, trial_size: 55, run_time: 123.74870657920837
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 50, run_time: 5.642752408981323
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 51, run_time: 5.897161245346069
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 52, run_time: 5.900808811187744
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 53, run_time: 6.06984281539917
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 54, run_time: 6.023195743560791
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 55, run_time: 6.366469621658325
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 56, run_time: 6.156808137893677
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 57, run_time: 5.990898609161377
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 58, run_time: 6.786129951477051
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 59, run_time: 6.031538009643555
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 60, run_time: 6.184435606002808
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 61, run_time: 6.292306900024414
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 62, run_time: 6.3741090297698975
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 63, run_time: 6.6324708461761475
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 64, run_time: 6.383559942245483
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 65, run_time: 6.2608349323272705
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 66, run_time: 6.712526082992554
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 67, run_time: 7.2389655113220215
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 68, run_time: 7.170745611190796
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 69, run_time: 7.16716194152832
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 70, run_time: 7.020984888076782
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 71, run_time: 7.262561082839966
# DB: 4.0, OC: 1.8, model: partflex-2, trial_size: 72, run_time: 6.890483140945435
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 50, run_time: 55.332417011260986
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 51, run_time: 58.45069646835327
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 52, run_time: 70.78410196304321
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 53, run_time: 76.9533212184906
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 54, run_time: 82.31941866874695
# DB: 4.0, OC: 1.8, model: partflex-3, trial_size: 55, run_time: 123.83054161071777
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 50, run_time: 54.858768939971924
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 51, run_time: 56.542810678482056
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 52, run_time: 69.8366470336914
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 53, run_time: 75.5647714138031
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 54, run_time: 79.64008331298828
# DB: 4.0, OC: 1.8, model: partflex-4, trial_size: 55, run_time: 123.72146439552307
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 50, run_time: 5.930086374282837
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 51, run_time: 5.901022911071777
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 52, run_time: 5.936707973480225
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 53, run_time: 6.509726047515869
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 54, run_time: 5.997093915939331
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 55, run_time: 5.970882415771484
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 56, run_time: 5.952391624450684
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 57, run_time: 6.006840229034424
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 58, run_time: 6.065722465515137
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 59, run_time: 6.113580226898193
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 60, run_time: 6.975391864776611
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 61, run_time: 6.282570123672485
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 62, run_time: 6.599401950836182
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 63, run_time: 6.888702154159546
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 64, run_time: 6.660062551498413
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 65, run_time: 6.465015172958374
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 66, run_time: 6.780966520309448
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 67, run_time: 6.74439263343811
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 68, run_time: 6.91866660118103
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 69, run_time: 7.72736930847168
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 70, run_time: 6.93149209022522
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 71, run_time: 6.983286619186401
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 72, run_time: 7.260890483856201
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 73, run_time: 6.784854888916016
# DB: 4.0, OC: 2.0, model: fixed, trial_size: 74, run_time: 6.661694526672363
# DB: 4.0, OC: 2.0, model: flex, trial_size: 50, run_time: 69.18837642669678
# DB: 4.0, OC: 2.0, model: flex, trial_size: 51, run_time: 58.54405331611633
# DB: 4.0, OC: 2.0, model: flex, trial_size: 52, run_time: 64.27063918113708
# DB: 4.0, OC: 2.0, model: flex, trial_size: 53, run_time: 123.88538432121277
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 50, run_time: 5.701659679412842
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 51, run_time: 5.665757656097412
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 52, run_time: 5.796168088912964
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 53, run_time: 5.773417949676514
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 54, run_time: 5.9081714153289795
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 55, run_time: 5.79779052734375
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 56, run_time: 6.002719402313232
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 57, run_time: 5.913039684295654
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 58, run_time: 6.019719123840332
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 59, run_time: 5.969992637634277
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 60, run_time: 6.132492780685425
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 61, run_time: 6.1832873821258545
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 62, run_time: 7.477596998214722
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 63, run_time: 6.933234691619873
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 64, run_time: 6.7128846645355225
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 65, run_time: 7.090987205505371
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 66, run_time: 7.386224031448364
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 67, run_time: 8.356994867324829
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 68, run_time: 7.979945659637451
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 69, run_time: 7.168527841567993
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 70, run_time: 6.9856836795806885
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 71, run_time: 7.065767049789429
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 72, run_time: 7.924312114715576
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 73, run_time: 7.0535595417022705
# DB: 4.0, OC: 2.0, model: partflex-2, trial_size: 74, run_time: 6.790945053100586
# DB: 4.0, OC: 2.0, model: partflex-3, trial_size: 50, run_time: 71.34597063064575
# DB: 4.0, OC: 2.0, model: partflex-3, trial_size: 51, run_time: 59.808614015579224
# DB: 4.0, OC: 2.0, model: partflex-3, trial_size: 52, run_time: 66.45946002006531
# DB: 4.0, OC: 2.0, model: partflex-3, trial_size: 53, run_time: 124.10048341751099
# DB: 4.0, OC: 2.0, model: partflex-4, trial_size: 50, run_time: 72.09216237068176
# DB: 4.0, OC: 2.0, model: partflex-4, trial_size: 51, run_time: 60.14355778694153
# DB: 4.0, OC: 2.0, model: partflex-4, trial_size: 52, run_time: 65.70598435401917
# DB: 4.0, OC: 2.0, model: partflex-4, trial_size: 53, run_time: 123.98341059684753
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 50, run_time: 6.294093132019043
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 51, run_time: 5.724144458770752
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 52, run_time: 5.893160104751587
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 53, run_time: 5.874996900558472
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 54, run_time: 6.33681058883667
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 55, run_time: 6.0802881717681885
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 56, run_time: 6.346025705337524
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 57, run_time: 6.824686765670776
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 58, run_time: 7.337183713912964
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 59, run_time: 6.439272880554199
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 60, run_time: 6.788561105728149
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 61, run_time: 6.9346230030059814
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 62, run_time: 6.716418743133545
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 63, run_time: 7.257426023483276
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 64, run_time: 6.830170631408691
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 65, run_time: 7.313225507736206
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 66, run_time: 7.701111793518066
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 67, run_time: 7.974847793579102
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 68, run_time: 7.473652362823486
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 69, run_time: 7.151417970657349
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 70, run_time: 7.136587858200073
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 71, run_time: 7.8210601806640625
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 72, run_time: 7.720065593719482
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 73, run_time: 7.945751190185547
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 74, run_time: 8.550522804260254
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 75, run_time: 8.513490200042725
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 76, run_time: 8.376776456832886
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 77, run_time: 8.524205684661865
# DB: 4.0, OC: 2.5, model: fixed, trial_size: 78, run_time: 8.23563265800476
# DB: 4.0, OC: 2.5, model: flex, trial_size: 50, run_time: 60.99395728111267
# DB: 4.0, OC: 2.5, model: flex, trial_size: 51, run_time: 62.83260798454285
# DB: 4.0, OC: 2.5, model: flex, trial_size: 52, run_time: 59.83519172668457
# DB: 4.0, OC: 2.5, model: flex, trial_size: 53, run_time: 57.50503921508789
# DB: 4.0, OC: 2.5, model: flex, trial_size: 54, run_time: 123.96530818939209
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 50, run_time: 6.273475170135498
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 51, run_time: 5.762324094772339
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 52, run_time: 5.939051866531372
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 53, run_time: 5.781243801116943
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 54, run_time: 6.418509006500244
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 55, run_time: 5.971350431442261
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 56, run_time: 6.402911424636841
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 57, run_time: 6.446551561355591
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 58, run_time: 6.5046281814575195
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 59, run_time: 6.462075233459473
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 60, run_time: 6.76418924331665
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 61, run_time: 6.806931018829346
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 62, run_time: 6.823850154876709
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 63, run_time: 7.236280679702759
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 64, run_time: 6.844379186630249
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 65, run_time: 7.232449293136597
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 66, run_time: 7.09652042388916
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 67, run_time: 7.507992267608643
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 68, run_time: 7.391878843307495
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 69, run_time: 7.789804220199585
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 70, run_time: 7.53412652015686
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 71, run_time: 7.75421667098999
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 72, run_time: 7.727631568908691
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 73, run_time: 8.175268411636353
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 74, run_time: 7.97938346862793
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 75, run_time: 8.26743769645691
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 76, run_time: 8.359583139419556
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 77, run_time: 8.385108470916748
# DB: 4.0, OC: 2.5, model: partflex-2, trial_size: 78, run_time: 8.033106803894043
# DB: 4.0, OC: 2.5, model: partflex-3, trial_size: 50, run_time: 61.94608283042908
# DB: 4.0, OC: 2.5, model: partflex-3, trial_size: 51, run_time: 63.120699882507324
# DB: 4.0, OC: 2.5, model: partflex-3, trial_size: 52, run_time: 59.105945348739624
# DB: 4.0, OC: 2.5, model: partflex-3, trial_size: 53, run_time: 57.701863050460815
# DB: 4.0, OC: 2.5, model: partflex-3, trial_size: 54, run_time: 123.73367643356323
# DB: 4.0, OC: 2.5, model: partflex-4, trial_size: 50, run_time: 61.924668073654175
# DB: 4.0, OC: 2.5, model: partflex-4, trial_size: 51, run_time: 63.17299795150757
# DB: 4.0, OC: 2.5, model: partflex-4, trial_size: 52, run_time: 59.94038701057434
# DB: 4.0, OC: 2.5, model: partflex-4, trial_size: 53, run_time: 57.70526957511902
# DB: 4.0, OC: 2.5, model: partflex-4, trial_size: 54, run_time: 123.9775390625
