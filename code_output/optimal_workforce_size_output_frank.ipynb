# %%
from glob import glob
from os import path
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
from os.path import basename, splitext

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
# from solver_output import practice_print
from solver_rostering import run_roster_solver_objval
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
list_city_dt = []

for file_in in os.listdir(r'../instances'):
    base_file = splitext(basename(file_in))[0]
    base_file_split = base_file.split('_')
    file = base_file_split[0]+'_'+base_file_split[1]
    list_city_dt.append(file)

list_city_dt = list(set(list_city_dt))
list_city_dt.sort()
print(list_city_dt)
print(len(list_city_dt))
# Out:
# ['berlin_db=0.50', 'berlin_db=1.00', 'berlin_db=2.00', 'berlin_db=4.00', 'frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00', 'lyon_db=0.50', 'lyon_db=1.00', 'lyon_db=2.00', 'lyon_db=4.00', 'paris_db=0.50', 'paris_db=1.00', 'paris_db=2.00', 'paris_db=4.00']
# 16

# %%
#Subset to frank

list_city_dt_subset = []

for city_db in list_city_dt:
    if (city_db.find('frank') > -1):
        list_city_dt_subset.append(city_db)

print(list_city_dt_subset)
# Out:
# ['frankfurt_db=0.50', 'frankfurt_db=1.00', 'frankfurt_db=2.00', 'frankfurt_db=4.00']

# %%
def dict_append_workforce(dict_, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, workforce_size, objvalprev, objval, objvalnext):
    dict_['instance_file_base'].append(base_file)
    dict_['city'].append(city)
    dict_['demand_baseline'].append(demand_baseline)
    dict_['model'].append(model)
    dict_['max_n_shifts'].append(max_n_shifts)
    dict_['outsourcing_cost_multiplier'].append(OC)
    dict_['regional_multiplier'].append(RM)
    dict_['global_multiplier'].append(GM)
    dict_['workforce_size_region0'].append(workforce_size)
    dict_['objective_value_prev'].append(objvalprev)
    dict_['objective_value'].append(objval)
    dict_['objective_value_next'].append(objvalnext)
    return dict_

# %%
#Code that determines optimal workforce size

MAX_TRIES = 200

RM = 1.5
GM = 0.8
h_min = 32
h_max = 48
max_n_diff = 3

for base_file in list_city_dt_subset:
# for base_file in ['berlin_db=0.50']:
    print(base_file+'============================================')

    if f'{base_file}.json' not in os.listdir(r'../workforce_size'):

        list_results = []

        #create inputs to run a trial workforce size
        weekday_ = f'{base_file}_dt=doublepeak.json'
        weekend_ = f'{base_file}_dt=uniform.json'

        instance_file_weekday = f"../instances/{weekday_}"
        instance_file_weekend = f"../instances/{weekend_}"

        shift_file_weekday = f"../shifts/{weekday_}"
        shift_file_weekend = f"../shifts/{weekend_}"

        #create dictionary for evaluating optimal workforce size
        workforce_out = f"../workforce_size/{base_file}.json"
        dict_out = {
            'instance_file_base':[],
            'city':[],
            'demand_baseline':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'workforce_size_region0':[],
            'objective_value_prev':[],
            'objective_value':[],
            'objective_value_next':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'

        city_match = re.search(city_pattern, base_file)
        db_match = re.search(db_pattern, base_file)

        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None

        #Set min_tries based on demand_baseline
        if demand_baseline == 0.5:
            MIN_TRIES = 5
        elif demand_baseline == 1.0:
            MIN_TRIES = 10
        elif demand_baseline == 2.0:
            MIN_TRIES = 20
        elif demand_baseline == 4.0:
            MIN_TRIES = 50

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
        # for OC in [1.2]:
            print(f'OC = {OC}++++++++++++++++++++++')
            for model in ['fixed', 'flex', 'partflex']:
            # for model in ['fixed']:
                print(f'model = {model}-------------------------')
                if model == 'partflex':
                    for max_n_shifts in range(2,5):
                    # for max_n_shifts in [4]:
                        objvalprev = 1e8
                        objval = 1e7
                        for trial_size in range(MIN_TRIES, MAX_TRIES):
                            workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                            if (objval < objvalprev)&(np.isnan(objval) == False):
                                objvalprev = objval
                                dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff, max_n_shifts)
                                objval = dict_results['objective_value'][0]
                                print("trial_size",trial_size)
                                df_ = pd.DataFrame(dict_results)
                                df_['workforce_size_trial'] = trial_size
                                list_results.append(df_)
                            else:
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size-1, np.nan, objvalprev, objval)
                                break
                            if trial_size == int(MAX_TRIES-1):
                                #keep track of optimal
                                dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, max_n_shifts, trial_size, objvalprev, objval, np.nan)
                else:
                    objvalprev = 1e8
                    objval = 1e7
                    for trial_size in range(MIN_TRIES, MAX_TRIES):
                        workforce_dict = {0:trial_size, 1:1, 2:1, 3:1, 4:1}
                        if (objval < objvalprev)&(np.isnan(objval) == False):
                            objvalprev = objval
                            dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
                            objval = dict_results['objective_value'][0]
                            print("trial_size",trial_size)
                            df_ = pd.DataFrame(dict_results)
                            df_['workforce_size_trial'] = trial_size
                            list_results.append(df_)
                        else: 
                            #keep track of optimal (trial size - 1)
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size-1, np.nan, objvalprev, objval)
                            break
                        if trial_size == int(MAX_TRIES-1):
                            #keep track of optimal
                            dict_out = dict_append_workforce(dict_out, base_file, city, demand_baseline, OC, RM, GM, model, np.nan, trial_size, objvalprev, objval, np.nan)
        #export optimal workforce size values
        with open(workforce_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
        df_trials = pd.concat(list_results, ignore_index = True)
        df_trials.to_excel(f'../workforce_size/{base_file}_all_trials.xlsx', index = False)
# Out:
# frankfurt_db=0.50============================================
# OC = 1.2++++++++++++++++++++++
# model = fixed-------------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54968 rows, 57696 columns and 109458 nonzeros
# Model fingerprint: 0xf9d5aab1
# Variable types: 53760 continuous, 3936 integer (3936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2114.5000336
# Presolve removed 53839 rows and 54268 columns
# Presolve time: 0.13s
# Presolved: 1129 rows, 3428 columns, 11253 nonzeros
# Found heuristic solution: objective 2026.0000003
# Variable types: 841 continuous, 2587 integer (2587 binary)
#
# Root relaxation: objective 1.959280e+03, 2110 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1959.2800000 1959.28000  0.00%     -    0s
#
# Explored 1 nodes (2447 simplex iterations) in 0.22 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1959.28 2026 2114.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.959280000000e+03, best bound 1.959280000000e+03, gap 0.0000%
# trial_size 5
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55119 rows, 58216 columns and 120121 nonzeros
# Model fingerprint: 0x4ff61aea
# Variable types: 53760 continuous, 4456 integer (4456 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 53862 rows and 54285 columns
# Presolve time: 0.10s
# Presolved: 1257 rows, 3931 columns, 13321 nonzeros
# Variable types: 841 continuous, 3090 integer (3090 binary)
#
# Root relaxation: objective 1.948640e+03, 3335 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1948.6400000 1948.64000  0.00%     -    0s
#
# Explored 1 nodes (3773 simplex iterations) in 0.21 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1948.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.948640000000e+03, best bound 1.948640000000e+03, gap 0.0000%
# trial_size 6
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55270 rows, 58736 columns and 130784 nonzeros
# Model fingerprint: 0x9da18b0b
# Variable types: 53760 continuous, 4976 integer (4976 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 53885 rows and 54302 columns
# Presolve time: 0.11s
# Presolved: 1385 rows, 4434 columns, 15389 nonzeros
# Variable types: 841 continuous, 3593 integer (3593 binary)
#
# Root relaxation: objective 1.939000e+03, 3638 iterations, 0.09 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1939.0000000 1939.00000  0.00%     -    0s
#
# Explored 1 nodes (4184 simplex iterations) in 0.26 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1939
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.939000000000e+03, best bound 1.939000000000e+03, gap 0.0000%
# trial_size 7
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55421 rows, 59256 columns and 141447 nonzeros
# Model fingerprint: 0xa5bf1cba
# Variable types: 53760 continuous, 5496 integer (5496 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2137.0800326
# Presolve removed 53908 rows and 54319 columns
# Presolve time: 0.15s
# Presolved: 1513 rows, 4937 columns, 17457 nonzeros
# Found heuristic solution: objective 2012.0800002
# Variable types: 841 continuous, 4096 integer (4096 binary)
#
# Root relaxation: objective 1.931080e+03, 4208 iterations, 0.11 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1931.0800000 1931.08000  0.00%     -    0s
#
# Explored 1 nodes (4208 simplex iterations) in 0.31 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1931.08 2012.08 2137.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.931080000000e+03, best bound 1.931080000000e+03, gap 0.0000%
# trial_size 8
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55572 rows, 59776 columns and 152110 nonzeros
# Model fingerprint: 0xbd4a7e7a
# Variable types: 53760 continuous, 6016 integer (6016 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2122.8400325
# Presolve removed 53931 rows and 54336 columns
# Presolve time: 0.13s
# Presolved: 1641 rows, 5440 columns, 19525 nonzeros
# Found heuristic solution: objective 2004.2000002
# Variable types: 841 continuous, 4599 integer (4599 binary)
#
# Root relaxation: objective 1.924600e+03, 6277 iterations, 0.20 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1924.6000000 1924.60000  0.00%     -    0s
#
# Explored 1 nodes (7068 simplex iterations) in 0.41 seconds (0.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1924.6 2004.2 2122.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.924600000000e+03, best bound 1.924600000000e+03, gap 0.0000%
# trial_size 9
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55723 rows, 60296 columns and 162773 nonzeros
# Model fingerprint: 0xd99e2a4c
# Variable types: 53760 continuous, 6536 integer (6536 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2116.9600321
# Presolve removed 53954 rows and 54353 columns
# Presolve time: 0.16s
# Presolved: 1769 rows, 5943 columns, 21593 nonzeros
# Found heuristic solution: objective 2001.6000002
# Variable types: 841 continuous, 5102 integer (5102 binary)
#
# Root relaxation: objective 1.918680e+03, 6349 iterations, 0.25 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1918.6800000 1918.68000  0.00%     -    0s
#
# Explored 1 nodes (7223 simplex iterations) in 0.49 seconds (0.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1918.68 2001.6 2116.96
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.918680000000e+03, best bound 1.918680000000e+03, gap 0.0000%
# trial_size 10
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55874 rows, 60816 columns and 173436 nonzeros
# Model fingerprint: 0xeb2e56e5
# Variable types: 53760 continuous, 7056 integer (7056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 53977 rows and 54370 columns
# Presolve time: 0.17s
# Presolved: 1897 rows, 6446 columns, 23661 nonzeros
# Variable types: 841 continuous, 5605 integer (5605 binary)
#
# Root relaxation: objective 1.913320e+03, 8092 iterations, 0.34 seconds (0.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1913.3200000 1913.32000  0.00%     -    0s
#
# Explored 1 nodes (8092 simplex iterations) in 0.56 seconds (0.50 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1913.32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.913320000000e+03, best bound 1.913320000000e+03, gap 0.0000%
# trial_size 11
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 56025 rows, 61336 columns and 184099 nonzeros
# Model fingerprint: 0xb4f90779
# Variable types: 53760 continuous, 7576 integer (7576 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2119.2800315
# Presolve removed 54000 rows and 54387 columns
# Presolve time: 0.17s
# Presolved: 2025 rows, 6949 columns, 25729 nonzeros
# Found heuristic solution: objective 1995.6000002
# Variable types: 841 continuous, 6108 integer (6108 binary)
#
# Root relaxation: objective 1.909000e+03, 8211 iterations, 0.37 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1909.0000000 1909.00000  0.00%     -    0s
#
# Explored 1 nodes (9522 simplex iterations) in 0.64 seconds (0.59 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1909 1995.6 2119.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.909000000000e+03, best bound 1.909000000000e+03, gap 0.0000%
# trial_size 12
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 56176 rows, 61856 columns and 194762 nonzeros
# Model fingerprint: 0x90c0eee8
# Variable types: 53760 continuous, 8096 integer (8096 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2129.5800311
# Presolve removed 54023 rows and 54404 columns
# Presolve time: 0.20s
# Presolved: 2153 rows, 7452 columns, 27797 nonzeros
# Found heuristic solution: objective 1984.6800002
# Variable types: 841 continuous, 6611 integer (6611 binary)
#
# Root relaxation: objective 1.906680e+03, 8010 iterations, 0.43 seconds (0.38 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1906.6800000 1906.68000  0.00%     -    0s
#
# Explored 1 nodes (9408 simplex iterations) in 0.77 seconds (0.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1906.68 1984.68 2129.58
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.906680000000e+03, best bound 1.906680000000e+03, gap 0.0000%
# trial_size 13
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 56327 rows, 62376 columns and 205425 nonzeros
# Model fingerprint: 0xcb19e0fb
# Variable types: 53760 continuous, 8616 integer (8616 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2137.4200308
# Presolve removed 54046 rows and 54421 columns
# Presolve time: 0.20s
# Presolved: 2281 rows, 7955 columns, 29865 nonzeros
# Found heuristic solution: objective 1980.4400002
# Variable types: 841 continuous, 7114 integer (7114 binary)
#
# Root relaxation: objective 1.906360e+03, 8796 iterations, 0.43 seconds (0.39 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1906.3600000 1906.36000  0.00%     -    0s
#
# Explored 1 nodes (10154 simplex iterations) in 0.74 seconds (0.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1906.36 1980.44 2137.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.906360000000e+03, best bound 1.906360000000e+03, gap 0.0000%
# trial_size 14
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 56478 rows, 62896 columns and 216088 nonzeros
# Model fingerprint: 0xfc40c5a3
# Variable types: 53760 continuous, 9136 integer (9136 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 54069 rows and 54438 columns
# Presolve time: 0.20s
# Presolved: 2409 rows, 8458 columns, 31933 nonzeros
# Variable types: 841 continuous, 7617 integer (7617 binary)
#
# Root relaxation: objective 1.906360e+03, 10159 iterations, 0.55 seconds (0.48 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1906.3600000 1906.36000  0.00%     -    0s
#
# Explored 1 nodes (10159 simplex iterations) in 0.81 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1906.36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.906360000000e+03, best bound 1.906360000000e+03, gap 0.0000%
# trial_size 15
# model = flex-------------------------
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54803 rows, 57673 columns and 107969 nonzeros
# Model fingerprint: 0x51e83d39
# Variable types: 53760 continuous, 3913 integer (3913 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2075.3400333
# Presolve removed 53765 rows and 54063 columns
# Presolve time: 0.05s
# Presolved: 1038 rows, 3610 columns, 9806 nonzeros
# Found heuristic solution: objective 1971.8400003
# Variable types: 841 continuous, 2769 integer (2769 binary)
# Found heuristic solution: objective 1913.1600000
#
# Root relaxation: objective 1.818320e+03, 1283 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1818.3200000 1818.32000  0.00%     -    0s
#
# Explored 1 nodes (1283 simplex iterations) in 0.14 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1818.32 1913.16 1971.84 2075.34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.818320000000e+03, best bound 1.818320000000e+03, gap 0.0000%
# trial_size 5
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54929 rows, 58189 columns and 118398 nonzeros
# Model fingerprint: 0x523dd7c4
# Variable types: 53760 continuous, 4429 integer (4429 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 2062.1400330
# Presolve removed 53876 rows and 54081 columns
# Presolve time: 0.06s
# Presolved: 1053 rows, 4108 columns, 10403 nonzeros
# Found heuristic solution: objective 1961.2000003
# Variable types: 841 continuous, 3267 integer (3267 binary)
# Found heuristic solution: objective 1897.0800000
#
# Root relaxation: objective 1.802360e+03, 1899 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1802.3600000 1802.36000  0.00%     -    0s
#
# Explored 1 nodes (1899 simplex iterations) in 0.17 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1802.36 1897.08 1961.2 2062.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.802360000000e+03, best bound 1.802360000000e+03, gap 0.0000%
# trial_size 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 100
#      98 if (objval < objvalprev)&(np.isnan(objval) == False):
#      99     objvalprev = objval
# --> 100     dict_results = run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, OC, RM, GM, h_min, h_max, max_n_diff)
#     101     objval = dict_results['objective_value'][0]
#     102     print("trial_size",trial_size)
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering.py:676, in run_roster_solver_objval(model, instance_file_weekday, shift_file_weekday, instance_file_weekend, shift_file_weekend, workforce_dict, outsourcing_cost_multiplier, regional_multiplier, global_multiplier, h_min, h_max, max_n_diff, max_n_shifts, expand_workforce_to_regions)
#     673 i = Instance(args=args)
#     674 solver = Solver(args=args, i=i)
# --> 676 roster_results = solver.solve_roster_objval()
#     678 return roster_results
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering.py:635, in Solver.solve_roster_objval(self)
#     634 def solve_roster_objval(self) -> dict:
# --> 635     self.__build_baseline_model()
#     636     self.__build_roster_model()
#     637     self.m.optimize()
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering.py:419, in Solver.__build_baseline_model(self)
#     407 self.m.addConstrs((
#     408     sum(self.k[(employee, area, theta, day)]
#     409         for area in self.i.reg_areas[region]
#    (...)
#     415         for day in self.i.days
#     416 ), name = 'specific_periods_per_day')
#     418 #constraint - demand can be met by outsourcing
# --> 419 self.m.addConstrs(
#     420     (
#     421         self.i.srequired[(scenario, area, theta, day)] * self.omega[(scenario, area, theta, day)] >= \
#     422         (self.i.srequired[(scenario, area, theta, day)] -
#     423         sum(
#     424             self.k[(employee, area, theta, day)]
#     425             for employee in self.i.employees[region]
#     426         )) * self.i.sdemand[(scenario, area, theta, day)] * self.i.outsourcing_cost
#     427
#     428         for region in self.i.regions
#     429         for area in self.i.reg_areas[region]
#     430         for day in self.i.days
#     431         for theta in self.i.periods[day]
#     432         for scenario in self.i.scenarios[day]
#     433     ), name='outsourcing_demand'
#     434 )
#
# File src/gurobipy/model.pxi:3877, in gurobipy.Model.addConstrs()
#
# File ~/Documents/VSCode/Term3/Masters_Thesis/lmd-sizing-scheduling/code_output/../solver/solver_rostering.py:420, in <genexpr>(.0)
#     407 self.m.addConstrs((
#     408     sum(self.k[(employee, area, theta, day)]
#     409         for area in self.i.reg_areas[region]
#    (...)
#     415         for day in self.i.days
#     416 ), name = 'specific_periods_per_day')
#     418 #constraint - demand can be met by outsourcing
#     419 self.m.addConstrs(
# --> 420     (
#     421         self.i.srequired[(scenario, area, theta, day)] * self.omega[(scenario, area, theta, day)] >= \
#     422         (self.i.srequired[(scenario, area, theta, day)] -
#     423         sum(
#     424             self.k[(employee, area, theta, day)]
#     425             for employee in self.i.employees[region]
#     426         )) * self.i.sdemand[(scenario, area, theta, day)] * self.i.outsourcing_cost
#     427
#     428         for region in self.i.regions
#     429         for area in self.i.reg_areas[region]
#     430         for day in self.i.days
#     431         for theta in self.i.periods[day]
#     432         for scenario in self.i.scenarios[day]
#     433     ), name='outsourcing_demand'
#     434 )
#
# KeyboardInterrupt:

# %%
df_view = pd.read_excel(f'../workforce_size/berlin_db=2.00_all_trials.xlsx')
df_view.sort_values(by = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts', 'workforce_size_trial'], ascending = [True, True, True, True, True, False], inplace = True)
df_view.drop_duplicates(subset = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts'], inplace = True)
df_view.sort_values(by = ['workforce_size_trial'], inplace = True)
df_view.head()
# Out:
#            instance    city  demand_baseline  outsourcing_cost_multiplier  \
# 137  berlin_db=2.00  berlin                2                          1.2
# 377  berlin_db=2.00  berlin                2                          1.5
# 619  berlin_db=2.00  berlin                2                          1.8
# 864  berlin_db=2.00  berlin                2                          2.0
# 97   berlin_db=2.00  berlin                2                          1.2
#
#      region_multiplier  global_multiplier     model  max_n_shifts  \
# 137                1.5                0.8  partflex           2.0
# 377                1.5                0.8  partflex           2.0
# 619                1.5                0.8  partflex           2.0
# 864                1.5                0.8  partflex           2.0
# 97                 1.5                0.8      flex           NaN
#
#      workforce_size  wage_costs  objective_value  objective_value_post_wage  \
# 137              43       844.0     14182.163333               13338.163333
# 377              45       900.0     17510.425000               16610.425000
# 619              46       948.0     20826.365000               19878.365000
# 864              47       948.0     23035.072222               22087.072222
# 97               47      1084.0     13266.540000               12182.540000
#
#      workforce_size_trial
# 137                    40
# 377                    42
# 619                    43
# 864                    44
# 97                     44

# %%
df_view.tail()
# Out:
#             instance    city  demand_baseline  outsourcing_cost_multiplier  \
# 53    berlin_db=2.00  berlin                2                          1.2
# 289   berlin_db=2.00  berlin                2                          1.5
# 529   berlin_db=2.00  berlin                2                          1.8
# 773   berlin_db=2.00  berlin                2                          2.0
# 1020  berlin_db=2.00  berlin                2                          2.5
#
#       region_multiplier  global_multiplier  model  max_n_shifts  \
# 53                  1.5                0.8  fixed           NaN
# 289                 1.5                0.8  fixed           NaN
# 529                 1.5                0.8  fixed           NaN
# 773                 1.5                0.8  fixed           NaN
# 1020                1.5                0.8  fixed           NaN
#
#       workforce_size  wage_costs  objective_value  objective_value_post_wage  \
# 53                57      1324.0     13368.893333               12044.893333
# 289               61      1420.0     16367.629167               14947.629167
# 529               63      1468.0     19351.010000               17883.010000
# 773               63      1468.0     21338.011111               19870.011111
# 1020              65      1532.0     26295.972222               24763.972222
#
#       workforce_size_trial
# 53                      54
# 289                     58
# 529                     60
# 773                     60
# 1020                    62

# %%
df_view = pd.read_excel(f'../workforce_size/lyon_db=0.50_all_trials.xlsx')
df_view.sort_values(by = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts', 'workforce_size_trial'], ascending = [True, True, True, True, True, False], inplace = True)
df_view.drop_duplicates(subset = ['city','demand_baseline','outsourcing_cost_multiplier','model','max_n_shifts'], inplace = True)
df_view.sort_values(by = ['workforce_size_trial'], inplace = True)
df_view.head()
# Out:
#         instance  city  demand_baseline  outsourcing_cost_multiplier  \
# 20  lyon_db=0.50  lyon              0.5                          1.2
# 41  lyon_db=0.50  lyon              0.5                          1.2
# 50  lyon_db=0.50  lyon              0.5                          1.2
# 71  lyon_db=0.50  lyon              0.5                          1.5
# 92  lyon_db=0.50  lyon              0.5                          1.5
#
#     region_multiplier  global_multiplier     model  max_n_shifts  \
# 20                1.5                0.8      flex           NaN
# 41                1.5                0.8  partflex           3.0
# 50                1.5                0.8  partflex           4.0
# 71                1.5                0.8      flex           NaN
# 92                1.5                0.8  partflex           3.0
#
#     workforce_size  wage_costs  objective_value  objective_value_post_wage  \
# 20              16       332.0      2749.553333                2417.553333
# 41              16       332.0      2749.553333                2417.553333
# 50              16       332.0      2749.553333                2417.553333
# 71              17       372.0      3379.108333                3007.108333
# 92              17       372.0      3379.108333                3007.108333
#
#     workforce_size_trial
# 20                    13
# 41                    13
# 50                    13
# 71                    14
# 92                    14
